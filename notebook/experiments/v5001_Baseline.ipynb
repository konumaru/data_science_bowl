# %%
import os
import gc
import re
import json
import copy
import time
import eli5
import datetime
from numba import jit

from IPython.display import HTML
import altair as alt
from category_encoders.ordinal import OrdinalEncoder
from typing import List, Any

import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats

import random
random.seed(28)
np.random.seed(28)

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import lightgbm as lgb

import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance

import catboost as cat
from catboost import CatBoostRegressor, CatBoostClassifier

from bayes_opt import BayesianOptimization
import shap

from itertools import product
from functools import partial

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn import linear_model
from sklearn.svm import NuSVR, SVR
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import cohen_kappa_score, mean_squared_error, mean_absolute_error


# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from collections import defaultdict
from joblib import Parallel, delayed

pd.set_option('display.max_columns', 1000)
pd.set_option('max_rows', 500)
pd.options.display.precision = 15
np.random.seed(42)

import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/rui/.local/share/virtualenvs/data_science_bowl-_c7OiX6v/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/rui/.local/share/virtualenvs/data_science_bowl-_c7OiX6v/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Objective
#
# - 特徴量を考える。
# - アンサンブルについては、最終日周辺で考える。

# %% [markdown]
# # Notes
#
# - CV score with added features
#     - baseline：0.606055546528173
#     - add last_game_round：0.6056430755467688
#     - add last_game_level：
#     - {world}_duration_sumを除く：

# %% [markdown]
# ## Load Data

# %%
def read_data():
    if os.path.exists('/kaggle/input/data-science-bowl-2019/'):
        data_dir_path = '/kaggle/input/data-science-bowl-2019/'
    else:
        data_dir_path = '../data/raw/'
        
    
    print('Reading train.csv file....')
    train = pd.read_csv(data_dir_path+'train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv(data_dir_path+'test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv(data_dir_path+'train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv(data_dir_path+'specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv(data_dir_path+'sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
raw_train, raw_test, train_labels, specs, sample_submission = read_data()
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns

# %%
print(raw_train.shape)
raw_train.head()
# Out:
# (11341042, 11)
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %% [markdown]
# ## Transform Data

# %%
def encode_title(raw_train, raw_test, train_labels):
    train = raw_train.copy()
    test = raw_test.copy()
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
#     activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
#     train['world'] = train['world'].map(activities_world)
#     test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    train['hour'] = train['timestamp'].dt.hour
    test['hour'] = test['timestamp'].dt.hour
    train['weekday'] = train['timestamp'].dt.weekday
    test['weekday'] = test['timestamp'].dt.weekday
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code, list_of_worlds

# %%
clip_time = {
    'Welcome to Lost Lagoon!':19,'Tree Top City - Level 1':17,'Ordering Spheres':61, 'Costume Box':61,
    '12 Monkeys':109,'Tree Top City - Level 2':25, 'Pirate\'s Tale':80, 'Treasure Map':156,'Tree Top City - Level 3':26,
    'Rulers':126, 'Magma Peak - Level 1':20, 'Slop Problem':60, 'Magma Peak - Level 2':22, 'Crystal Caves - Level 1':18,
    'Balancing Act':72, 'Lifting Heavy Things':118,'Crystal Caves - Level 2':24, 'Honey Cake':142, 'Crystal Caves - Level 3':19,
    'Heavy, Heavier, Heaviest':61
}

# %%
def parse_game_session(session):
    game_title = session['title'].iloc[-1]
    game_world = session['world'].iloc[-1]
    game_num_correct = session['event_data'].str.contains('"correct":true').astype(int).sum()
    game_num_incorrect = session['event_data'].str.contains('"correct":false').astype(int).sum()
    game_num_trial = game_num_correct + game_num_incorrect
    game_accuracy = game_num_correct/game_num_trial if game_num_trial>0 else -1
    game_num_event_count = session['event_count'].iloc[-1]
    game_session_mean = session['game_time'].diff().mean()
    game_session_std = session['game_time'].diff().std()
    
    return game_title, game_world, game_num_correct, game_num_incorrect, game_num_trial, \
            game_accuracy, game_num_event_count, game_session_mean, game_session_std

# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # 学習データとなるリスト（出力値）
    all_assessments = [] 
    
    # installation_idごとの特徴量
    # Constants and parameters declaration
    last_activity = 0
    # typeごとの回数
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    # 最後のセッションの時間
    last_session_time_sec = 0
    last_sessin_world = None
    # 直前のGame_Sessionから得られる特徴量
    last_game_title = None
    last_game_world = None
    last_game_num_correct = 0
    last_game_num_incorrect = 0
    last_game_num_trial = 0
    last_game_accuracy = 0
    last_game_num_event_count = 0
    last_game_session_mean = 0
    last_game_session_std = 0
    # Assessmentから得られる特徴量
    accuracy_groups = {0:0, 1:0, 2:0, 3:0} # accuracy_groupの回数
    accumulated_accuracy_group = 0 # 累積のaccuracy_group。最後にassessmenに挑戦した回数（counter）で割っている。
    accumulated_accuracy = 0 # 累積のaccuracy。単純に正答率を足し合わせている。
    accumulated_correct_attempts = 0 # 累積のcorrect_attempts
    accumulated_uncorrect_attempts = 0 # 累積のuncorrect_attempts
    accumulated_actions = 0 # 全てのセッションにおけるイベント回数
    counter = 0 # Assessmentに挑戦した回数
    time_first_activity = float(user_sample['timestamp'].values[0])
    accumulated_each_world_accuracy: Dict[str, int] = {f'accumulated_accuracy_of_{world}': 0 for world in list_of_worlds}
    # セッション時間の特徴量
    # each session type
    Assessment_durations = []
    clip_durations = [] # clipだけのセッション時間
    Activity_durations = [] # Activityだけのセッション時間
    Game_durations = [] # Gameだけのセッション時間
    world_durations: Dict[str, list] = {world: [] for world in list_of_worlds}
    
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles} # titleごとの最後の正答率
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    game_event_code_count: Dict[str, int] = { str(ev) + '_g': 0 for ev in list_of_event_code}
    Activity_event_code_count: Dict[str, int] = {str(ev) + '_A': 0 for ev in list_of_event_code}    
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    Activity_sum_event_count = 0
    game_sum_event_count = 0
#     game_event_id_count: Dict[str, int] = {eve+'_g': 0 for eve in list_of_event_id}
#     Activity_event_id_count: Dict[str, int] = {eve+'_A': 0 for eve in list_of_event_id}
#     Accessment_event_id_count: Dict[str, int] = {eve+'_ac': 0 for eve in list_of_event_id}
    world_count: Dict[str, int] = {world: 0 for world in list_of_worlds}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_world = session['world'].iloc[0]
        session_title = session['title'].iloc[0]
#         session_game_time = session['game_time'].iloc[-1]
        session_game_time_sec = (session.iloc[-1, 2] - session.iloc[0, 2]).seconds
        session_title_text = activities_labels[session_title]
        
        if session_type == 'Clip':
            clip_durations.append((clip_time[activities_labels[session_title]]))
        
        if session_type == 'Activity':
            Activity_sum_event_count = Activity_sum_event_count + session['event_count'].iloc[-1]
            Activity_durations.append(session_game_time_sec)
            def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = str(k) + '_A'
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            Activity_event_code_count = update_counters(Activity_event_code_count, "event_code")
#             def update_counters_id(counter: dict, col: str):
#                 num_of_session_count = Counter(session[col])
#                 for k in num_of_session_count.keys():
#                     x = k + '_g'
#                     if col == 'title':
#                         x = activities_labels[k]
#                     counter[x] += num_of_session_count[k]
#                 return counter
#             Activity_event_id_count = update_counters(Activity_event_id_count, "event_id")
        
        if session_type == 'Game':
            # Gameセッションデータを解析
            game_title, game_world, game_num_correct, game_num_incorrect, game_num_trial, \
                game_accuracy, game_num_event_count, game_session_mean, game_session_std = parse_game_session(session)
            
            last_game_title = game_title
            last_game_world = game_world
            last_game_num_correct = game_num_correct
            last_game_num_incorrect = game_num_incorrect
            last_game_num_trial = game_num_trial
            last_game_accuracy = game_accuracy
            last_game_num_event_count = game_num_event_count
            last_game_session_mean = game_session_mean
            last_game_session_std = game_session_std
            
            game_sum_event_count = game_sum_event_count + session['event_count'].iloc[-1]
            Game_durations.append(session_game_time_sec)
            def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = str(k) + '_g'
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            game_event_code_count = update_counters(game_event_code_count, "event_code")
#             def update_counters_id(counter: dict, col: str):
#                 num_of_session_count = Counter(session[col])
#                 for k in num_of_session_count.keys():
#                     x = k + '_g'
#                     if col == 'title':
#                         x = activities_labels[k]
#                     counter[x] += num_of_session_count[k]
#                 return counter
#             game_event_id_count = update_counters(game_event_id_count, "event_id")

        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            
            features.update(game_event_code_count.copy())
#             features.update(game_event_id_count.copy())
            features.update(Activity_event_code_count.copy())
#             features.update(Activity_event_id_count.copy())
#             features.update(Accessment_event_id_count.copy())
            
            features.update(world_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features['installation_session_count'] = sessions_count
            features['hour'] = session['hour'].iloc[-1]
            features['weekday'] = session['weekday'].iloc[-1]
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            features['num_of_post_words'] = sum([v>0 for v in world_count.values()])
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            features['game_sum_event_count'] = game_sum_event_count
            features['Activity_sum_event_count'] = game_sum_event_count
            features.update(accumulated_each_world_accuracy.copy())
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            # TODO: これに合計を入れるとどうなるのだろうか。
            features['Assessment_duration_mean'] = np.mean(Assessment_durations) if len(Assessment_durations)!=0 else 0.0
            features['Assessment_duration_std'] = np.std(Assessment_durations) if len(Assessment_durations)!=0 else 0.0
            features['Clip_duration_mean'] = np.mean(clip_durations) if len(clip_durations)!=0 else 0.0
            features['Clip_duration_std'] = np.std(clip_durations) if len(clip_durations)!=0 else 0.0
            features['Activity_duration_mean'] = np.mean(Activity_durations) if len(Activity_durations)!=0 else 0.0
            features['Activity_duration_std'] = np.std(Activity_durations) if len(Activity_durations)!=0 else 0.0
            features['Game_duration_mean'] = np.mean(Game_durations) if len(Game_durations)!=0 else 0.0
            features['Game_duration_std'] = np.std(Game_durations) if len(Game_durations)!=0 else 0.0
            
            # parse each world durations
            for key, val in world_durations.items():
                features[f'{key}_duration_sum'] = np.sum(val) if len(val)!=0 else 0.0
                features[f'{key}_duration_mean'] = np.mean(val) if len(val)!=0 else 0.0
                features[f'{key}_duration_std'] = np.std(val) if len(val)!=0 else 0.0
                
            # 直前のGame Sessionの特徴量を更新
            features.update({
#                 'last_game_title': last_game_title,
#                 'last_game_world': last_game_world,
                'last_game_num_correct': last_game_num_correct,
                'last_game_num_incorrect': last_game_num_incorrect,
                'last_game_num_trial': last_game_num_trial,
                'last_game_accuracy': last_game_accuracy,
                'last_game_num_event_count': last_game_num_event_count,
                'last_game_session_mean': last_game_session_mean,
                'last_game_session_std': last_game_session_std
            })
                
            Assessment_durations.append(session_game_time_sec)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            accumulated_each_world_accuracy[f'accumulated_accuracy_of_{session_world}'] += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            # last session data
            features['last_session_time_sec'] = last_session_time_sec
            features['last_sessin_world'] = last_sessin_world
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)  
            counter += 1
        
        sessions_count += 1
        # World-related features
        world_count[session_world] += 1
        world_durations[session_world].append(session_game_time_sec)
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
        
        last_session_time_sec = session_game_time_sec
        last_sessin_world = session_world
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    
    # worldに関するデータを置換
    map_of_worlds = {w: i for i, w in enumerate(sorted(list_of_worlds))}
    reduce_train['last_sessin_world'] = reduce_train['last_sessin_world'].map(map_of_worlds).fillna(-1).astype(int)
    reduce_test['last_sessin_world'] = reduce_test['last_sessin_world'].map(map_of_worlds).fillna(-1).astype(int)
#     reduce_train['last_game_world'] = reduce_train['last_game_world'].map(map_of_worlds).fillna(-1).astype(int)
#     reduce_test['last_game_world'] = reduce_test['last_game_world'].map(map_of_worlds).fillna(-1).astype(int)

    categoricals = ['session_title', 'last_sessin_world']
    return reduce_train, reduce_test, categoricals

# %%
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, \
    activities_labels, assess_titles, list_of_event_id, all_title_event_code, list_of_worlds = encode_title(raw_train, raw_test, train_labels)

# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=17000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
def stract_hists(feature, train=reduce_train, test=reduce_test, adjust=False, plot=False):
    n_bins = 10
    train_data = train[feature]
    test_data = test[feature]
    if adjust:
        test_data *= train_data.mean() / test_data.mean()
    perc_90 = np.percentile(train_data, 95)
    train_data = np.clip(train_data, 0, perc_90)
    test_data = np.clip(test_data, 0, perc_90)
    train_hist = np.histogram(train_data, bins=n_bins)[0] / len(train_data)
    test_hist = np.histogram(test_data, bins=n_bins)[0] / len(test_data)
    msre = mean_squared_error(train_hist, test_hist)
    if plot:
        print(msre)
        plt.bar(range(n_bins), train_hist, color='blue', alpha=0.5)
        plt.bar(range(n_bins), test_hist, color='red', alpha=0.5)
        plt.show()
    return msre
stract_hists('Magma Peak - Level 1_2000', adjust=False, plot=True)
# Out:
# 0.0026939774600629332
# 0.0026939774600629332

# %%
# column名をLGBMが扱える形に変更
reduce_train.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in reduce_train.columns]
reduce_test.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in reduce_test.columns]

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
# counter = 0
to_remove = []
# for feat_a in features:
#     for feat_b in features:
#         if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
#             c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
#             if c > 0.995:
#                 counter += 1
#                 to_remove.append(feat_b)
#                 print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group']+categoricals:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# acc_Cart_Balancer__Assessment_ -0.04020325710970143 -0.47065833333333335 0.006732930476733109
# eb2c19cd 0.17382702091577162 0.008 0.0
# 0ce40006 0.0008479366873940079 0.0
# a8cc6fec 0.0 0.0
# bfc77bd6 0.012832108535895986 0.0
# 01ca3a3c 0.0004522328999434709 0.0
# 7fd1ac25 0.01978518937252685 0.0
# dcb1663e 0.0 0.0
# 1b54d27f 0.0007348784624081402 0.0
# 4074bac2 0.0 0.0
# 6aeafed4 0.14703222159412097 0.008 0.0
# 2ec694de 0.008988128886376484 0.0
# 5dc079d8 0.0 0.0
# 003cd2ee 0.0 0.0
# ecc6157f 0.007292255511588468 0.0
# 13f56524 0.04392312040700961 0.0
# 119b5b02 0.0002826455624646693 0.0
# 611485c5 0.0013566986998304127 0.0
# 17ca3959 0.0 0.0
# e4d32835 0.0013001695873374789 0.0
# 29a42aea 0.004070096099491238 0.0
# ab4ec3a4 0.0009044657998869418 0.0
# 5000_g 0.0 0.0
# 5010_g 0.0 0.0
# 4021_g 0.0 0.0
# 4022_g 0.0 0.0
# 2010_g 0.0 0.0
# 2050_A 0.0 0.0
# 4100_A 0.0 0.0
# 2060_A 0.0 0.0
# 4110_A 0.0 0.0
# 2070_A 0.0 0.0
# 2075_A 0.0 0.0
# 2080_A 0.0 0.0
# 2081_A 0.0 0.0
# 2083_A 0.0 0.0
# 3120_A 0.0 0.0
# 3121_A 0.0 0.0
# 4220_A 0.0 0.0
# 4230_A 0.0 0.0
# 4235_A 0.0 0.0
# 4010_A 0.0 0.0
# 4031_A 0.0 0.0
# 4040_A 0.0 0.0
# 3020_A 0.0 0.0
# 3021_A 0.0 0.0
# 4045_A 0.0 0.0
# 4050_A 0.0 0.0
# 2010_A 0.0007348784624081402 0.0
# 2025_A 0.0 0.0
# 2035_A 0.0 0.0
# 2040_A 0.0 0.0
# 4095_A 0.0 0.0
# Bubble_Bath_4080 0.004070096099491238 0.0
# Scrub_A_Dub_4080 0.0 0.0
# Bubble_Bath_4090 0.14703222159412097 0.008 0.0
# Crystals_Rule_2010 0.0 0.0
# Dino_Dive_4080 0.0002826455624646693 0.0
# Bug_Measurer__Activity__4080 0.008988128886376484 0.0
# Watering_Hole__Activity__2010 0.0007348784624081402 0.0
# Air_Show_4080 0.0 0.0
# Bottle_Filler__Activity__2010 0.0 0.0
# Cart_Balancer__Assessment__4080 0.007292255511588468 0.0
# Dino_Drink_4080 0.0009044657998869418 0.0
# Pan_Balance_4080 0.0013001695873374789 0.0
# Happy_Camel_4080 0.0008479366873940079 0.0
# Egg_Dropper__Activity__4080 0.01978518937252685 0.0
# Chest_Sorter__Assessment__4080 0.012832108535895986 0.0
# Mushroom_Sorter__Assessment__4080 0.04392312040700961 0.0
# Pan_Balance_2010 0.0 0.0
# Fireworks__Activity__4080 0.0013566986998304127 0.0
# Sandcastle_Builder__Activity__2010 0.0 0.0
# Leaf_Leader_4080 0.0004522328999434709 0.0
# Mushroom_Sorter__Assessment__4090 0.17382702091577162 0.008 0.0
# accumulated_accuracy_of_NONE 0.0 0.0
# NONE_duration_sum 0.0 0.0
# NONE_duration_mean 0.0 0.0
# NONE_duration_std 0.0 0.0
# last_game_session_mean 1739.3879833570775 1628.043264258649
# last_game_session_std 4929.45028917171 9176.409707592102

# %%
categoricals = [x for x in categoricals if x not in (to_exclude + to_remove)]
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 943)

# %% [markdown]
# ## Training Model

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
class Base_Model(object):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True,ps={}):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
#         self.params = self.get_params()
        self.params = self.set_params(ps)
        self.oof_pred, self.y_pred, self.score, self.models = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        method = 'StratifiedKFold'
        if method=='StratifiedKFold':
            cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
            return cv.split(self.train_df, self.train_df[self.target])
        elif method=='GroupKFold':
            cv = GroupKFold(n_splits=self.n_splits)
            return cv.split(self.train_df, self.train_df[self.target], self.train_df['installation_id'])
    
    def get_params(self):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        models = []
        
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            model = self.train_model(train_set, val_set)
            models.append(model)
            
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print(f'\nOur oof cohen kappa score is: {loss_score}\n')
        return oof_pred, y_pred, loss_score, models

# %%
class Lgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set
        
    def get_params(self):
        params = {
            'n_estimators':5000,
            'boosting_type': 'gbdt',
            'objective': 'regression',
            'metric': 'rmse',
            'subsample': 0.75,
            'subsample_freq': 1,
            'min_data_in_leaf': 50,
            'learning_rate': 0.01,
            'feature_fraction': 0.9,
            'max_depth': 15,
            'lambda_l1': 1,  
            'lambda_l2': 1,
            'early_stopping_rounds': 100
        }
        return params
    def set_params(self,ps={}):
        params = self.get_params()
        if 'subsample_freq' in ps:
            params['subsample_freq']=int(ps['subsample_freq'])
            params['learning_rate']=ps['learning_rate']
            params['feature_fraction']=ps['feature_fraction']
            params['lambda_l1']=ps['lambda_l1']
            params['lambda_l2']=ps['lambda_l2']
            params['max_depth']=int(ps['max_depth'])
        
        return params    
    
    def get_feature_importance(self, models):
        feature_importance = pd.DataFrame(
            [model.feature_importance() for model in models],
            columns=models[0].feature_name()
        ).T

        feature_importance['Agerage_Importance'] = feature_importance.iloc[:, :len(models)].mean(axis=1)
        feature_importance['importance_std'] = feature_importance.iloc[:, :len(models)].std(axis=1)
        feature_importance.sort_values(by='Agerage_Importance', inplace=True)
        return feature_importance
    
    def plot_importance(self, models, max_num_features=50, figsize=(12, 15)):
        feature_importance = self.get_feature_importance(models)
        plt.figure(figsize=figsize)
        
        feature_importance[-max_num_features:].plot(
            kind='barh', title='Feature importance', figsize=figsize,
            y='Agerage_Importance', xerr='importance_std',
            grid=True, align="center"
        )
        plt.legend()
        plt.show()

# %%
class Catb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        clf = CatBoostRegressor(**self.params)
        clf.fit(train_set['X'], 
                train_set['y'], 
                eval_set=(val_set['X'], val_set['y']),
                verbose=verbosity, 
                cat_features=self.categoricals)
        return clf
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = {'X': x_train, 'y': y_train}
        val_set = {'X': x_val, 'y': y_val}
        return train_set, val_set
        
    def get_params(self):
        params = {'loss_function': 'RMSE',
                   'task_type': "CPU",
                   'iterations': 5000,
                   'od_type': "Iter",
                    'depth': 10,
                  'colsample_bylevel': 0.5, 
                   'early_stopping_rounds': 300,
                    'l2_leaf_reg': 18,
                   'random_seed': 42,
                    'use_best_model': True
                    }
        return params
    
    def set_params(self, ps={}):
        return self.get_params()

# %%
def LGB_Beyes(subsample_freq,
                    learning_rate,
                    feature_fraction,
                    max_depth,
                    lambda_l1,
                    lambda_l2):
    params={}
    params['subsample_freq']=subsample_freq
    params['learning_rate']=learning_rate
    params['feature_fraction']=feature_fraction
    params['lambda_l1']=lambda_l1
    params['lambda_l2']=lambda_l2
    params['max_depth']=max_depth
    lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals,ps=params)
    print('kappa: ',lgb_model.score)
    return lgb_model.score

bounds_LGB = {
    'subsample_freq': (1, 10),
    'learning_rate': (0.025, 0.5),
    'feature_fraction': (0.5, 1),
    'lambda_l1': (0, 5),
    'lambda_l2': (0, 5),
    'max_depth': (15, 17),
}

if os.path.exists('/kaggle/input/data-science-bowl-2019/'):
    LGB_BO = BayesianOptimization(LGB_Beyes, bounds_LGB, random_state=1029)
    import warnings
    init_points = 16
    n_iter = 16
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore')
        LGB_BO.maximize(init_points=init_points, n_iter=n_iter, acq='ucb', xi=0.0, alpha=1e-6)
        
    params = LGB_BO.max['params']
    print('\n', LGB_BO.max['params'])
else:
    params = {
        'feature_fraction': 0.5,
        'lambda_l1': 0.5, 
        'lambda_l2': 5, 
        'learning_rate': 0.03, 
        'max_depth': 16, 
        'subsample_freq': 1
    }
# Out:
# |   iter    |  target   | featur... | lambda_l1 | lambda_l2 | learni... | max_depth | subsam... |
# -------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.626489	valid_1's rmse: 1.068
# Early stopping, best iteration is:
# [8]	training's rmse: 0.944371	valid_1's rmse: 1.01152
# Partial score of fold 0 is: 0.5732413609638183
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.632133	valid_1's rmse: 1.05894
# Early stopping, best iteration is:
# [13]	training's rmse: 0.913641	valid_1's rmse: 1.004
# Partial score of fold 1 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.634342	valid_1's rmse: 1.07201
# Early stopping, best iteration is:
# [11]	training's rmse: 0.92199	valid_1's rmse: 1.01541
# Partial score of fold 2 is: 0.5635789012120558
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.631117	valid_1's rmse: 1.06908
# Early stopping, best iteration is:
# [8]	training's rmse: 0.944627	valid_1's rmse: 1.01836
# Partial score of fold 3 is: 0.5558847202986151
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.636246	valid_1's rmse: 1.06772
# Early stopping, best iteration is:
# [13]	training's rmse: 0.913695	valid_1's rmse: 1.01628
# Partial score of fold 4 is: 0.5594436541261267
#
# Our oof cohen kappa score is: 0.5677260973958106
#
# kappa:  0.5677260973958106
# |  1        |  0.5677   |  0.5123   |  2.049    |  2.944    |  0.4525   |  15.24    |  2.532    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.714023	valid_1's rmse: 1.00873
# Early stopping, best iteration is:
# [19]	training's rmse: 0.90833	valid_1's rmse: 0.999081
# Partial score of fold 0 is: 0.5709152132458014
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.717631	valid_1's rmse: 1.00768
# Early stopping, best iteration is:
# [19]	training's rmse: 0.913112	valid_1's rmse: 0.990903
# Partial score of fold 1 is: 0.5914926738282588
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.717359	valid_1's rmse: 1.01867
# Early stopping, best iteration is:
# [30]	training's rmse: 0.869878	valid_1's rmse: 0.991056
# Partial score of fold 2 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.716377	valid_1's rmse: 1.0119
# Early stopping, best iteration is:
# [22]	training's rmse: 0.899061	valid_1's rmse: 0.989814
# Partial score of fold 3 is: 0.5857667717531403
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.720107	valid_1's rmse: 1.00219
# Early stopping, best iteration is:
# [24]	training's rmse: 0.893642	valid_1's rmse: 0.99012
# Partial score of fold 4 is: 0.5845006878138547
#
# Our oof cohen kappa score is: 0.5842582804342982
#
# kappa:  0.5842582804342982
# |  2        |  0.5843   |  0.7821   |  2.977    |  1.678    |  0.2348   |  15.99    |  1.791    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.904334	valid_1's rmse: 0.994362
# [200]	training's rmse: 0.8388	valid_1's rmse: 0.989814
# [300]	training's rmse: 0.789347	valid_1's rmse: 0.989687
# [400]	training's rmse: 0.749235	valid_1's rmse: 0.991642
# Early stopping, best iteration is:
# [302]	training's rmse: 0.78846	valid_1's rmse: 0.989399
# Partial score of fold 0 is: 0.5841563617945131
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9093	valid_1's rmse: 0.984554
# [200]	training's rmse: 0.842981	valid_1's rmse: 0.97858
# [300]	training's rmse: 0.792914	valid_1's rmse: 0.980007
# Early stopping, best iteration is:
# [214]	training's rmse: 0.835259	valid_1's rmse: 0.978477
# Partial score of fold 1 is: 0.5984711169823096
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.904968	valid_1's rmse: 0.989519
# [200]	training's rmse: 0.840481	valid_1's rmse: 0.983762
# [300]	training's rmse: 0.791693	valid_1's rmse: 0.984798
# Early stopping, best iteration is:
# [248]	training's rmse: 0.815845	valid_1's rmse: 0.983006
# Partial score of fold 2 is: 0.5950713626252079
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907385	valid_1's rmse: 0.985662
# [200]	training's rmse: 0.842301	valid_1's rmse: 0.980517
# Early stopping, best iteration is:
# [175]	training's rmse: 0.855927	valid_1's rmse: 0.9801
# Partial score of fold 3 is: 0.6024076746589535
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.910649	valid_1's rmse: 0.986761
# [200]	training's rmse: 0.844916	valid_1's rmse: 0.980991
# [300]	training's rmse: 0.795665	valid_1's rmse: 0.980573
# Early stopping, best iteration is:
# [250]	training's rmse: 0.818913	valid_1's rmse: 0.979819
# Partial score of fold 4 is: 0.5921967767322283
#
# Our oof cohen kappa score is: 0.5939574889400063
#
# kappa:  0.5939574889400063
# |  3        |  0.594    |  0.5822   |  3.3      |  0.4016   |  0.04336  |  16.35    |  2.686    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.690789	valid_1's rmse: 1.0303
# Early stopping, best iteration is:
# [29]	training's rmse: 0.859604	valid_1's rmse: 1.00149
# Partial score of fold 0 is: 0.5754313600952857
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.697024	valid_1's rmse: 1.02223
# Early stopping, best iteration is:
# [14]	training's rmse: 0.927576	valid_1's rmse: 0.995124
# Partial score of fold 1 is: 0.5886297227906995
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.696506	valid_1's rmse: 1.0376
# Early stopping, best iteration is:
# [18]	training's rmse: 0.901061	valid_1's rmse: 1.00099
# Partial score of fold 2 is: 0.5777750622735316
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.695314	valid_1's rmse: 1.02345
# Early stopping, best iteration is:
# [17]	training's rmse: 0.90663	valid_1's rmse: 1.0019
# Partial score of fold 3 is: 0.5741360331630556
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.69814	valid_1's rmse: 1.02206
# Early stopping, best iteration is:
# [21]	training's rmse: 0.896042	valid_1's rmse: 0.994251
# Partial score of fold 4 is: 0.5838422456402448
#
# Our oof cohen kappa score is: 0.5789970861526041
#
# kappa:  0.5789970861526041
# |  4        |  0.579    |  0.7818   |  4.356    |  1.791    |  0.2947   |  16.76    |  5.072    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.768959	valid_1's rmse: 1.00443
# Early stopping, best iteration is:
# [48]	training's rmse: 0.856585	valid_1's rmse: 0.999144
# Partial score of fold 0 is: 0.5793251319186319
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.774369	valid_1's rmse: 0.99407
# Early stopping, best iteration is:
# [34]	training's rmse: 0.893312	valid_1's rmse: 0.985659
# Partial score of fold 1 is: 0.5913137393884114
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.77284	valid_1's rmse: 1.00226
# Early stopping, best iteration is:
# [47]	training's rmse: 0.861705	valid_1's rmse: 0.99021
# Partial score of fold 2 is: 0.5913137393884114
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769897	valid_1's rmse: 0.997758
# Early stopping, best iteration is:
# [30]	training's rmse: 0.900261	valid_1's rmse: 0.990879
# Partial score of fold 3 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.777232	valid_1's rmse: 0.995154
# Early stopping, best iteration is:
# [62]	training's rmse: 0.837056	valid_1's rmse: 0.992061
# Partial score of fold 4 is: 0.5846796666259099
#
# Our oof cohen kappa score is: 0.585725688363206
#
# kappa:  0.585725688363206
# |  5        |  0.5857   |  0.7115   |  3.981    |  4.719    |  0.1693   |  16.82    |  5.5      |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.768975	valid_1's rmse: 1.00362
# Early stopping, best iteration is:
# [59]	training's rmse: 0.837137	valid_1's rmse: 0.997796
# Partial score of fold 0 is: 0.5816512796366488
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.773592	valid_1's rmse: 0.996797
# Early stopping, best iteration is:
# [39]	training's rmse: 0.884053	valid_1's rmse: 0.990066
# Partial score of fold 1 is: 0.5857667717531403
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.776896	valid_1's rmse: 0.998401
# Early stopping, best iteration is:
# [74]	training's rmse: 0.816252	valid_1's rmse: 0.994353
# Partial score of fold 2 is: 0.5818302140764962
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.770589	valid_1's rmse: 0.997857
# Early stopping, best iteration is:
# [44]	training's rmse: 0.8682	valid_1's rmse: 0.990019
# Partial score of fold 3 is: 0.5893454605500893
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.77678	valid_1's rmse: 0.993276
# Early stopping, best iteration is:
# [84]	training's rmse: 0.801355	valid_1's rmse: 0.9923
# Partial score of fold 4 is: 0.5828898785053579
#
# Our oof cohen kappa score is: 0.58522462224114
#
# kappa:  0.58522462224114
# |  6        |  0.5852   |  0.5116   |  1.336    |  0.582    |  0.1599   |  15.98    |  7.815    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.917081	valid_1's rmse: 0.996569
# [200]	training's rmse: 0.856814	valid_1's rmse: 0.991862
# [300]	training's rmse: 0.812216	valid_1's rmse: 0.991548
# Early stopping, best iteration is:
# [270]	training's rmse: 0.82477	valid_1's rmse: 0.991323
# Partial score of fold 0 is: 0.5780725908396996
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.921952	valid_1's rmse: 0.982058
# [200]	training's rmse: 0.859891	valid_1's rmse: 0.977243
# [300]	training's rmse: 0.814473	valid_1's rmse: 0.978761
# Early stopping, best iteration is:
# [212]	training's rmse: 0.854147	valid_1's rmse: 0.976804
# Partial score of fold 1 is: 0.5997236580612417
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.919261	valid_1's rmse: 0.992042
# [200]	training's rmse: 0.859501	valid_1's rmse: 0.98333
# [300]	training's rmse: 0.814925	valid_1's rmse: 0.982835
# Early stopping, best iteration is:
# [253]	training's rmse: 0.834604	valid_1's rmse: 0.98236
# Partial score of fold 2 is: 0.5968607070236824
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.921495	valid_1's rmse: 0.988381
# [200]	training's rmse: 0.860901	valid_1's rmse: 0.979132
# [300]	training's rmse: 0.816229	valid_1's rmse: 0.98027
# Early stopping, best iteration is:
# [212]	training's rmse: 0.855027	valid_1's rmse: 0.978597
# Partial score of fold 3 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.922081	valid_1's rmse: 0.986511
# [200]	training's rmse: 0.862587	valid_1's rmse: 0.97905
# [300]	training's rmse: 0.817488	valid_1's rmse: 0.978969
# [400]	training's rmse: 0.779953	valid_1's rmse: 0.978175
# [500]	training's rmse: 0.747339	valid_1's rmse: 0.979894
# Early stopping, best iteration is:
# [400]	training's rmse: 0.779953	valid_1's rmse: 0.978175
# Partial score of fold 4 is: 0.5927337131683938
#
# Our oof cohen kappa score is: 0.594172231563749
#
# kappa:  0.594172231563749
# |  7        |  0.5942   |  0.7121   |  2.64     |  4.351    |  0.03592  |  15.62    |  2.515    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771329	valid_1's rmse: 1.00439
# Early stopping, best iteration is:
# [50]	training's rmse: 0.853412	valid_1's rmse: 0.997729
# Partial score of fold 0 is: 0.5739570987232081
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.778075	valid_1's rmse: 0.993702
# Early stopping, best iteration is:
# [39]	training's rmse: 0.886724	valid_1's rmse: 0.98948
# Partial score of fold 1 is: 0.5875561161516147
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.774757	valid_1's rmse: 0.99841
# Early stopping, best iteration is:
# [72]	training's rmse: 0.816205	valid_1's rmse: 0.990868
# Partial score of fold 2 is: 0.590419067189174
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.777925	valid_1's rmse: 0.990461
# Early stopping, best iteration is:
# [60]	training's rmse: 0.840546	valid_1's rmse: 0.985774
# Partial score of fold 3 is: 0.6000815269409366
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.782204	valid_1's rmse: 0.99274
# Early stopping, best iteration is:
# [49]	training's rmse: 0.864438	valid_1's rmse: 0.988988
# Partial score of fold 4 is: 0.5846796666259099
#
# Our oof cohen kappa score is: 0.5866920301700478
#
# kappa:  0.5866920301700478
# |  8        |  0.5867   |  0.6278   |  3.884    |  2.672    |  0.1635   |  15.94    |  7.059    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.748392	valid_1's rmse: 1.01318
# Early stopping, best iteration is:
# [26]	training's rmse: 0.899728	valid_1's rmse: 1.00701
# Partial score of fold 0 is: 0.5714520165653438
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.751311	valid_1's rmse: 1.01079
# Early stopping, best iteration is:
# [36]	training's rmse: 0.880164	valid_1's rmse: 0.996282
# Partial score of fold 1 is: 0.5880929194711572
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.75165	valid_1's rmse: 1.00784
# Early stopping, best iteration is:
# [26]	training's rmse: 0.902733	valid_1's rmse: 0.995531
# Partial score of fold 2 is: 0.5816512796366488
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.75492	valid_1's rmse: 1.0043
# Early stopping, best iteration is:
# [34]	training's rmse: 0.883966	valid_1's rmse: 0.996747
# Partial score of fold 3 is: 0.5836195584749708
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.756751	valid_1's rmse: 0.997101
# Early stopping, best iteration is:
# [28]	training's rmse: 0.903212	valid_1's rmse: 0.99215
# Partial score of fold 4 is: 0.5863315779579708
#
# Our oof cohen kappa score is: 0.582280144399035
#
# kappa:  0.582280144399035
# |  9        |  0.5823   |  0.5766   |  3.202    |  3.754    |  0.2022   |  15.32    |  9.341    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.753745	valid_1's rmse: 1.00807
# Early stopping, best iteration is:
# [28]	training's rmse: 0.898117	valid_1's rmse: 0.999671
# Partial score of fold 0 is: 0.5712730821254963
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.763397	valid_1's rmse: 0.998601
# Early stopping, best iteration is:
# [23]	training's rmse: 0.919297	valid_1's rmse: 0.988114
# Partial score of fold 1 is: 0.5988289858620044
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.760682	valid_1's rmse: 1.00201
# Early stopping, best iteration is:
# [33]	training's rmse: 0.888065	valid_1's rmse: 0.994236
# Partial score of fold 2 is: 0.5821880829561912
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.761383	valid_1's rmse: 1.00438
# Early stopping, best iteration is:
# [30]	training's rmse: 0.896167	valid_1's rmse: 0.994254
# Partial score of fold 3 is: 0.5789610243601102
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766915	valid_1's rmse: 0.991869
# Early stopping, best iteration is:
# [42]	training's rmse: 0.870576	valid_1's rmse: 0.988302
# Partial score of fold 4 is: 0.5893331157393451
#
# Our oof cohen kappa score is: 0.5847951369936548
#
# kappa:  0.5847951369936548
# |  10       |  0.5848   |  0.7996   |  0.5259   |  4.569    |  0.1726   |  15.95    |  9.381    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.607274	valid_1's rmse: 1.09941
# Early stopping, best iteration is:
# [7]	training's rmse: 0.939255	valid_1's rmse: 1.01712
# Partial score of fold 0 is: 0.5601791468549541
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.613268	valid_1's rmse: 1.07274
# Early stopping, best iteration is:
# [8]	training's rmse: 0.940004	valid_1's rmse: 1.00318
# Partial score of fold 1 is: 0.5770297742807764
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.615766	valid_1's rmse: 1.08384
# Early stopping, best iteration is:
# [6]	training's rmse: 0.950023	valid_1's rmse: 1.01125
# Partial score of fold 2 is: 0.5643547443676422
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.614668	valid_1's rmse: 1.09125
# Early stopping, best iteration is:
# [8]	training's rmse: 0.933217	valid_1's rmse: 1.0163
# Partial score of fold 3 is: 0.5657261144902253
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.619318	valid_1's rmse: 1.07337
# Early stopping, best iteration is:
# [13]	training's rmse: 0.903412	valid_1's rmse: 1.01279
# Partial score of fold 4 is: 0.563202209179286
#
# Our oof cohen kappa score is: 0.5636429885550072
#
# kappa:  0.5636429885550072
# |  11       |  0.5636   |  0.7618   |  0.2751   |  4.832    |  0.4788   |  15.14    |  5.325    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.767013	valid_1's rmse: 1.00437
# Early stopping, best iteration is:
# [52]	training's rmse: 0.849199	valid_1's rmse: 0.997768
# Partial score of fold 0 is: 0.5780725908396996
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.778742	valid_1's rmse: 0.999506
# Early stopping, best iteration is:
# [33]	training's rmse: 0.897833	valid_1's rmse: 0.990626
# Partial score of fold 1 is: 0.5895243949899367
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.775673	valid_1's rmse: 0.999235
# Early stopping, best iteration is:
# [35]	training's rmse: 0.889836	valid_1's rmse: 0.99175
# Partial score of fold 2 is: 0.5837984929148182
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.774114	valid_1's rmse: 1.00326
# Early stopping, best iteration is:
# [30]	training's rmse: 0.903295	valid_1's rmse: 0.99186
# Partial score of fold 3 is: 0.5891665261102419
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.778723	valid_1's rmse: 0.996056
# Early stopping, best iteration is:
# [72]	training's rmse: 0.822313	valid_1's rmse: 0.990717
# Partial score of fold 4 is: 0.5861114971223516
#
# Our oof cohen kappa score is: 0.5862983353598531
#
# kappa:  0.5862983353598531
# |  12       |  0.5863   |  0.653    |  1.843    |  2.172    |  0.1569   |  15.63    |  6.525    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.693871	valid_1's rmse: 1.02852
# Early stopping, best iteration is:
# [19]	training's rmse: 0.902368	valid_1's rmse: 1.00761
# Partial score of fold 0 is: 0.5691258688473269
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.695148	valid_1's rmse: 1.02037
# Early stopping, best iteration is:
# [20]	training's rmse: 0.899202	valid_1's rmse: 0.992805
# Partial score of fold 1 is: 0.5793251319186319
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.696296	valid_1's rmse: 1.0304
# Early stopping, best iteration is:
# [27]	training's rmse: 0.871984	valid_1's rmse: 1.00337
# Partial score of fold 2 is: 0.5728834920841235
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.694397	valid_1's rmse: 1.01772
# Early stopping, best iteration is:
# [23]	training's rmse: 0.889252	valid_1's rmse: 0.999473
# Partial score of fold 3 is: 0.5880929194711572
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.700902	valid_1's rmse: 1.01744
# Early stopping, best iteration is:
# [25]	training's rmse: 0.880896	valid_1's rmse: 0.998303
# Partial score of fold 4 is: 0.5755517472110947
#
# Our oof cohen kappa score is: 0.5763485937931119
#
# kappa:  0.5763485937931119
# |  13       |  0.5763   |  0.6197   |  1.488    |  3.371    |  0.2804   |  16.9     |  5.218    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.749728	valid_1's rmse: 1.00999
# Early stopping, best iteration is:
# [54]	training's rmse: 0.832524	valid_1's rmse: 1.00155
# Partial score of fold 0 is: 0.5755675086818353
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.752846	valid_1's rmse: 1.00262
# Early stopping, best iteration is:
# [39]	training's rmse: 0.870409	valid_1's rmse: 0.992442
# Partial score of fold 1 is: 0.5880929194711572
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.750995	valid_1's rmse: 1.00897
# Early stopping, best iteration is:
# [44]	training's rmse: 0.856676	valid_1's rmse: 0.996042
# Partial score of fold 2 is: 0.5780725908396996
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.748318	valid_1's rmse: 1.01123
# Early stopping, best iteration is:
# [30]	training's rmse: 0.891147	valid_1's rmse: 0.996927
# Partial score of fold 3 is: 0.5863035750726826
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.754452	valid_1's rmse: 1.0049
# Early stopping, best iteration is:
# [35]	training's rmse: 0.881302	valid_1's rmse: 0.997361
# Partial score of fold 4 is: 0.5811000903848059
#
# Our oof cohen kappa score is: 0.5815024167629347
#
# kappa:  0.5815024167629347
# |  14       |  0.5815   |  0.5761   |  0.9706   |  4.516    |  0.1912   |  16.35    |  5.414    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.773969	valid_1's rmse: 1.00275
# Early stopping, best iteration is:
# [35]	training's rmse: 0.888758	valid_1's rmse: 0.99571
# Partial score of fold 0 is: 0.5768200497607674
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.77766	valid_1's rmse: 0.996378
# Early stopping, best iteration is:
# [33]	training's rmse: 0.898484	valid_1's rmse: 0.987683
# Partial score of fold 1 is: 0.5863035750726826
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.777632	valid_1's rmse: 1.00474
# Early stopping, best iteration is:
# [38]	training's rmse: 0.884917	valid_1's rmse: 0.996479
# Partial score of fold 2 is: 0.5823670173960386
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.780145	valid_1's rmse: 0.999214
# Early stopping, best iteration is:
# [37]	training's rmse: 0.889028	valid_1's rmse: 0.989171
# Partial score of fold 3 is: 0.5929241493470384
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.781803	valid_1's rmse: 0.993709
# Early stopping, best iteration is:
# [60]	training's rmse: 0.843875	valid_1's rmse: 0.989895
# Partial score of fold 4 is: 0.585574560686186
#
# Our oof cohen kappa score is: 0.5846877656817835
#
# kappa:  0.5846877656817835
# |  15       |  0.5847   |  0.7118   |  1.536    |  0.4828   |  0.1487   |  15.64    |  7.365    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.684753	valid_1's rmse: 1.03404
# Early stopping, best iteration is:
# [13]	training's rmse: 0.928358	valid_1's rmse: 1.00766
# Partial score of fold 0 is: 0.5673601529961241
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.688106	valid_1's rmse: 1.02188
# Early stopping, best iteration is:
# [24]	training's rmse: 0.881022	valid_1's rmse: 1.00348
# Partial score of fold 1 is: 0.5814723451968014
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.693296	valid_1's rmse: 1.02095
# Early stopping, best iteration is:
# [22]	training's rmse: 0.890228	valid_1's rmse: 0.997364
# Partial score of fold 2 is: 0.5746728364825979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.689526	valid_1's rmse: 1.03576
# Early stopping, best iteration is:
# [29]	training's rmse: 0.862969	valid_1's rmse: 1.01079
# Partial score of fold 3 is: 0.5737781642833607
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.691014	valid_1's rmse: 1.02942
# Early stopping, best iteration is:
# [24]	training's rmse: 0.882386	valid_1's rmse: 1.00432
# Partial score of fold 4 is: 0.572151149782046
#
# Our oof cohen kappa score is: 0.5737716823082006
#
# kappa:  0.5737716823082006
# |  16       |  0.5738   |  0.5796   |  1.826    |  1.33     |  0.2994   |  15.89    |  7.747    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.940212	valid_1's rmse: 1.00427
# [200]	training's rmse: 0.88121	valid_1's rmse: 0.992599
# [300]	training's rmse: 0.841148	valid_1's rmse: 0.990332
# [400]	training's rmse: 0.807783	valid_1's rmse: 0.989314
# Early stopping, best iteration is:
# [350]	training's rmse: 0.82355	valid_1's rmse: 0.989014
# Partial score of fold 0 is: 0.5843352962343606
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944657	valid_1's rmse: 0.98926
# [200]	training's rmse: 0.886157	valid_1's rmse: 0.975676
# [300]	training's rmse: 0.845811	valid_1's rmse: 0.976002
# Early stopping, best iteration is:
# [246]	training's rmse: 0.866738	valid_1's rmse: 0.974716
# Partial score of fold 1 is: 0.6018708713394112
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942062	valid_1's rmse: 0.998704
# [200]	training's rmse: 0.883454	valid_1's rmse: 0.983634
# [300]	training's rmse: 0.843536	valid_1's rmse: 0.981513
# [400]	training's rmse: 0.811175	valid_1's rmse: 0.981068
# Early stopping, best iteration is:
# [355]	training's rmse: 0.825273	valid_1's rmse: 0.980589
# Partial score of fold 2 is: 0.5990079203018519
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944055	valid_1's rmse: 0.996505
# [200]	training's rmse: 0.884765	valid_1's rmse: 0.983442
# [300]	training's rmse: 0.844734	valid_1's rmse: 0.981916
# [400]	training's rmse: 0.811741	valid_1's rmse: 0.981226
# Early stopping, best iteration is:
# [352]	training's rmse: 0.827108	valid_1's rmse: 0.980951
# Partial score of fold 3 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943369	valid_1's rmse: 0.992686
# [200]	training's rmse: 0.885157	valid_1's rmse: 0.98096
# [300]	training's rmse: 0.845616	valid_1's rmse: 0.978408
# [400]	training's rmse: 0.812651	valid_1's rmse: 0.977924
# [500]	training's rmse: 0.783376	valid_1's rmse: 0.97871
# Early stopping, best iteration is:
# [403]	training's rmse: 0.811645	valid_1's rmse: 0.977911
# Partial score of fold 4 is: 0.5921967767322283
#
# Our oof cohen kappa score is: 0.5941006506891681
#
# kappa:  0.5941006506891681
# |  17       |  0.5941   |  0.8      |  3.975e-1 |  0.0      |  0.025    |  15.0     |  1.0      |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953812	valid_1's rmse: 1.0098
# [200]	training's rmse: 0.894591	valid_1's rmse: 0.991676
# [300]	training's rmse: 0.857296	valid_1's rmse: 0.988264
# [400]	training's rmse: 0.826352	valid_1's rmse: 0.987523
# Early stopping, best iteration is:
# [381]	training's rmse: 0.831895	valid_1's rmse: 0.987084
# Partial score of fold 0 is: 0.5863035750726826
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.960783	valid_1's rmse: 1.00404
# [200]	training's rmse: 0.899507	valid_1's rmse: 0.982221
# [300]	training's rmse: 0.861911	valid_1's rmse: 0.980361
# [400]	training's rmse: 0.830956	valid_1's rmse: 0.979157
# [500]	training's rmse: 0.804259	valid_1's rmse: 0.980146
# Early stopping, best iteration is:
# [400]	training's rmse: 0.830956	valid_1's rmse: 0.979157
# Partial score of fold 1 is: 0.5991868547416994
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954856	valid_1's rmse: 1.00558
# [200]	training's rmse: 0.896549	valid_1's rmse: 0.984385
# [300]	training's rmse: 0.859351	valid_1's rmse: 0.980395
# [400]	training's rmse: 0.829412	valid_1's rmse: 0.980664
# Early stopping, best iteration is:
# [361]	training's rmse: 0.840647	valid_1's rmse: 0.979931
# Partial score of fold 2 is: 0.6041970190574282
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955321	valid_1's rmse: 1.00293
# [200]	training's rmse: 0.896814	valid_1's rmse: 0.982418
# [300]	training's rmse: 0.85946	valid_1's rmse: 0.978907
# [400]	training's rmse: 0.828894	valid_1's rmse: 0.97854
# Early stopping, best iteration is:
# [368]	training's rmse: 0.838156	valid_1's rmse: 0.97842
# Partial score of fold 3 is: 0.602586609098801
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.959615	valid_1's rmse: 1.00291
# [200]	training's rmse: 0.89892	valid_1's rmse: 0.982399
# [300]	training's rmse: 0.861871	valid_1's rmse: 0.979767
# [400]	training's rmse: 0.831012	valid_1's rmse: 0.979147
# [500]	training's rmse: 0.804076	valid_1's rmse: 0.979221
# Early stopping, best iteration is:
# [441]	training's rmse: 0.819692	valid_1's rmse: 0.978721
# Partial score of fold 4 is: 0.594702480101001
#
# Our oof cohen kappa score is: 0.5965701908622081
#
# kappa:  0.5965701908622081
# |  18       |  0.5966   |  0.5403   |  4.959    |  2.081    |  0.02555  |  15.21    |  1.241    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.947181	valid_1's rmse: 1.00737
# [200]	training's rmse: 0.890977	valid_1's rmse: 0.995218
# [300]	training's rmse: 0.853939	valid_1's rmse: 0.992361
# [400]	training's rmse: 0.823532	valid_1's rmse: 0.992619
# Early stopping, best iteration is:
# [336]	training's rmse: 0.842494	valid_1's rmse: 0.992169
# Partial score of fold 0 is: 0.580577672997564
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.950105	valid_1's rmse: 0.992279
# [200]	training's rmse: 0.894812	valid_1's rmse: 0.97794
# [300]	training's rmse: 0.857573	valid_1's rmse: 0.977842
# Early stopping, best iteration is:
# [252]	training's rmse: 0.874263	valid_1's rmse: 0.976945
# Partial score of fold 1 is: 0.604912756816818
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.949885	valid_1's rmse: 1.00341
# [200]	training's rmse: 0.894933	valid_1's rmse: 0.986554
# [300]	training's rmse: 0.858073	valid_1's rmse: 0.984388
# [400]	training's rmse: 0.827354	valid_1's rmse: 0.983862
# Early stopping, best iteration is:
# [370]	training's rmse: 0.836126	valid_1's rmse: 0.983235
# Partial score of fold 2 is: 0.6009761991401739
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.950943	valid_1's rmse: 0.999553
# [200]	training's rmse: 0.895356	valid_1's rmse: 0.985246
# [300]	training's rmse: 0.85884	valid_1's rmse: 0.983264
# [400]	training's rmse: 0.828491	valid_1's rmse: 0.98312
# Early stopping, best iteration is:
# [380]	training's rmse: 0.834653	valid_1's rmse: 0.982834
# Partial score of fold 3 is: 0.5975764447830723
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.951213	valid_1's rmse: 0.995482
# [200]	training's rmse: 0.896729	valid_1's rmse: 0.982532
# [300]	training's rmse: 0.860816	valid_1's rmse: 0.980681
# [400]	training's rmse: 0.830118	valid_1's rmse: 0.98036
# Early stopping, best iteration is:
# [324]	training's rmse: 0.853238	valid_1's rmse: 0.980052
# Partial score of fold 4 is: 0.5916598402960627
#
# Our oof cohen kappa score is: 0.5951743638078811
#
# kappa:  0.5951743638078811
# |  19       |  0.5952   |  0.8      |  5.0      |  5.411e-1 |  0.025    |  17.0     |  9.917    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.949785	valid_1's rmse: 1.00718
# [200]	training's rmse: 0.894622	valid_1's rmse: 0.994271
# [300]	training's rmse: 0.858696	valid_1's rmse: 0.991501
# [400]	training's rmse: 0.828758	valid_1's rmse: 0.990901
# Early stopping, best iteration is:
# [394]	training's rmse: 0.83048	valid_1's rmse: 0.990859
# Partial score of fold 0 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952788	valid_1's rmse: 0.991949
# [200]	training's rmse: 0.898189	valid_1's rmse: 0.977875
# [300]	training's rmse: 0.861998	valid_1's rmse: 0.979238
# Early stopping, best iteration is:
# [238]	training's rmse: 0.883184	valid_1's rmse: 0.977144
# Partial score of fold 1 is: 0.6052706256965128
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.951951	valid_1's rmse: 1.00512
# [200]	training's rmse: 0.89808	valid_1's rmse: 0.988395
# [300]	training's rmse: 0.861739	valid_1's rmse: 0.985894
# [400]	training's rmse: 0.831781	valid_1's rmse: 0.986121
# Early stopping, best iteration is:
# [305]	training's rmse: 0.860109	valid_1's rmse: 0.985808
# Partial score of fold 2 is: 0.5997236580612417
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953437	valid_1's rmse: 1.00005
# [200]	training's rmse: 0.898613	valid_1's rmse: 0.985487
# [300]	training's rmse: 0.862789	valid_1's rmse: 0.983419
# Early stopping, best iteration is:
# [278]	training's rmse: 0.870029	valid_1's rmse: 0.983313
# Partial score of fold 3 is: 0.592387346027496
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952587	valid_1's rmse: 0.995736
# [200]	training's rmse: 0.899817	valid_1's rmse: 0.983011
# [300]	training's rmse: 0.86437	valid_1's rmse: 0.980724
# [400]	training's rmse: 0.834629	valid_1's rmse: 0.980384
# Early stopping, best iteration is:
# [376]	training's rmse: 0.841395	valid_1's rmse: 0.980119
# Partial score of fold 4 is: 0.5918388191081179
#
# Our oof cohen kappa score is: 0.5937069558789733
#
# kappa:  0.5937069558789733
# |  20       |  0.5937   |  0.8      |  5.0      |  5.0      |  0.025    |  17.0     |  10.0     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952885	valid_1's rmse: 1.00901
# [200]	training's rmse: 0.893951	valid_1's rmse: 0.991589
# [300]	training's rmse: 0.857061	valid_1's rmse: 0.988497
# [400]	training's rmse: 0.825996	valid_1's rmse: 0.987507
# [500]	training's rmse: 0.799279	valid_1's rmse: 0.987129
# Early stopping, best iteration is:
# [483]	training's rmse: 0.803566	valid_1's rmse: 0.986901
# Partial score of fold 0 is: 0.5875561161516147
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.958648	valid_1's rmse: 1.00077
# [200]	training's rmse: 0.898511	valid_1's rmse: 0.980112
# [300]	training's rmse: 0.861291	valid_1's rmse: 0.978946
# [400]	training's rmse: 0.830448	valid_1's rmse: 0.978824
# Early stopping, best iteration is:
# [349]	training's rmse: 0.84555	valid_1's rmse: 0.978227
# Partial score of fold 1 is: 0.6033023468581908
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953924	valid_1's rmse: 1.00466
# [200]	training's rmse: 0.89606	valid_1's rmse: 0.984006
# [300]	training's rmse: 0.858736	valid_1's rmse: 0.980752
# [400]	training's rmse: 0.828492	valid_1's rmse: 0.979487
# [500]	training's rmse: 0.801816	valid_1's rmse: 0.979379
# Early stopping, best iteration is:
# [452]	training's rmse: 0.814259	valid_1's rmse: 0.978895
# Partial score of fold 2 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953988	valid_1's rmse: 1.00255
# [200]	training's rmse: 0.896345	valid_1's rmse: 0.982641
# [300]	training's rmse: 0.859129	valid_1's rmse: 0.979552
# [400]	training's rmse: 0.828429	valid_1's rmse: 0.978011
# Early stopping, best iteration is:
# [389]	training's rmse: 0.831439	valid_1's rmse: 0.977947
# Partial score of fold 3 is: 0.6063442323355976
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.958207	valid_1's rmse: 1.00191
# [200]	training's rmse: 0.898517	valid_1's rmse: 0.982915
# [300]	training's rmse: 0.861054	valid_1's rmse: 0.979452
# [400]	training's rmse: 0.830336	valid_1's rmse: 0.9786
# [500]	training's rmse: 0.803551	valid_1's rmse: 0.978295
# [600]	training's rmse: 0.779177	valid_1's rmse: 0.978529
# Early stopping, best iteration is:
# [544]	training's rmse: 0.792532	valid_1's rmse: 0.977986
# Partial score of fold 4 is: 0.5943445224768906
#
# Our oof cohen kappa score is: 0.5972502091707264
#
# kappa:  0.5972502091707264
# |  21       |  0.5973   |  0.5607   |  4.969    |  3.045    |  0.02573  |  16.87    |  1.416    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933149	valid_1's rmse: 0.999882
# [200]	training's rmse: 0.876623	valid_1's rmse: 0.991083
# [300]	training's rmse: 0.836518	valid_1's rmse: 0.988624
# [400]	training's rmse: 0.802939	valid_1's rmse: 0.988668
# Early stopping, best iteration is:
# [341]	training's rmse: 0.822148	valid_1's rmse: 0.988221
# Partial score of fold 0 is: 0.5839774273546656
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938771	valid_1's rmse: 0.987899
# [200]	training's rmse: 0.881273	valid_1's rmse: 0.977572
# [300]	training's rmse: 0.841189	valid_1's rmse: 0.977616
# Early stopping, best iteration is:
# [240]	training's rmse: 0.864114	valid_1's rmse: 0.977041
# Partial score of fold 1 is: 0.6038391501777332
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.935346	valid_1's rmse: 0.995177
# [200]	training's rmse: 0.878846	valid_1's rmse: 0.982854
# [300]	training's rmse: 0.838758	valid_1's rmse: 0.981706
# [400]	training's rmse: 0.805212	valid_1's rmse: 0.982075
# Early stopping, best iteration is:
# [360]	training's rmse: 0.818079	valid_1's rmse: 0.981502
# Partial score of fold 2 is: 0.5997236580612417
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9363	valid_1's rmse: 0.992707
# [200]	training's rmse: 0.87932	valid_1's rmse: 0.981335
# [300]	training's rmse: 0.839215	valid_1's rmse: 0.980107
# [400]	training's rmse: 0.806249	valid_1's rmse: 0.980541
# Early stopping, best iteration is:
# [336]	training's rmse: 0.826619	valid_1's rmse: 0.979744
# Partial score of fold 3 is: 0.5981132481026146
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.937589	valid_1's rmse: 0.990696
# [200]	training's rmse: 0.881356	valid_1's rmse: 0.980076
# [300]	training's rmse: 0.841653	valid_1's rmse: 0.977695
# [400]	training's rmse: 0.808422	valid_1's rmse: 0.978586
# Early stopping, best iteration is:
# [322]	training's rmse: 0.833902	valid_1's rmse: 0.977457
# Partial score of fold 4 is: 0.5916598402960627
#
# Our oof cohen kappa score is: 0.5951743638078811
#
# kappa:  0.5951743638078811
# |  22       |  0.5952   |  0.6728   |  4.662    |  4.282    |  0.03059  |  15.03    |  1.04     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946302	valid_1's rmse: 1.00425
# [200]	training's rmse: 0.889128	valid_1's rmse: 0.991461
# [300]	training's rmse: 0.851752	valid_1's rmse: 0.989049
# [400]	training's rmse: 0.820277	valid_1's rmse: 0.988876
# Early stopping, best iteration is:
# [352]	training's rmse: 0.834643	valid_1's rmse: 0.988594
# Partial score of fold 0 is: 0.5802198041178691
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.949017	valid_1's rmse: 0.991072
# [200]	training's rmse: 0.891958	valid_1's rmse: 0.975181
# [300]	training's rmse: 0.853726	valid_1's rmse: 0.973716
# [400]	training's rmse: 0.822779	valid_1's rmse: 0.974247
# Early stopping, best iteration is:
# [327]	training's rmse: 0.844905	valid_1's rmse: 0.973567
# Partial score of fold 1 is: 0.6052706256965128
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.947894	valid_1's rmse: 1.00154
# [200]	training's rmse: 0.891555	valid_1's rmse: 0.983909
# [300]	training's rmse: 0.853642	valid_1's rmse: 0.980484
# [400]	training's rmse: 0.822332	valid_1's rmse: 0.980141
# Early stopping, best iteration is:
# [359]	training's rmse: 0.834723	valid_1's rmse: 0.979623
# Partial score of fold 2 is: 0.602586609098801
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.949777	valid_1's rmse: 0.997551
# [200]	training's rmse: 0.893082	valid_1's rmse: 0.982543
# [300]	training's rmse: 0.854975	valid_1's rmse: 0.980272
# [400]	training's rmse: 0.823399	valid_1's rmse: 0.979788
# Early stopping, best iteration is:
# [375]	training's rmse: 0.830781	valid_1's rmse: 0.979556
# Partial score of fold 3 is: 0.5968607070236824
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948722	valid_1's rmse: 0.994834
# [200]	training's rmse: 0.89326	valid_1's rmse: 0.980925
# [300]	training's rmse: 0.855419	valid_1's rmse: 0.977717
# [400]	training's rmse: 0.824008	valid_1's rmse: 0.976923
# [500]	training's rmse: 0.796393	valid_1's rmse: 0.97655
# [600]	training's rmse: 0.771689	valid_1's rmse: 0.97755
# Early stopping, best iteration is:
# [514]	training's rmse: 0.792602	valid_1's rmse: 0.976325
# Partial score of fold 4 is: 0.5959553317853874
#
# Our oof cohen kappa score is: 0.5953175255570429
#
# kappa:  0.5953175255570429
# |  23       |  0.5953   |  0.7586   |  4.19     |  0.01993  |  0.02503  |  16.99    |  1.413    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.922197	valid_1's rmse: 0.99744
# [200]	training's rmse: 0.864114	valid_1's rmse: 0.990914
# [300]	training's rmse: 0.821056	valid_1's rmse: 0.99127
# Early stopping, best iteration is:
# [253]	training's rmse: 0.84	valid_1's rmse: 0.990735
# Partial score of fold 0 is: 0.5789672630389369
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.926289	valid_1's rmse: 0.985658
# [200]	training's rmse: 0.866243	valid_1's rmse: 0.977479
# [300]	training's rmse: 0.82338	valid_1's rmse: 0.977686
# Early stopping, best iteration is:
# [230]	training's rmse: 0.852236	valid_1's rmse: 0.976905
# Partial score of fold 1 is: 0.6011551335800214
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.924167	valid_1's rmse: 0.992572
# [200]	training's rmse: 0.865656	valid_1's rmse: 0.983611
# [300]	training's rmse: 0.822593	valid_1's rmse: 0.983542
# Early stopping, best iteration is:
# [234]	training's rmse: 0.850289	valid_1's rmse: 0.983119
# Partial score of fold 2 is: 0.5977553792229198
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.926525	valid_1's rmse: 0.991384
# [200]	training's rmse: 0.86664	valid_1's rmse: 0.985053
# [300]	training's rmse: 0.823967	valid_1's rmse: 0.985027
# Early stopping, best iteration is:
# [263]	training's rmse: 0.838659	valid_1's rmse: 0.984267
# Partial score of fold 3 is: 0.5950713626252079
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.927028	valid_1's rmse: 0.987603
# [200]	training's rmse: 0.868916	valid_1's rmse: 0.981131
# Early stopping, best iteration is:
# [196]	training's rmse: 0.870809	valid_1's rmse: 0.980854
# Partial score of fold 4 is: 0.5896910733634555
#
# Our oof cohen kappa score is: 0.5932416801941975
#
# kappa:  0.5932416801941975
# |  24       |  0.5932   |  0.6503   |  4.61     |  0.003013 |  0.03493  |  15.07    |  9.829    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938676	valid_1's rmse: 1.00233
# [200]	training's rmse: 0.882069	valid_1's rmse: 0.993747
# [300]	training's rmse: 0.843428	valid_1's rmse: 0.992843
# [400]	training's rmse: 0.810859	valid_1's rmse: 0.992518
# Early stopping, best iteration is:
# [366]	training's rmse: 0.821294	valid_1's rmse: 0.992053
# Partial score of fold 0 is: 0.580577672997564
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942448	valid_1's rmse: 0.988786
# [200]	training's rmse: 0.885927	valid_1's rmse: 0.979172
# [300]	training's rmse: 0.84713	valid_1's rmse: 0.978809
# Early stopping, best iteration is:
# [248]	training's rmse: 0.866355	valid_1's rmse: 0.978211
# Partial score of fold 1 is: 0.6009761991401739
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.940289	valid_1's rmse: 0.998644
# [200]	training's rmse: 0.885069	valid_1's rmse: 0.985969
# [300]	training's rmse: 0.846636	valid_1's rmse: 0.984014
# [400]	training's rmse: 0.81417	valid_1's rmse: 0.983528
# [500]	training's rmse: 0.785868	valid_1's rmse: 0.983873
# Early stopping, best iteration is:
# [435]	training's rmse: 0.803881	valid_1's rmse: 0.983231
# Partial score of fold 2 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942231	valid_1's rmse: 0.993724
# [200]	training's rmse: 0.885756	valid_1's rmse: 0.9818
# [300]	training's rmse: 0.847399	valid_1's rmse: 0.979655
# [400]	training's rmse: 0.815173	valid_1's rmse: 0.98005
# Early stopping, best iteration is:
# [306]	training's rmse: 0.845211	valid_1's rmse: 0.979441
# Partial score of fold 3 is: 0.5920294771478012
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942086	valid_1's rmse: 0.991931
# [200]	training's rmse: 0.887207	valid_1's rmse: 0.980511
# [300]	training's rmse: 0.849015	valid_1's rmse: 0.978316
# [400]	training's rmse: 0.816745	valid_1's rmse: 0.978944
# Early stopping, best iteration is:
# [302]	training's rmse: 0.848372	valid_1's rmse: 0.978254
# Partial score of fold 4 is: 0.5911229038598971
#
# Our oof cohen kappa score is: 0.5920605957636133
#
# kappa:  0.5920605957636133
# |  25       |  0.5921   |  0.7874   |  4.919    |  0.5775   |  0.02771  |  15.06    |  3.692    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942907	valid_1's rmse: 1.00614
# [200]	training's rmse: 0.88171	valid_1's rmse: 0.991197
# [300]	training's rmse: 0.841638	valid_1's rmse: 0.989497
# [400]	training's rmse: 0.807931	valid_1's rmse: 0.988006
# Early stopping, best iteration is:
# [399]	training's rmse: 0.808216	valid_1's rmse: 0.987981
# Partial score of fold 0 is: 0.5823670173960386
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948603	valid_1's rmse: 0.996954
# [200]	training's rmse: 0.885601	valid_1's rmse: 0.978759
# [300]	training's rmse: 0.844686	valid_1's rmse: 0.97749
# Early stopping, best iteration is:
# [252]	training's rmse: 0.863338	valid_1's rmse: 0.97705
# Partial score of fold 1 is: 0.6006183302604791
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943847	valid_1's rmse: 1.00204
# [200]	training's rmse: 0.882975	valid_1's rmse: 0.984026
# [300]	training's rmse: 0.84287	valid_1's rmse: 0.981652
# [400]	training's rmse: 0.809997	valid_1's rmse: 0.982229
# Early stopping, best iteration is:
# [351]	training's rmse: 0.825508	valid_1's rmse: 0.981134
# Partial score of fold 2 is: 0.5991868547416994
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944306	valid_1's rmse: 0.999009
# [200]	training's rmse: 0.883409	valid_1's rmse: 0.982938
# [300]	training's rmse: 0.843437	valid_1's rmse: 0.982028
# Early stopping, best iteration is:
# [249]	training's rmse: 0.862493	valid_1's rmse: 0.981868
# Partial score of fold 3 is: 0.5984711169823096
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.947918	valid_1's rmse: 0.997403
# [200]	training's rmse: 0.886233	valid_1's rmse: 0.979543
# [300]	training's rmse: 0.845913	valid_1's rmse: 0.976891
# [400]	training's rmse: 0.812436	valid_1's rmse: 0.976112
# [500]	training's rmse: 0.782878	valid_1's rmse: 0.975993
# Early stopping, best iteration is:
# [456]	training's rmse: 0.795358	valid_1's rmse: 0.97564
# Partial score of fold 4 is: 0.5977451199059394
#
# Our oof cohen kappa score is: 0.5954248968689142
#
# kappa:  0.5954248968689142
# |  26       |  0.5954   |  0.5524   |  0.01528  |  2.038    |  0.02672  |  16.57    |  1.139    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.940437	valid_1's rmse: 1.00182
# [200]	training's rmse: 0.883581	valid_1's rmse: 0.991147
# [300]	training's rmse: 0.845476	valid_1's rmse: 0.988951
# [400]	training's rmse: 0.813082	valid_1's rmse: 0.988546
# [500]	training's rmse: 0.784259	valid_1's rmse: 0.988784
# Early stopping, best iteration is:
# [431]	training's rmse: 0.803746	valid_1's rmse: 0.988316
# Partial score of fold 0 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944412	valid_1's rmse: 0.98904
# [200]	training's rmse: 0.887828	valid_1's rmse: 0.976681
# [300]	training's rmse: 0.848916	valid_1's rmse: 0.976236
# Early stopping, best iteration is:
# [254]	training's rmse: 0.865645	valid_1's rmse: 0.975856
# Partial score of fold 1 is: 0.6038391501777332
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942335	valid_1's rmse: 0.998104
# [200]	training's rmse: 0.88642	valid_1's rmse: 0.983843
# [300]	training's rmse: 0.847606	valid_1's rmse: 0.982069
# [400]	training's rmse: 0.815252	valid_1's rmse: 0.981652
# [500]	training's rmse: 0.787115	valid_1's rmse: 0.982301
# Early stopping, best iteration is:
# [427]	training's rmse: 0.807408	valid_1's rmse: 0.981227
# Partial score of fold 2 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943898	valid_1's rmse: 0.994987
# [200]	training's rmse: 0.887714	valid_1's rmse: 0.981403
# [300]	training's rmse: 0.849063	valid_1's rmse: 0.978679
# [400]	training's rmse: 0.816599	valid_1's rmse: 0.977844
# Early stopping, best iteration is:
# [359]	training's rmse: 0.829229	valid_1's rmse: 0.977508
# Partial score of fold 3 is: 0.5981132481026146
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943884	valid_1's rmse: 0.992236
# [200]	training's rmse: 0.888297	valid_1's rmse: 0.98094
# [300]	training's rmse: 0.84971	valid_1's rmse: 0.978965
# [400]	training's rmse: 0.818042	valid_1's rmse: 0.978591
# [500]	training's rmse: 0.790105	valid_1's rmse: 0.978239
# Early stopping, best iteration is:
# [492]	training's rmse: 0.792253	valid_1's rmse: 0.978056
# Partial score of fold 4 is: 0.5909439250478419
#
# Our oof cohen kappa score is: 0.5955680586180759
#
# kappa:  0.5955680586180759
# |  27       |  0.5956   |  0.7342   |  4.192    |  4.383    |  0.02753  |  16.91    |  1.185    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.941714	valid_1's rmse: 1.00401
# [200]	training's rmse: 0.880973	valid_1's rmse: 0.990405
# [300]	training's rmse: 0.841447	valid_1's rmse: 0.988628
# Early stopping, best iteration is:
# [293]	training's rmse: 0.844127	valid_1's rmse: 0.98841
# Partial score of fold 0 is: 0.5823670173960386
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946021	valid_1's rmse: 0.99353
# [200]	training's rmse: 0.885568	valid_1's rmse: 0.978452
# [300]	training's rmse: 0.84591	valid_1's rmse: 0.978093
# Early stopping, best iteration is:
# [227]	training's rmse: 0.87359	valid_1's rmse: 0.977621
# Partial score of fold 1 is: 0.6024076746589535
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942708	valid_1's rmse: 1.00197
# [200]	training's rmse: 0.883917	valid_1's rmse: 0.987206
# [300]	training's rmse: 0.845579	valid_1's rmse: 0.986089
# [400]	training's rmse: 0.81203	valid_1's rmse: 0.986733
# Early stopping, best iteration is:
# [306]	training's rmse: 0.843229	valid_1's rmse: 0.985862
# Partial score of fold 2 is: 0.5939977559861231
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943864	valid_1's rmse: 0.999608
# [200]	training's rmse: 0.884266	valid_1's rmse: 0.985294
# [300]	training's rmse: 0.845173	valid_1's rmse: 0.98373
# Early stopping, best iteration is:
# [273]	training's rmse: 0.854777	valid_1's rmse: 0.983467
# Partial score of fold 3 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945343	valid_1's rmse: 0.994517
# [200]	training's rmse: 0.886691	valid_1's rmse: 0.980706
# [300]	training's rmse: 0.84741	valid_1's rmse: 0.976926
# [400]	training's rmse: 0.813997	valid_1's rmse: 0.976986
# Early stopping, best iteration is:
# [326]	training's rmse: 0.838585	valid_1's rmse: 0.976339
# Partial score of fold 4 is: 0.5961343105974426
#
# Our oof cohen kappa score is: 0.5944585550620725
#
# kappa:  0.5944585550620725
# |  28       |  0.5945   |  0.6532   |  0.1249   |  0.4304   |  0.02609  |  16.09    |  9.805    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945281	valid_1's rmse: 1.0042
# [200]	training's rmse: 0.887972	valid_1's rmse: 0.991344
# [300]	training's rmse: 0.850253	valid_1's rmse: 0.989441
# [400]	training's rmse: 0.818608	valid_1's rmse: 0.988433
# [500]	training's rmse: 0.790617	valid_1's rmse: 0.98844
# Early stopping, best iteration is:
# [453]	training's rmse: 0.803305	valid_1's rmse: 0.988153
# Partial score of fold 0 is: 0.582903820715581
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948788	valid_1's rmse: 0.991304
# [200]	training's rmse: 0.891774	valid_1's rmse: 0.976845
# [300]	training's rmse: 0.853919	valid_1's rmse: 0.975653
# [400]	training's rmse: 0.82235	valid_1's rmse: 0.97575
# Early stopping, best iteration is:
# [320]	training's rmse: 0.847181	valid_1's rmse: 0.975307
# Partial score of fold 1 is: 0.6058074290160552
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946774	valid_1's rmse: 1.00036
# [200]	training's rmse: 0.890371	valid_1's rmse: 0.984319
# [300]	training's rmse: 0.852341	valid_1's rmse: 0.981689
# [400]	training's rmse: 0.820961	valid_1's rmse: 0.981595
# [500]	training's rmse: 0.793186	valid_1's rmse: 0.981903
# Early stopping, best iteration is:
# [450]	training's rmse: 0.806783	valid_1's rmse: 0.981267
# Partial score of fold 2 is: 0.6018708713394112
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948601	valid_1's rmse: 0.996401
# [200]	training's rmse: 0.891962	valid_1's rmse: 0.981319
# [300]	training's rmse: 0.854225	valid_1's rmse: 0.97943
# [400]	training's rmse: 0.822424	valid_1's rmse: 0.979723
# Early stopping, best iteration is:
# [344]	training's rmse: 0.839537	valid_1's rmse: 0.978895
# Partial score of fold 3 is: 0.6004393958206315
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.947847	valid_1's rmse: 0.994181
# [200]	training's rmse: 0.892162	valid_1's rmse: 0.981954
# [300]	training's rmse: 0.854429	valid_1's rmse: 0.979242
# [400]	training's rmse: 0.823458	valid_1's rmse: 0.977974
# [500]	training's rmse: 0.795971	valid_1's rmse: 0.978571
# Early stopping, best iteration is:
# [414]	training's rmse: 0.819525	valid_1's rmse: 0.9777
# Partial score of fold 4 is: 0.5950604377251114
#
# Our oof cohen kappa score is: 0.5969996761096934
#
# kappa:  0.5969996761096934
# |  29       |  0.597    |  0.7357   |  4.143    |  1.725    |  0.02568  |  16.72    |  1.001    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94479	valid_1's rmse: 1.00468
# [200]	training's rmse: 0.888512	valid_1's rmse: 0.992286
# [300]	training's rmse: 0.851094	valid_1's rmse: 0.990236
# [400]	training's rmse: 0.820087	valid_1's rmse: 0.989566
# [500]	training's rmse: 0.792629	valid_1's rmse: 0.989474
# [600]	training's rmse: 0.767774	valid_1's rmse: 0.989233
# Early stopping, best iteration is:
# [525]	training's rmse: 0.786167	valid_1's rmse: 0.988894
# Partial score of fold 0 is: 0.5811144763171063
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948274	valid_1's rmse: 0.99015
# [200]	training's rmse: 0.892237	valid_1's rmse: 0.977993
# [300]	training's rmse: 0.854107	valid_1's rmse: 0.976775
# [400]	training's rmse: 0.822624	valid_1's rmse: 0.976463
# Early stopping, best iteration is:
# [376]	training's rmse: 0.829824	valid_1's rmse: 0.976194
# Partial score of fold 1 is: 0.6018708713394112
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946438	valid_1's rmse: 1.00108
# [200]	training's rmse: 0.891265	valid_1's rmse: 0.984485
# [300]	training's rmse: 0.853832	valid_1's rmse: 0.983112
# [400]	training's rmse: 0.823064	valid_1's rmse: 0.982569
# Early stopping, best iteration is:
# [362]	training's rmse: 0.834241	valid_1's rmse: 0.982523
# Partial score of fold 2 is: 0.594355624865818
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94826	valid_1's rmse: 0.996786
# [200]	training's rmse: 0.892737	valid_1's rmse: 0.982159
# [300]	training's rmse: 0.855452	valid_1's rmse: 0.979042
# [400]	training's rmse: 0.824299	valid_1's rmse: 0.979638
# Early stopping, best iteration is:
# [302]	training's rmse: 0.854805	valid_1's rmse: 0.979004
# Partial score of fold 3 is: 0.5954292315049028
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948363	valid_1's rmse: 0.99567
# [200]	training's rmse: 0.893334	valid_1's rmse: 0.982606
# [300]	training's rmse: 0.855919	valid_1's rmse: 0.980154
# [400]	training's rmse: 0.8248	valid_1's rmse: 0.980198
# [500]	training's rmse: 0.797701	valid_1's rmse: 0.98008
# [600]	training's rmse: 0.773414	valid_1's rmse: 0.980203
# Early stopping, best iteration is:
# [513]	training's rmse: 0.794403	valid_1's rmse: 0.979686
# Partial score of fold 4 is: 0.5932706496045594
#
# Our oof cohen kappa score is: 0.5923111288246463
#
# kappa:  0.5923111288246463
# |  30       |  0.5923   |  0.7755   |  4.712    |  2.986    |  0.02585  |  16.93    |  2.032    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.940994	valid_1's rmse: 1.00435
# [200]	training's rmse: 0.88081	valid_1's rmse: 0.991282
# [300]	training's rmse: 0.840978	valid_1's rmse: 0.990415
# [400]	training's rmse: 0.807685	valid_1's rmse: 0.989684
# Early stopping, best iteration is:
# [373]	training's rmse: 0.816019	valid_1's rmse: 0.989394
# Partial score of fold 0 is: 0.5850510339937505
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94706	valid_1's rmse: 0.994677
# [200]	training's rmse: 0.884706	valid_1's rmse: 0.977439
# [300]	training's rmse: 0.843901	valid_1's rmse: 0.977447
# Early stopping, best iteration is:
# [218]	training's rmse: 0.876758	valid_1's rmse: 0.976707
# Partial score of fold 1 is: 0.6036602157378858
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94178	valid_1's rmse: 0.999144
# [200]	training's rmse: 0.882444	valid_1's rmse: 0.982662
# [300]	training's rmse: 0.842635	valid_1's rmse: 0.980929
# [400]	training's rmse: 0.809742	valid_1's rmse: 0.980229
# Early stopping, best iteration is:
# [370]	training's rmse: 0.818518	valid_1's rmse: 0.979687
# Partial score of fold 2 is: 0.6020498057792587
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942085	valid_1's rmse: 0.997543
# [200]	training's rmse: 0.882207	valid_1's rmse: 0.983228
# [300]	training's rmse: 0.842364	valid_1's rmse: 0.982659
# [400]	training's rmse: 0.809074	valid_1's rmse: 0.98321
# Early stopping, best iteration is:
# [328]	training's rmse: 0.832607	valid_1's rmse: 0.982451
# Partial score of fold 3 is: 0.5993657891815468
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946346	valid_1's rmse: 0.996827
# [200]	training's rmse: 0.885692	valid_1's rmse: 0.980263
# [300]	training's rmse: 0.845354	valid_1's rmse: 0.9766
# Early stopping, best iteration is:
# [297]	training's rmse: 0.846482	valid_1's rmse: 0.976539
# Partial score of fold 4 is: 0.5936286072286698
#
# Our oof cohen kappa score is: 0.5967491430486603
#
# kappa:  0.5967491430486603
# |  31       |  0.5967   |  0.5808   |  0.2223   |  4.189    |  0.02721  |  15.16    |  1.258    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.931762	valid_1's rmse: 1.00082
# [200]	training's rmse: 0.872432	valid_1's rmse: 0.990192
# [300]	training's rmse: 0.831086	valid_1's rmse: 0.988299
# [400]	training's rmse: 0.796189	valid_1's rmse: 0.988131
# Early stopping, best iteration is:
# [340]	training's rmse: 0.816465	valid_1's rmse: 0.987705
# Partial score of fold 0 is: 0.5864825095125301
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938969	valid_1's rmse: 0.993962
# [200]	training's rmse: 0.877586	valid_1's rmse: 0.980154
# [300]	training's rmse: 0.835332	valid_1's rmse: 0.978782
# [400]	training's rmse: 0.800742	valid_1's rmse: 0.980575
# Early stopping, best iteration is:
# [305]	training's rmse: 0.833508	valid_1's rmse: 0.978601
# Partial score of fold 1 is: 0.6013340680198689
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933071	valid_1's rmse: 0.996992
# [200]	training's rmse: 0.873766	valid_1's rmse: 0.984537
# [300]	training's rmse: 0.83186	valid_1's rmse: 0.983721
# [400]	training's rmse: 0.797609	valid_1's rmse: 0.983611
# Early stopping, best iteration is:
# [354]	training's rmse: 0.812729	valid_1's rmse: 0.982998
# Partial score of fold 2 is: 0.5977553792229198
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933899	valid_1's rmse: 0.994231
# [200]	training's rmse: 0.874379	valid_1's rmse: 0.981826
# [300]	training's rmse: 0.833021	valid_1's rmse: 0.980736
# Early stopping, best iteration is:
# [244]	training's rmse: 0.854958	valid_1's rmse: 0.980165
# Partial score of fold 3 is: 0.5975764447830723
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.937411	valid_1's rmse: 0.992923
# [200]	training's rmse: 0.877124	valid_1's rmse: 0.980669
# [300]	training's rmse: 0.83511	valid_1's rmse: 0.978663
# [400]	training's rmse: 0.800073	valid_1's rmse: 0.977929
# Early stopping, best iteration is:
# [379]	training's rmse: 0.807227	valid_1's rmse: 0.977727
# Partial score of fold 4 is: 0.5943445224768906
#
# Our oof cohen kappa score is: 0.5949596211841386
#
# kappa:  0.5949596211841386
# |  32       |  0.595    |  0.526    |  3.842    |  1.024    |  0.03199  |  15.26    |  1.007    |
# =================================================================================================
#
#  {'feature_fraction': 0.5607267136232248, 'lambda_l1': 4.968730799819422, 'lambda_l2': 3.0452919554013085, 'learning_rate': 0.025728160844400758, 'max_depth': 16.871754138246526, 'subsample_freq': 1.4162785993564102}

# %%
# cat_model = Catb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals, ps=params)
# xgb_model = Xgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952885	valid_1's rmse: 1.00901
# [200]	training's rmse: 0.893951	valid_1's rmse: 0.991589
# [300]	training's rmse: 0.857061	valid_1's rmse: 0.988497
# [400]	training's rmse: 0.825996	valid_1's rmse: 0.987507
# [500]	training's rmse: 0.799279	valid_1's rmse: 0.987129
# Early stopping, best iteration is:
# [483]	training's rmse: 0.803566	valid_1's rmse: 0.986901
# Partial score of fold 0 is: 0.5875561161516147
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.958648	valid_1's rmse: 1.00077
# [200]	training's rmse: 0.898511	valid_1's rmse: 0.980112
# [300]	training's rmse: 0.861291	valid_1's rmse: 0.978946
# [400]	training's rmse: 0.830448	valid_1's rmse: 0.978824
# Early stopping, best iteration is:
# [349]	training's rmse: 0.84555	valid_1's rmse: 0.978227
# Partial score of fold 1 is: 0.6033023468581908
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953924	valid_1's rmse: 1.00466
# [200]	training's rmse: 0.89606	valid_1's rmse: 0.984006
# [300]	training's rmse: 0.858736	valid_1's rmse: 0.980752
# [400]	training's rmse: 0.828492	valid_1's rmse: 0.979487
# [500]	training's rmse: 0.801816	valid_1's rmse: 0.979379
# Early stopping, best iteration is:
# [452]	training's rmse: 0.814259	valid_1's rmse: 0.978895
# Partial score of fold 2 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953988	valid_1's rmse: 1.00255
# [200]	training's rmse: 0.896345	valid_1's rmse: 0.982641
# [300]	training's rmse: 0.859129	valid_1's rmse: 0.979552
# [400]	training's rmse: 0.828429	valid_1's rmse: 0.978011
# Early stopping, best iteration is:
# [389]	training's rmse: 0.831439	valid_1's rmse: 0.977947
# Partial score of fold 3 is: 0.6063442323355976
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.958207	valid_1's rmse: 1.00191
# [200]	training's rmse: 0.898517	valid_1's rmse: 0.982915
# [300]	training's rmse: 0.861054	valid_1's rmse: 0.979452
# [400]	training's rmse: 0.830336	valid_1's rmse: 0.9786
# [500]	training's rmse: 0.803551	valid_1's rmse: 0.978295
# [600]	training's rmse: 0.779177	valid_1's rmse: 0.978529
# Early stopping, best iteration is:
# [544]	training's rmse: 0.792532	valid_1's rmse: 0.977986
# Partial score of fold 4 is: 0.5943445224768906
#
# Our oof cohen kappa score is: 0.5972502091707264

# %%
lgb_model.plot_importance(lgb_model.models, max_num_features=80, figsize=(12, 20))

# %%
# feature_importances = cat_model.models[0].get_feature_importance()
# feature_names = features
# for score, name in sorted(zip(feature_importances, feature_names), reverse=True):
#     print('{}: {}'.format(name, score))

# %%
# fig, ax = plt.subplots(1,1, figsize=(12, 24))
# xgb.plot_importance(xgb_model.models[0], ax=ax, max_num_features=100, importance_type='weight')

# %%
# cnn_model = Cnn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# nn_model = Nn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)

# %% [markdown]
# ## Submission

# %%
weights = {'lbg': 0.70, 'cat': 0.20, 'xgb': 0.10, 'nn': 0.00}

# final_pred = (lgb_model.y_pred * weights['lbg']) + (cat_model.y_pred * weights['cat']) + (xgb_model.y_pred * weights['xgb'])
final_pred = lgb_model.y_pred
#final_pred = cnn_model.y_pred
print(final_pred.shape)
# Out:
# (1000,)

# %%
# pd.DataFrame(
#     [(round(a, 2), round(b, 2), round(c, 2), round(d, 2)) 
#          for a, b, c, d in zip(lgb_model.y_pred, cat_model.y_pred, xgb_model.y_pred, nn_model.y_pred)],
#     columns=['lgb', 'cat', 'xgb', 'nn']
# ).head(50)

# %%
# improved
import scipy as sp
from functools import partial

from sklearn.metrics import cohen_kappa_score

class OptimizedRounder(object):
    """
    An optimizer for rounding thresholds
    to maximize Quadratic Weighted Kappa (QWK) score
    # https://www.kaggle.com/naveenasaithambi/optimizedrounder-improved
    """
    def __init__(self, num_class=4):
        self.coef_ = 0
        self.initial_coef = [0.5+i for i in range(num_class-1)]
        self.labels = [i for i in range(num_class)]
    
    def _kappa_loss(self, coef, X, y):
        """
        Get loss according to
        using current coefficients
        
        :param coef: A list of coefficients that will be used for rounding
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels=self.labels)
        return -cohen_kappa_score(y, preds, weights = 'quadratic')
    
    def fit(self, X, y):
        """
        Optimize rounding thresholds
        
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        loss_partial = partial(self._kappa_loss, X = X, y = y)
        initial_coef = self.initial_coef
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method = 'nelder-mead')
    
    def predict(self, X, coef):
        """
        Make predictions with specified thresholds
        
        :param X: The raw predictions
        :param coef: A list of coefficients that will be used for rounding
        """
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels=self.labels)
        return preds
    
    def coefficients(self):
        """
        Return the optimized coefficients
        """
        return self.coef_['x']

# %%
trian_pred_reg = lgb_model.oof_pred

optR = OptimizedRounder(num_class=4)
optR.fit(trian_pred_reg, reduce_train['accuracy_group'])
coefficients = optR.coefficients()

opt_preds = optR.predict(trian_pred_reg.reshape(-1, ), coefficients)

from sklearn.metrics import mean_squared_error
rmse_score = np.sqrt(mean_squared_error(reduce_train['accuracy_group'], lgb_model.oof_pred))
print(f'\nrmse_score is {rmse_score}\n')

off_score = cohen_kappa_score(reduce_train['accuracy_group'], opt_preds, weights='quadratic')
print(f'\noff_score is {off_score}\n')

sample_submission['accuracy_group'] = optR.predict(final_pred.reshape(-1, ), coefficients).astype(int)
sample_submission.to_csv('submission.csv', index=False)
display(sample_submission['accuracy_group'].value_counts(normalize=True).sort_index())
sample_submission['accuracy_group'].hist()
# Out:
# rmse_score is 0.979997569525652
#
#
# off_score is 0.6026086449981174
# 0    0.174
# 1    0.137
# 2    0.235
# 3    0.454
# Name: accuracy_group, dtype: float64

# %%
from sklearn.model_selection import train_test_split


smpl_scores = []
valid_scores = []
for i in range(100):
    _trian, _smpl_train, _pred, _smpl_pred = train_test_split(\
        reduce_train['accuracy_group'], opt_preds, test_size=0.14, random_state=42+i)
    
    smpl_scores.append(cohen_kappa_score(_smpl_train, _smpl_pred, weights='quadratic'))
    valid_scores.append(cohen_kappa_score(_trian, _pred, weights='quadratic'))

pd.DataFrame({'smpl': smpl_scores, 'valid': valid_scores}).describe().round(3)
# Out:
#           smpl    valid
# count  100.000  100.000
# mean     0.601    0.603
# std      0.014    0.002
# min      0.571    0.597
# 25%      0.591    0.601
# 50%      0.601    0.603
# 75%      0.612    0.605
# max      0.637    0.608
