# %%
import os
import gc
import re
import json
import copy
import time
import eli5
import datetime
from numba import jit

from IPython.display import HTML
import altair as alt
from category_encoders.ordinal import OrdinalEncoder
from typing import List, Any

import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats

import random
random.seed(28)
np.random.seed(28)

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import lightgbm as lgb

import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance

import catboost as cat
from catboost import CatBoostRegressor, CatBoostClassifier

from bayes_opt import BayesianOptimization
import shap

from itertools import product
from functools import partial

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn import linear_model
from sklearn.svm import NuSVR, SVR
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import cohen_kappa_score, mean_squared_error, mean_absolute_error


# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from collections import defaultdict
from joblib import Parallel, delayed

pd.set_option('display.max_columns', 1000)
pd.set_option('max_rows', 500)
pd.options.display.precision = 15
np.random.seed(566)

import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/rui/.local/share/virtualenvs/data_science_bowl-_c7OiX6v/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/rui/.local/share/virtualenvs/data_science_bowl-_c7OiX6v/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Objective
#
# - 特徴量の追加
# - 主に、worldに関する特徴量を追加する。
# - cv scoreに関する詳細はnoteに書き残す。

# %% [markdown]
# # Notes
#
# - CV score with added features
#     - baseline：0.5933490515060689
#     - world count：0.5928479853840027
#     - last_session_time_sec, last_sessin_world：0.5942796028756203
#     - world_count and duration：0.5901637025872202
#     - accumulated_each_world_accuracy, nunique post world：0.593026937570455

# %% [markdown]
# ## Load Data

# %%
def read_data():
    if os.path.exists('/kaggle/input/data-science-bowl-2019/'):
        data_dir_path = '/kaggle/input/data-science-bowl-2019/'
    else:
        data_dir_path = '../data/raw/'
        
    
    print('Reading train.csv file....')
    train = pd.read_csv(data_dir_path+'train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv(data_dir_path+'test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv(data_dir_path+'train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv(data_dir_path+'specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv(data_dir_path+'sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
raw_train, raw_test, train_labels, specs, sample_submission = read_data()
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns

# %%
print(raw_train.shape)
raw_train.head()
# Out:
# (11341042, 11)
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %% [markdown]
# ## Transform Data

# %%
def encode_title(raw_train, raw_test, train_labels):
    train = raw_train.copy()
    test = raw_test.copy()
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
#     activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
#     train['world'] = train['world'].map(activities_world)
#     test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    train['hour'] = train['timestamp'].dt.hour
    test['hour'] = test['timestamp'].dt.hour
    train['weekday'] = train['timestamp'].dt.weekday
    test['weekday'] = test['timestamp'].dt.weekday
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code, list_of_worlds

# %%
clip_time = {
    'Welcome to Lost Lagoon!':19,'Tree Top City - Level 1':17,'Ordering Spheres':61, 'Costume Box':61,
    '12 Monkeys':109,'Tree Top City - Level 2':25, 'Pirate\'s Tale':80, 'Treasure Map':156,'Tree Top City - Level 3':26,
    'Rulers':126, 'Magma Peak - Level 1':20, 'Slop Problem':60, 'Magma Peak - Level 2':22, 'Crystal Caves - Level 1':18,
    'Balancing Act':72, 'Lifting Heavy Things':118,'Crystal Caves - Level 2':24, 'Honey Cake':142, 'Crystal Caves - Level 3':19,
    'Heavy, Heavier, Heaviest':61
}

# %%
# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # 学習データとなるリスト（出力値）
    all_assessments = [] 
    
    # installation_idごとの特徴量
    # Constants and parameters declaration
    last_activity = 0
    # typeごとの回数
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    # 最後のセッションの時間
    last_session_time_sec = 0
    last_sessin_world = None
    # Assessmentから得られる特徴量
    accuracy_groups = {0:0, 1:0, 2:0, 3:0} # accuracy_groupの回数
    accumulated_accuracy_group = 0 # 累積のaccuracy_group。最後にassessmenに挑戦した回数（counter）で割っている。
    accumulated_accuracy = 0 # 累積のaccuracy。単純に正答率を足し合わせている。
    accumulated_correct_attempts = 0 # 累積のcorrect_attempts
    accumulated_uncorrect_attempts = 0 # 累積のuncorrect_attempts
    accumulated_actions = 0 # 全てのセッションにおけるイベント回数
    counter = 0 # Assessmentに挑戦した回数
    time_first_activity = float(user_sample['timestamp'].values[0])
    accumulated_each_world_accuracy: Dict[str, int] = {f'accumulated_accuracy_of_{world}': 0 for world in list_of_worlds}
    # セッション時間の特徴量
    # each session type
    Assessment_durations = []
    clip_durations = [] # clipだけのセッション時間
    Activity_durations = [] # Activityだけのセッション時間
    Game_durations = [] # Gameだけのセッション時間
    world_durations: Dict[str, list] = {world: [] for world in list_of_worlds}
    
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles} # titleごとの最後の正答率
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    game_event_code_count: Dict[str, int] = { str(ev) + '_g': 0 for ev in list_of_event_code}
    Activity_event_code_count: Dict[str, int] = {str(ev) + '_A': 0 for ev in list_of_event_code}    
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    Activity_sum_event_count = 0
    game_sum_event_count = 0
#     game_event_id_count: Dict[str, int] = {eve+'_g': 0 for eve in list_of_event_id}
#     Activity_event_id_count: Dict[str, int] = {eve+'_A': 0 for eve in list_of_event_id}
#     Accessment_event_id_count: Dict[str, int] = {eve+'_ac': 0 for eve in list_of_event_id}
    world_count: Dict[str, int] = {world: 0 for world in list_of_worlds}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_world = session['world'].iloc[0]
        session_title = session['title'].iloc[0]
#         session_game_time = session['game_time'].iloc[-1]
        session_game_time_sec = (session.iloc[-1, 2] - session.iloc[0, 2]).seconds
        session_title_text = activities_labels[session_title]
        
        if session_type == 'Clip':
            clip_durations.append((clip_time[activities_labels[session_title]]))
        
        if session_type == 'Activity':
            Activity_sum_event_count = Activity_sum_event_count + session['event_count'].iloc[-1]
            Activity_durations.append(session_game_time_sec)
            def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = str(k) + '_A'
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            Activity_event_code_count = update_counters(Activity_event_code_count, "event_code")
#             def update_counters_id(counter: dict, col: str):
#                 num_of_session_count = Counter(session[col])
#                 for k in num_of_session_count.keys():
#                     x = k + '_g'
#                     if col == 'title':
#                         x = activities_labels[k]
#                     counter[x] += num_of_session_count[k]
#                 return counter
#             Activity_event_id_count = update_counters(Activity_event_id_count, "event_id")
        
        if session_type == 'Game':
            game_sum_event_count = game_sum_event_count + session['event_count'].iloc[-1]
            Game_durations.append(session_game_time_sec)
            def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = str(k) + '_g'
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            game_event_code_count = update_counters(game_event_code_count, "event_code")
#             def update_counters_id(counter: dict, col: str):
#                 num_of_session_count = Counter(session[col])
#                 for k in num_of_session_count.keys():
#                     x = k + '_g'
#                     if col == 'title':
#                         x = activities_labels[k]
#                     counter[x] += num_of_session_count[k]
#                 return counter
#             game_event_id_count = update_counters(game_event_id_count, "event_id")

        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            
            features.update(game_event_code_count.copy())
#             features.update(game_event_id_count.copy())
            features.update(Activity_event_code_count.copy())
#             features.update(Activity_event_id_count.copy())
#             features.update(Accessment_event_id_count.copy())
            
            features.update(world_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features['installation_session_count'] = sessions_count
            features['hour'] = session['hour'].iloc[-1]
            features['weekday'] = session['weekday'].iloc[-1]
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            features['num_of_post_words'] = sum([v>0 for v in world_count.values()])
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            features['game_sum_event_count'] = game_sum_event_count
            features['Activity_sum_event_count'] = game_sum_event_count
            features.update(accumulated_each_world_accuracy.copy())
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            # TODO: これに合計を入れるとどうなるのだろうか。
            features['Assessment_duration_mean'] = np.mean(Assessment_durations) if len(Assessment_durations)!=0 else 0.0
            features['Assessment_duration_std'] = np.std(Assessment_durations) if len(Assessment_durations)!=0 else 0.0
            features['Clip_duration_mean'] = np.mean(clip_durations) if len(clip_durations)!=0 else 0.0
            features['Clip_duration_std'] = np.std(clip_durations) if len(clip_durations)!=0 else 0.0
            features['Activity_duration_mean'] = np.mean(Activity_durations) if len(Activity_durations)!=0 else 0.0
            features['Activity_duration_std'] = np.std(Activity_durations) if len(Activity_durations)!=0 else 0.0
            features['Game_duration_mean'] = np.mean(Game_durations) if len(Game_durations)!=0 else 0.0
            features['Game_duration_std'] = np.std(Game_durations) if len(Game_durations)!=0 else 0.0
            
            # parse each world durations
            for key, val in world_durations.items():
                features[f'{key}_duration_sum'] = np.sum(val) if len(val)!=0 else 0.0
                features[f'{key}_duration_mean'] = np.mean(val) if len(val)!=0 else 0.0
                features[f'{key}_duration_std'] = np.std(val) if len(val)!=0 else 0.0
                
            Assessment_durations.append(session_game_time_sec)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            accumulated_each_world_accuracy[f'accumulated_accuracy_of_{session_world}'] += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            # last session data
            features['last_session_time_sec'] = last_session_time_sec
            features['last_sessin_world'] = last_sessin_world
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)  
            counter += 1
        
        sessions_count += 1
        # World-related features
        world_count[session_world] += 1
        world_durations[session_world].append(session_game_time_sec)
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
        
        last_session_time_sec = session_game_time_sec
        last_sessin_world = session_world
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    
    map_of_worlds = {w: i for i, w in enumerate(sorted(list_of_worlds))}
    reduce_train['last_sessin_world'] = reduce_train['last_sessin_world'].map(map_of_worlds).fillna(-1).astype(int)
    reduce_test['last_sessin_world'] = reduce_test['last_sessin_world'].map(map_of_worlds).fillna(-1).astype(int)

    categoricals = ['session_title', 'last_sessin_world']
    return reduce_train, reduce_test, categoricals

# %%
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, \
    activities_labels, assess_titles, list_of_event_id, all_title_event_code, list_of_worlds = encode_title(raw_train, raw_test, train_labels)

# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=17000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
def stract_hists(feature, train=reduce_train, test=reduce_test, adjust=False, plot=False):
    n_bins = 10
    train_data = train[feature]
    test_data = test[feature]
    if adjust:
        test_data *= train_data.mean() / test_data.mean()
    perc_90 = np.percentile(train_data, 95)
    train_data = np.clip(train_data, 0, perc_90)
    test_data = np.clip(test_data, 0, perc_90)
    train_hist = np.histogram(train_data, bins=n_bins)[0] / len(train_data)
    test_hist = np.histogram(test_data, bins=n_bins)[0] / len(test_data)
    msre = mean_squared_error(train_hist, test_hist)
    if plot:
        print(msre)
        plt.bar(range(n_bins), train_hist, color='blue', alpha=0.5)
        plt.bar(range(n_bins), test_hist, color='red', alpha=0.5)
        plt.show()
    return msre
stract_hists('Magma Peak - Level 1_2000', adjust=False, plot=True)
# Out:
# 0.0026939774600629332
# 0.0026939774600629332

# %%
# column名をLGBMが扱える形に変更
reduce_train.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in reduce_train.columns]
reduce_test.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in reduce_test.columns]

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
# counter = 0
to_remove = []
# for feat_a in features:
#     for feat_b in features:
#         if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
#             c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
#             if c > 0.995:
#                 counter += 1
#                 to_remove.append(feat_b)
#                 print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group']+categoricals:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# acc_Cart_Balancer__Assessment_ -0.04020325710970143 -0.47065833333333335 0.006732930476733109
# 01ca3a3c 0.0004522328999434709 0.0
# 6aeafed4 0.14703222159412097 0.008 0.0
# 17ca3959 0.0 0.0
# ab4ec3a4 0.0009044657998869418 0.0
# 0ce40006 0.0008479366873940079 0.0
# 2ec694de 0.008988128886376484 0.0
# 13f56524 0.04392312040700961 0.0
# 119b5b02 0.0002826455624646693 0.0
# 5dc079d8 0.0 0.0
# e4d32835 0.0013001695873374789 0.0
# eb2c19cd 0.17382702091577162 0.008 0.0
# 003cd2ee 0.0 0.0
# 29a42aea 0.004070096099491238 0.0
# 1b54d27f 0.0007348784624081402 0.0
# a8cc6fec 0.0 0.0
# dcb1663e 0.0 0.0
# 4074bac2 0.0 0.0
# 611485c5 0.0013566986998304127 0.0
# ecc6157f 0.007292255511588468 0.0
# bfc77bd6 0.012832108535895986 0.0
# 7fd1ac25 0.01978518937252685 0.0
# 5000_g 0.0 0.0
# 5010_g 0.0 0.0
# 4021_g 0.0 0.0
# 4022_g 0.0 0.0
# 2010_g 0.0 0.0
# 2050_A 0.0 0.0
# 4100_A 0.0 0.0
# 2060_A 0.0 0.0
# 4110_A 0.0 0.0
# 2070_A 0.0 0.0
# 2075_A 0.0 0.0
# 2080_A 0.0 0.0
# 2081_A 0.0 0.0
# 2083_A 0.0 0.0
# 3120_A 0.0 0.0
# 3121_A 0.0 0.0
# 4220_A 0.0 0.0
# 4230_A 0.0 0.0
# 4235_A 0.0 0.0
# 4010_A 0.0 0.0
# 4031_A 0.0 0.0
# 4040_A 0.0 0.0
# 3020_A 0.0 0.0
# 3021_A 0.0 0.0
# 4045_A 0.0 0.0
# 4050_A 0.0 0.0
# 2010_A 0.0007348784624081402 0.0
# 2025_A 0.0 0.0
# 2035_A 0.0 0.0
# 2040_A 0.0 0.0
# 4095_A 0.0 0.0
# Dino_Drink_4080 0.0009044657998869418 0.0
# Pan_Balance_2010 0.0 0.0
# Fireworks__Activity__4080 0.0013566986998304127 0.0
# Crystals_Rule_2010 0.0 0.0
# Pan_Balance_4080 0.0013001695873374789 0.0
# Scrub_A_Dub_4080 0.0 0.0
# Chest_Sorter__Assessment__4080 0.012832108535895986 0.0
# Mushroom_Sorter__Assessment__4090 0.17382702091577162 0.008 0.0
# Happy_Camel_4080 0.0008479366873940079 0.0
# Cart_Balancer__Assessment__4080 0.007292255511588468 0.0
# Bubble_Bath_4080 0.004070096099491238 0.0
# Egg_Dropper__Activity__4080 0.01978518937252685 0.0
# Sandcastle_Builder__Activity__2010 0.0 0.0
# Leaf_Leader_4080 0.0004522328999434709 0.0
# Dino_Dive_4080 0.0002826455624646693 0.0
# Air_Show_4080 0.0 0.0
# Bug_Measurer__Activity__4080 0.008988128886376484 0.0
# Mushroom_Sorter__Assessment__4080 0.04392312040700961 0.0
# Bubble_Bath_4090 0.14703222159412097 0.008 0.0
# Watering_Hole__Activity__2010 0.0007348784624081402 0.0
# Bottle_Filler__Activity__2010 0.0 0.0
# accumulated_accuracy_of_NONE 0.0 0.0
# NONE_duration_sum 0.0 0.0
# NONE_duration_mean 0.0 0.0
# NONE_duration_std 0.0 0.0

# %%
categoricals = [x for x in categoricals if x not in (to_exclude + to_remove)]
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 938)

# %% [markdown]
# ## Training Model

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
class Base_Model(object):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True,ps={}):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
#         self.params = self.get_params()
        self.params = self.set_params(ps)
        self.oof_pred, self.y_pred, self.score, self.models = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        method = 'StratifiedKFold'
        if method=='StratifiedKFold':
            cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
            return cv.split(self.train_df, self.train_df[self.target])
        elif method=='GroupKFold':
            cv = GroupKFold(n_splits=self.n_splits)
            return cv.split(self.train_df, self.train_df[self.target], self.train_df['installation_id'])
    
    def get_params(self):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        models = []
        
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            model = self.train_model(train_set, val_set)
            models.append(model)
            
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print(f'\nOur oof cohen kappa score is: {loss_score}\n')
        return oof_pred, y_pred, loss_score, models

# %%
class Lgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set
        
    def get_params(self):
        params = {'n_estimators':5000,
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': 'rmse',
                    'subsample': 0.75,
                    'subsample_freq': 1,
                    'learning_rate': 0.01,
                    'feature_fraction': 0.9,
                    'max_depth': 15,
                    'lambda_l1': 1,  
                    'lambda_l2': 1,
                    'early_stopping_rounds': 100
                    }
        return params
    def set_params(self,ps={}):
        params = self.get_params()
        if 'subsample_freq' in ps:
            params['subsample_freq']=int(ps['subsample_freq'])
            params['learning_rate']=ps['learning_rate']
            params['feature_fraction']=ps['feature_fraction']
            params['lambda_l1']=ps['lambda_l1']
            params['lambda_l2']=ps['lambda_l2']
            params['max_depth']=int(ps['max_depth'])
        
        return params    
    
    def get_feature_importance(self, models):
        feature_importance = pd.DataFrame(
            [model.feature_importance() for model in models],
            columns=models[0].feature_name()
        ).T

        feature_importance['Agerage_Importance'] = feature_importance.iloc[:, :len(models)].mean(axis=1)
        feature_importance['importance_std'] = feature_importance.iloc[:, :len(models)].std(axis=1)

        feature_importance.sort_values(by='Agerage_Importance', inplace=True)
        return feature_importance
    
    def plot_importance(self, models, max_num_features=50, figsize=(12, 15)):
        feature_importance = self.get_feature_importance(models)
        plt.figure(figsize=figsize)
        
        feature_importance[-max_num_features:].plot(
            kind='barh', title='Feature importance', figsize=figsize,
            y='Agerage_Importance', xerr='importance_std',
            grid=True, align="center"
        )
        plt.legend()
        plt.show()

# %%
class Xgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set, 
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')], 
                         verbose_eval=verbosity, early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self):
        params = {'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000}
        return params
    
    def set_params(self, ps={}):
        return self.get_params()

# %%
class fuse_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set, 
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')], 
                         verbose_eval=verbosity, early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self):
        params = {'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000}
        return params
    
    def set_params(self, ps={}):
        return self.get_params()

# %%
def LGB_Beyes(subsample_freq,
                    learning_rate,
                    feature_fraction,
                    max_depth,
                    lambda_l1,
                    lambda_l2):
    params={}
    params['subsample_freq']=subsample_freq
    params['learning_rate']=learning_rate
    params['feature_fraction']=feature_fraction
    params['lambda_l1']=lambda_l1
    params['lambda_l2']=lambda_l2
    params['max_depth']=max_depth
    lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals,ps=params)
    print('kappa: ',lgb_model.score)
    return lgb_model.score

bounds_LGB = {
    'subsample_freq': (1, 10),
    'learning_rate': (0.025, 0.5),
    'feature_fraction': (0.5, 1),
    'lambda_l1': (0, 5),
    'lambda_l2': (0, 5),
    'max_depth': (15, 17),
}

LGB_BO = BayesianOptimization(LGB_Beyes, bounds_LGB, random_state=1029)
import warnings
init_points = 16
n_iter = 16
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    LGB_BO.maximize(init_points=init_points, n_iter=n_iter, acq='ucb', xi=0.0, alpha=1e-6)
    
print('\n', LGB_BO.max['params'])
# Out:
# |   iter    |  target   | featur... | lambda_l1 | lambda_l2 | learni... | max_depth | subsam... |
# -------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.615726	valid_1's rmse: 1.0834
# Early stopping, best iteration is:
# [7]	training's rmse: 0.951171	valid_1's rmse: 1.02446
# Partial score of fold 0 is: 0.5437740747377939
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.622753	valid_1's rmse: 1.06403
# Early stopping, best iteration is:
# [11]	training's rmse: 0.918071	valid_1's rmse: 1.00448
# Partial score of fold 1 is: 0.5837984929148182
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.616421	valid_1's rmse: 1.0715
# Early stopping, best iteration is:
# [9]	training's rmse: 0.93064	valid_1's rmse: 1.01206
# Partial score of fold 2 is: 0.5662629178097676
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.620144	valid_1's rmse: 1.06255
# Early stopping, best iteration is:
# [11]	training's rmse: 0.921679	valid_1's rmse: 1.00876
# Partial score of fold 3 is: 0.5693048032871744
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.621409	valid_1's rmse: 1.06132
# Early stopping, best iteration is:
# [14]	training's rmse: 0.897758	valid_1's rmse: 1.00766
# Partial score of fold 4 is: 0.5700034040373836
#
# Our oof cohen kappa score is: 0.5662914809144994
#
# kappa:  0.5662914809144994
# |  1        |  0.5663   |  0.5205   |  2.049    |  2.944    |  0.4525   |  15.24    |  2.532    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.704026	valid_1's rmse: 1.02099
# Early stopping, best iteration is:
# [17]	training's rmse: 0.913267	valid_1's rmse: 1.00441
# Partial score of fold 0 is: 0.5719888198848861
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.707131	valid_1's rmse: 1.01144
# Early stopping, best iteration is:
# [21]	training's rmse: 0.900707	valid_1's rmse: 0.992525
# Partial score of fold 1 is: 0.5796830007983267
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.704675	valid_1's rmse: 1.01728
# Early stopping, best iteration is:
# [24]	training's rmse: 0.889338	valid_1's rmse: 0.997519
# Partial score of fold 2 is: 0.5718098854450386
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.706836	valid_1's rmse: 1.01585
# Early stopping, best iteration is:
# [20]	training's rmse: 0.904353	valid_1's rmse: 0.993944
# Partial score of fold 3 is: 0.5840211576571093
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.707166	valid_1's rmse: 1.00793
# Early stopping, best iteration is:
# [21]	training's rmse: 0.897992	valid_1's rmse: 0.992198
# Partial score of fold 4 is: 0.5830688573174131
#
# Our oof cohen kappa score is: 0.5772433547253728
#
# kappa:  0.5772433547253728
# |  2        |  0.5772   |  0.9701   |  2.977    |  1.678    |  0.2348   |  15.99    |  1.791    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.904129	valid_1's rmse: 0.995813
# [200]	training's rmse: 0.836163	valid_1's rmse: 0.991494
# [300]	training's rmse: 0.785101	valid_1's rmse: 0.992631
# Early stopping, best iteration is:
# [222]	training's rmse: 0.823576	valid_1's rmse: 0.990472
# Partial score of fold 0 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907808	valid_1's rmse: 0.985441
# [200]	training's rmse: 0.839761	valid_1's rmse: 0.982358
# Early stopping, best iteration is:
# [169]	training's rmse: 0.85807	valid_1's rmse: 0.98195
# Partial score of fold 1 is: 0.5977553792229198
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.903546	valid_1's rmse: 0.987693
# [200]	training's rmse: 0.836329	valid_1's rmse: 0.980331
# [300]	training's rmse: 0.786077	valid_1's rmse: 0.981238
# Early stopping, best iteration is:
# [219]	training's rmse: 0.825772	valid_1's rmse: 0.980045
# Partial score of fold 2 is: 0.598650051422157
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.905975	valid_1's rmse: 0.985117
# [200]	training's rmse: 0.839064	valid_1's rmse: 0.980721
# Early stopping, best iteration is:
# [189]	training's rmse: 0.845148	valid_1's rmse: 0.98037
# Partial score of fold 3 is: 0.5988289858620044
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907468	valid_1's rmse: 0.988266
# [200]	training's rmse: 0.840737	valid_1's rmse: 0.982298
# [300]	training's rmse: 0.789768	valid_1's rmse: 0.98149
# Early stopping, best iteration is:
# [288]	training's rmse: 0.795287	valid_1's rmse: 0.980912
# Partial score of fold 4 is: 0.5906304561527063
#
# Our oof cohen kappa score is: 0.5941006506891681
#
# kappa:  0.5941006506891681
# |  3        |  0.5941   |  0.6371   |  3.3      |  0.4016   |  0.04336  |  16.35    |  2.686    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.682368	valid_1's rmse: 1.02947
# Early stopping, best iteration is:
# [32]	training's rmse: 0.845409	valid_1's rmse: 1.00799
# Partial score of fold 0 is: 0.5685890655277845
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.688352	valid_1's rmse: 1.01829
# Early stopping, best iteration is:
# [12]	training's rmse: 0.928579	valid_1's rmse: 0.996604
# Partial score of fold 1 is: 0.5778936563998522
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.687818	valid_1's rmse: 1.02956
# Early stopping, best iteration is:
# [18]	training's rmse: 0.901487	valid_1's rmse: 1.00169
# Partial score of fold 2 is: 0.5761043120013776
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.682645	valid_1's rmse: 1.02813
# Early stopping, best iteration is:
# [16]	training's rmse: 0.909832	valid_1's rmse: 0.999493
# Partial score of fold 3 is: 0.589926643480863
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.691544	valid_1's rmse: 1.02681
# Early stopping, best iteration is:
# [11]	training's rmse: 0.936623	valid_1's rmse: 1.00508
# Partial score of fold 4 is: 0.569687632965066
#
# Our oof cohen kappa score is: 0.5757759467964649
#
# kappa:  0.5757759467964649
# |  4        |  0.5758   |  0.9697   |  4.356    |  1.791    |  0.2947   |  16.76    |  5.072    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766431	valid_1's rmse: 1.00412
# Early stopping, best iteration is:
# [34]	training's rmse: 0.886837	valid_1's rmse: 0.998688
# Partial score of fold 0 is: 0.5712730821254963
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769794	valid_1's rmse: 1.0002
# Early stopping, best iteration is:
# [26]	training's rmse: 0.912462	valid_1's rmse: 0.988152
# Partial score of fold 1 is: 0.5893454605500893
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.770392	valid_1's rmse: 0.993867
# Early stopping, best iteration is:
# [45]	training's rmse: 0.865478	valid_1's rmse: 0.988745
# Partial score of fold 2 is: 0.5888086572305469
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.770747	valid_1's rmse: 0.995926
# Early stopping, best iteration is:
# [38]	training's rmse: 0.882233	valid_1's rmse: 0.992749
# Partial score of fold 3 is: 0.5905980016290215
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771925	valid_1's rmse: 0.999711
# Early stopping, best iteration is:
# [50]	training's rmse: 0.853598	valid_1's rmse: 0.991232
# Partial score of fold 4 is: 0.5798472387004194
#
# Our oof cohen kappa score is: 0.5842582804342982
#
# kappa:  0.5842582804342982
# |  5        |  0.5843   |  0.8525   |  3.981    |  4.719    |  0.1693   |  16.82    |  5.5      |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.758806	valid_1's rmse: 1.00899
# Early stopping, best iteration is:
# [33]	training's rmse: 0.891701	valid_1's rmse: 1.00195
# Partial score of fold 0 is: 0.5771779186404624
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.764423	valid_1's rmse: 1.00059
# Early stopping, best iteration is:
# [39]	training's rmse: 0.878881	valid_1's rmse: 0.994494
# Partial score of fold 1 is: 0.5852299684335979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.762175	valid_1's rmse: 1.00368
# Early stopping, best iteration is:
# [40]	training's rmse: 0.876081	valid_1's rmse: 0.998758
# Partial score of fold 2 is: 0.5768200497607674
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.767648	valid_1's rmse: 1.00465
# Early stopping, best iteration is:
# [42]	training's rmse: 0.87412	valid_1's rmse: 0.995894
# Partial score of fold 3 is: 0.58710745211376
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.764901	valid_1's rmse: 0.998418
# Early stopping, best iteration is:
# [86]	training's rmse: 0.788413	valid_1's rmse: 0.997456
# Partial score of fold 4 is: 0.5798472387004194
#
# Our oof cohen kappa score is: 0.5810013506408686
#
# kappa:  0.5810013506408686
# |  6        |  0.581    |  0.5194   |  1.336    |  0.582    |  0.1599   |  15.98    |  7.815    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.917985	valid_1's rmse: 0.99766
# [200]	training's rmse: 0.856209	valid_1's rmse: 0.991588
# [300]	training's rmse: 0.810465	valid_1's rmse: 0.991712
# Early stopping, best iteration is:
# [222]	training's rmse: 0.845155	valid_1's rmse: 0.991036
# Partial score of fold 0 is: 0.5791893965285835
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.919947	valid_1's rmse: 0.983079
# [200]	training's rmse: 0.858343	valid_1's rmse: 0.978538
# [300]	training's rmse: 0.812554	valid_1's rmse: 0.97936
# Early stopping, best iteration is:
# [210]	training's rmse: 0.853259	valid_1's rmse: 0.977913
# Partial score of fold 1 is: 0.5990079203018519
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.91817	valid_1's rmse: 0.991106
# [200]	training's rmse: 0.856666	valid_1's rmse: 0.981834
# [300]	training's rmse: 0.81104	valid_1's rmse: 0.981408
# [400]	training's rmse: 0.7721	valid_1's rmse: 0.982152
# Early stopping, best iteration is:
# [362]	training's rmse: 0.78638	valid_1's rmse: 0.980763
# Partial score of fold 2 is: 0.5965028381439875
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.920908	valid_1's rmse: 0.989073
# [200]	training's rmse: 0.858704	valid_1's rmse: 0.980929
# [300]	training's rmse: 0.813468	valid_1's rmse: 0.980408
# Early stopping, best iteration is:
# [236]	training's rmse: 0.841338	valid_1's rmse: 0.980099
# Partial score of fold 3 is: 0.5999025925010892
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.919518	valid_1's rmse: 0.990017
# [200]	training's rmse: 0.858811	valid_1's rmse: 0.982673
# [300]	training's rmse: 0.814141	valid_1's rmse: 0.982007
# Early stopping, best iteration is:
# [248]	training's rmse: 0.836151	valid_1's rmse: 0.981595
# Partial score of fold 4 is: 0.5886172004911243
#
# Our oof cohen kappa score is: 0.5933132610687785
#
# kappa:  0.5933132610687785
# |  7        |  0.5933   |  0.8534   |  2.64     |  4.351    |  0.03592  |  15.62    |  2.515    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.76976	valid_1's rmse: 1.00773
# Early stopping, best iteration is:
# [34]	training's rmse: 0.89106	valid_1's rmse: 0.999161
# Partial score of fold 0 is: 0.5746728364825979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.773648	valid_1's rmse: 1.00012
# Early stopping, best iteration is:
# [37]	training's rmse: 0.888215	valid_1's rmse: 0.993595
# Partial score of fold 1 is: 0.5830827551554284
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.774003	valid_1's rmse: 0.998302
# Early stopping, best iteration is:
# [47]	training's rmse: 0.865095	valid_1's rmse: 0.995003
# Partial score of fold 2 is: 0.5737781642833607
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.775735	valid_1's rmse: 0.993602
# Early stopping, best iteration is:
# [41]	training's rmse: 0.878164	valid_1's rmse: 0.990672
# Partial score of fold 3 is: 0.5852299684335979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.775893	valid_1's rmse: 1.00027
# Early stopping, best iteration is:
# [47]	training's rmse: 0.866429	valid_1's rmse: 0.9956
# Partial score of fold 4 is: 0.5811000903848059
#
# Our oof cohen kappa score is: 0.5802139610204791
#
# kappa:  0.5802139610204791
# |  8        |  0.5802   |  0.713    |  3.884    |  2.672    |  0.1635   |  15.94    |  7.059    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.740385	valid_1's rmse: 1.01782
# Early stopping, best iteration is:
# [38]	training's rmse: 0.86345	valid_1's rmse: 1.00724
# Partial score of fold 0 is: 0.5685890655277845
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.748015	valid_1's rmse: 1.00595
# Early stopping, best iteration is:
# [24]	training's rmse: 0.907604	valid_1's rmse: 0.992661
# Partial score of fold 1 is: 0.5864825095125301
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.751162	valid_1's rmse: 1.00354
# Early stopping, best iteration is:
# [36]	training's rmse: 0.875052	valid_1's rmse: 0.995427
# Partial score of fold 2 is: 0.5807566074374115
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.7488	valid_1's rmse: 1.0104
# Early stopping, best iteration is:
# [24]	training's rmse: 0.909451	valid_1's rmse: 0.997585
# Partial score of fold 3 is: 0.5861215511567069
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.749582	valid_1's rmse: 1.00112
# Early stopping, best iteration is:
# [38]	training's rmse: 0.8664	valid_1's rmse: 0.999209
# Partial score of fold 4 is: 0.5764466412713707
#
# Our oof cohen kappa score is: 0.5808223984544164
#
# kappa:  0.5808223984544164
# |  9        |  0.5808   |  0.6277   |  3.202    |  3.754    |  0.2022   |  15.32    |  9.341    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.749164	valid_1's rmse: 1.00814
# Early stopping, best iteration is:
# [28]	training's rmse: 0.892879	valid_1's rmse: 1.00265
# Partial score of fold 0 is: 0.5701994754864116
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.752771	valid_1's rmse: 1.00695
# Early stopping, best iteration is:
# [30]	training's rmse: 0.893558	valid_1's rmse: 0.989518
# Partial score of fold 1 is: 0.5893454605500893
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.755774	valid_1's rmse: 1.01441
# Early stopping, best iteration is:
# [28]	training's rmse: 0.897384	valid_1's rmse: 0.999008
# Partial score of fold 2 is: 0.5775357875201572
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.753867	valid_1's rmse: 1.00413
# Early stopping, best iteration is:
# [33]	training's rmse: 0.885246	valid_1's rmse: 0.990319
# Partial score of fold 3 is: 0.5832616895952758
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.756606	valid_1's rmse: 0.998064
# Early stopping, best iteration is:
# [44]	training's rmse: 0.857819	valid_1's rmse: 0.991769
# Partial score of fold 4 is: 0.5825319208812475
#
# Our oof cohen kappa score is: 0.5808223984544164
#
# kappa:  0.5808223984544164
# |  10       |  0.5808   |  0.9993   |  0.5259   |  4.569    |  0.1726   |  15.95    |  9.381    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.593132	valid_1's rmse: 1.08406
# Early stopping, best iteration is:
# [9]	training's rmse: 0.923692	valid_1's rmse: 1.01381
# Partial score of fold 0 is: 0.5663047001858483
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.601984	valid_1's rmse: 1.07849
# Early stopping, best iteration is:
# [7]	training's rmse: 0.944461	valid_1's rmse: 1.00955
# Partial score of fold 1 is: 0.5657261144902253
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.594313	valid_1's rmse: 1.08792
# Early stopping, best iteration is:
# [8]	training's rmse: 0.933848	valid_1's rmse: 1.01476
# Partial score of fold 2 is: 0.5533796381407508
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.594473	valid_1's rmse: 1.08083
# Early stopping, best iteration is:
# [8]	training's rmse: 0.934204	valid_1's rmse: 1.01074
# Partial score of fold 3 is: 0.5730788010844845
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.600566	valid_1's rmse: 1.07815
# Early stopping, best iteration is:
# [11]	training's rmse: 0.912171	valid_1's rmse: 1.01153
# Partial score of fold 4 is: 0.5601595693743475
#
# Our oof cohen kappa score is: 0.5644303781753968
#
# kappa:  0.5644303781753968
# |  11       |  0.5644   |  0.9364   |  0.2751   |  4.832    |  0.4788   |  15.14    |  5.325    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.759936	valid_1's rmse: 1.00169
# Early stopping, best iteration is:
# [36]	training's rmse: 0.881618	valid_1's rmse: 0.997838
# Partial score of fold 0 is: 0.5730624265239709
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769671	valid_1's rmse: 0.999535
# Early stopping, best iteration is:
# [33]	training's rmse: 0.895135	valid_1's rmse: 0.990009
# Partial score of fold 1 is: 0.5900611983094791
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.76892	valid_1's rmse: 1.00298
# Early stopping, best iteration is:
# [36]	training's rmse: 0.888697	valid_1's rmse: 0.997218
# Partial score of fold 2 is: 0.5780725908396996
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.768638	valid_1's rmse: 0.998699
# Early stopping, best iteration is:
# [30]	training's rmse: 0.90412	valid_1's rmse: 0.994656
# Partial score of fold 3 is: 0.5843352962343606
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771965	valid_1's rmse: 0.998883
# Early stopping, best iteration is:
# [42]	training's rmse: 0.873665	valid_1's rmse: 0.992656
# Partial score of fold 4 is: 0.5853955818741308
#
# Our oof cohen kappa score is: 0.5807508175798355
#
# kappa:  0.5807508175798355
# |  12       |  0.5808   |  0.755    |  1.843    |  2.172    |  0.1569   |  15.63    |  6.525    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.683194	valid_1's rmse: 1.02915
# Early stopping, best iteration is:
# [26]	training's rmse: 0.866116	valid_1's rmse: 1.00314
# Partial score of fold 0 is: 0.5714520165653438
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.690643	valid_1's rmse: 1.01924
# Early stopping, best iteration is:
# [20]	training's rmse: 0.898164	valid_1's rmse: 0.997764
# Partial score of fold 1 is: 0.5879139850313098
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.689917	valid_1's rmse: 1.02634
# Early stopping, best iteration is:
# [21]	training's rmse: 0.890074	valid_1's rmse: 0.997285
# Partial score of fold 2 is: 0.5770419471381276
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.682043	valid_1's rmse: 1.0206
# Early stopping, best iteration is:
# [14]	training's rmse: 0.922943	valid_1's rmse: 0.998895
# Partial score of fold 3 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.691988	valid_1's rmse: 1.02472
# Early stopping, best iteration is:
# [14]	training's rmse: 0.922344	valid_1's rmse: 1.00036
# Partial score of fold 4 is: 0.5719721709699908
#
# Our oof cohen kappa score is: 0.5777802112847293
#
# kappa:  0.5777802112847293
# |  13       |  0.5778   |  0.6994   |  1.488    |  3.371    |  0.2804   |  16.9     |  5.218    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.741397	valid_1's rmse: 1.0148
# Early stopping, best iteration is:
# [31]	training's rmse: 0.884858	valid_1's rmse: 1.00112
# Partial score of fold 0 is: 0.5729685222121506
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.745297	valid_1's rmse: 1.01007
# Early stopping, best iteration is:
# [37]	training's rmse: 0.870619	valid_1's rmse: 0.993917
# Partial score of fold 1 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.74391	valid_1's rmse: 1.00551
# Early stopping, best iteration is:
# [22]	training's rmse: 0.915044	valid_1's rmse: 0.996489
# Partial score of fold 2 is: 0.5834406240351233
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.744875	valid_1's rmse: 1.01042
# Early stopping, best iteration is:
# [38]	training's rmse: 0.870592	valid_1's rmse: 1.0007
# Partial score of fold 3 is: 0.5821880829561912
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.744016	valid_1's rmse: 1.00759
# Early stopping, best iteration is:
# [33]	training's rmse: 0.881915	valid_1's rmse: 0.995559
# Partial score of fold 4 is: 0.5778784717678123
#
# Our oof cohen kappa score is: 0.579873369765433
#
# kappa:  0.579873369765433
# |  14       |  0.5799   |  0.6269   |  0.9706   |  4.516    |  0.1912   |  16.35    |  5.414    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.765992	valid_1's rmse: 1.00528
# Early stopping, best iteration is:
# [33]	training's rmse: 0.891302	valid_1's rmse: 0.998702
# Partial score of fold 0 is: 0.5741360331630556
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766023	valid_1's rmse: 0.997402
# Early stopping, best iteration is:
# [58]	training's rmse: 0.839396	valid_1's rmse: 0.990353
# Partial score of fold 1 is: 0.5852299684335979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771105	valid_1's rmse: 1.00127
# Early stopping, best iteration is:
# [44]	training's rmse: 0.871576	valid_1's rmse: 0.995381
# Partial score of fold 2 is: 0.5779367177174843
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771987	valid_1's rmse: 1.00081
# Early stopping, best iteration is:
# [37]	training's rmse: 0.886192	valid_1's rmse: 0.99267
# Partial score of fold 3 is: 0.5870193128320724
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771436	valid_1's rmse: 0.996823
# Early stopping, best iteration is:
# [48]	training's rmse: 0.860952	valid_1's rmse: 0.990791
# Partial score of fold 4 is: 0.5868274123705723
#
# Our oof cohen kappa score is: 0.5813234645764824
#
# kappa:  0.5813234645764824
# |  15       |  0.5813   |  0.853    |  1.536    |  0.4828   |  0.1487   |  15.64    |  7.365    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.666323	valid_1's rmse: 1.03234
# Early stopping, best iteration is:
# [16]	training's rmse: 0.90489	valid_1's rmse: 1.00503
# Partial score of fold 0 is: 0.5719888198848861
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.670849	valid_1's rmse: 1.02939
# Early stopping, best iteration is:
# [14]	training's rmse: 0.92256	valid_1's rmse: 0.999852
# Partial score of fold 1 is: 0.5789672630389369
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.672959	valid_1's rmse: 1.0319
# Early stopping, best iteration is:
# [19]	training's rmse: 0.897258	valid_1's rmse: 1.00407
# Partial score of fold 2 is: 0.5648314422909879
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.680898	valid_1's rmse: 1.03024
# Early stopping, best iteration is:
# [29]	training's rmse: 0.857618	valid_1's rmse: 1.00262
# Partial score of fold 3 is: 0.5812934107569538
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.680229	valid_1's rmse: 1.02985
# Early stopping, best iteration is:
# [15]	training's rmse: 0.916204	valid_1's rmse: 1.00722
# Partial score of fold 4 is: 0.5666028066083347
#
# Our oof cohen kappa score is: 0.5727337596267779
#
# kappa:  0.5727337596267779
# |  16       |  0.5727   |  0.6327   |  1.826    |  1.33     |  0.2994   |  15.89    |  7.747    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943383	valid_1's rmse: 1.00954
# [200]	training's rmse: 0.879198	valid_1's rmse: 0.996003
# [300]	training's rmse: 0.836231	valid_1's rmse: 0.993622
# [400]	training's rmse: 0.800486	valid_1's rmse: 0.992642
# Early stopping, best iteration is:
# [385]	training's rmse: 0.805669	valid_1's rmse: 0.992404
# Partial score of fold 0 is: 0.5855878373132928
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945847	valid_1's rmse: 0.998417
# [200]	training's rmse: 0.88117	valid_1's rmse: 0.983475
# [300]	training's rmse: 0.837548	valid_1's rmse: 0.983444
# Early stopping, best iteration is:
# [257]	training's rmse: 0.855058	valid_1's rmse: 0.982729
# Partial score of fold 1 is: 0.5981132481026146
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944407	valid_1's rmse: 1.00182
# [200]	training's rmse: 0.880437	valid_1's rmse: 0.985323
# [300]	training's rmse: 0.837921	valid_1's rmse: 0.982844
# [400]	training's rmse: 0.802615	valid_1's rmse: 0.982499
# Early stopping, best iteration is:
# [308]	training's rmse: 0.835014	valid_1's rmse: 0.9824
# Partial score of fold 2 is: 0.5938188215462756
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945703	valid_1's rmse: 1.00095
# [200]	training's rmse: 0.881572	valid_1's rmse: 0.982305
# [300]	training's rmse: 0.838521	valid_1's rmse: 0.980855
# [400]	training's rmse: 0.80245	valid_1's rmse: 0.980168
# Early stopping, best iteration is:
# [380]	training's rmse: 0.809177	valid_1's rmse: 0.97993
# Partial score of fold 3 is: 0.6040180846175807
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945622	valid_1's rmse: 1.00091
# [200]	training's rmse: 0.882156	valid_1's rmse: 0.985745
# [300]	training's rmse: 0.839638	valid_1's rmse: 0.981245
# [400]	training's rmse: 0.804212	valid_1's rmse: 0.980007
# [500]	training's rmse: 0.772858	valid_1's rmse: 0.978913
# Early stopping, best iteration is:
# [497]	training's rmse: 0.773646	valid_1's rmse: 0.978784
# Partial score of fold 4 is: 0.5895120945514003
#
# Our oof cohen kappa score is: 0.5933132610687785
#
# kappa:  0.5933132610687785
# |  17       |  0.5933   |  0.6332   |  0.0591   |  0.4395   |  0.026    |  16.9     |  1.44     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.947692	valid_1's rmse: 1.01015
# [200]	training's rmse: 0.891033	valid_1's rmse: 0.99801
# [300]	training's rmse: 0.852547	valid_1's rmse: 0.996453
# [400]	training's rmse: 0.821541	valid_1's rmse: 0.994807
# [500]	training's rmse: 0.794004	valid_1's rmse: 0.994677
# Early stopping, best iteration is:
# [483]	training's rmse: 0.798597	valid_1's rmse: 0.994347
# Partial score of fold 0 is: 0.5836195584749708
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94968	valid_1's rmse: 0.992747
# [200]	training's rmse: 0.893935	valid_1's rmse: 0.981224
# [300]	training's rmse: 0.855644	valid_1's rmse: 0.980095
# [400]	training's rmse: 0.824918	valid_1's rmse: 0.980459
# Early stopping, best iteration is:
# [329]	training's rmse: 0.84585	valid_1's rmse: 0.979627
# Partial score of fold 1 is: 0.5991868547416994
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.948056	valid_1's rmse: 1.00509
# [200]	training's rmse: 0.892582	valid_1's rmse: 0.988114
# [300]	training's rmse: 0.854436	valid_1's rmse: 0.987334
# Early stopping, best iteration is:
# [251]	training's rmse: 0.871802	valid_1's rmse: 0.986786
# Partial score of fold 2 is: 0.5854089028734453
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.950781	valid_1's rmse: 0.996755
# [200]	training's rmse: 0.894484	valid_1's rmse: 0.983031
# [300]	training's rmse: 0.856603	valid_1's rmse: 0.980772
# [400]	training's rmse: 0.824902	valid_1's rmse: 0.981626
# Early stopping, best iteration is:
# [332]	training's rmse: 0.845826	valid_1's rmse: 0.980194
# Partial score of fold 3 is: 0.6009761991401739
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94961	valid_1's rmse: 0.998614
# [200]	training's rmse: 0.894174	valid_1's rmse: 0.987213
# [300]	training's rmse: 0.85561	valid_1's rmse: 0.982838
# [400]	training's rmse: 0.824498	valid_1's rmse: 0.980457
# [500]	training's rmse: 0.796377	valid_1's rmse: 0.980845
# Early stopping, best iteration is:
# [429]	training's rmse: 0.815918	valid_1's rmse: 0.980294
# Partial score of fold 4 is: 0.5880802640549587
#
# Our oof cohen kappa score is: 0.5913805774550949
#
# kappa:  0.5913805774550949
# |  18       |  0.5914   |  1.0      |  4.781    |  0.0      |  0.025    |  17.0     |  10.0     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942847	valid_1's rmse: 1.00708
# [200]	training's rmse: 0.882246	valid_1's rmse: 0.993331
# [300]	training's rmse: 0.842212	valid_1's rmse: 0.991805
# [400]	training's rmse: 0.809489	valid_1's rmse: 0.991493
# Early stopping, best iteration is:
# [398]	training's rmse: 0.81003	valid_1's rmse: 0.991343
# Partial score of fold 0 is: 0.5823670173960386
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944886	valid_1's rmse: 0.995622
# [200]	training's rmse: 0.885178	valid_1's rmse: 0.98205
# [300]	training's rmse: 0.845204	valid_1's rmse: 0.980315
# [400]	training's rmse: 0.812628	valid_1's rmse: 0.981499
# Early stopping, best iteration is:
# [305]	training's rmse: 0.843278	valid_1's rmse: 0.980062
# Partial score of fold 1 is: 0.5963239037041401
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944727	valid_1's rmse: 1.00188
# [200]	training's rmse: 0.884411	valid_1's rmse: 0.985557
# [300]	training's rmse: 0.844303	valid_1's rmse: 0.983885
# [400]	training's rmse: 0.811558	valid_1's rmse: 0.983933
# Early stopping, best iteration is:
# [359]	training's rmse: 0.824438	valid_1's rmse: 0.983396
# Partial score of fold 2 is: 0.5965028381439875
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946123	valid_1's rmse: 1.00048
# [200]	training's rmse: 0.885604	valid_1's rmse: 0.981716
# [300]	training's rmse: 0.846037	valid_1's rmse: 0.98003
# [400]	training's rmse: 0.812648	valid_1's rmse: 0.97939
# Early stopping, best iteration is:
# [339]	training's rmse: 0.832458	valid_1's rmse: 0.978973
# Partial score of fold 3 is: 0.5999025925010892
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944733	valid_1's rmse: 1.00188
# [200]	training's rmse: 0.886384	valid_1's rmse: 0.987228
# [300]	training's rmse: 0.846298	valid_1's rmse: 0.984549
# [400]	training's rmse: 0.813795	valid_1's rmse: 0.983396
# [500]	training's rmse: 0.785593	valid_1's rmse: 0.982599
# [600]	training's rmse: 0.760202	valid_1's rmse: 0.983216
# Early stopping, best iteration is:
# [501]	training's rmse: 0.785311	valid_1's rmse: 0.982519
# Partial score of fold 4 is: 0.5913018826719523
#
# Our oof cohen kappa score is: 0.5924542905738079
#
# kappa:  0.5924542905738079
# |  19       |  0.5925   |  0.5485   |  4.944    |  3.679    |  0.02972  |  16.97    |  1.173    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.923372	valid_1's rmse: 0.999188
# [200]	training's rmse: 0.861533	valid_1's rmse: 0.991513
# [300]	training's rmse: 0.816313	valid_1's rmse: 0.989884
# [400]	training's rmse: 0.777776	valid_1's rmse: 0.990289
# Early stopping, best iteration is:
# [306]	training's rmse: 0.813774	valid_1's rmse: 0.989533
# Partial score of fold 0 is: 0.5837984929148182
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.925895	valid_1's rmse: 0.989714
# [200]	training's rmse: 0.863324	valid_1's rmse: 0.982906
# [300]	training's rmse: 0.818042	valid_1's rmse: 0.983184
# Early stopping, best iteration is:
# [230]	training's rmse: 0.848652	valid_1's rmse: 0.982236
# Partial score of fold 1 is: 0.5963239037041401
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.924603	valid_1's rmse: 0.993076
# [200]	training's rmse: 0.863168	valid_1's rmse: 0.983326
# [300]	training's rmse: 0.817884	valid_1's rmse: 0.983614
# Early stopping, best iteration is:
# [270]	training's rmse: 0.830117	valid_1's rmse: 0.983033
# Partial score of fold 2 is: 0.592745214907191
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.925945	valid_1's rmse: 0.989366
# [200]	training's rmse: 0.863511	valid_1's rmse: 0.980614
# [300]	training's rmse: 0.818637	valid_1's rmse: 0.980446
# Early stopping, best iteration is:
# [275]	training's rmse: 0.828903	valid_1's rmse: 0.979716
# Partial score of fold 3 is: 0.598650051422157
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.925255	valid_1's rmse: 0.993429
# [200]	training's rmse: 0.863954	valid_1's rmse: 0.984867
# [300]	training's rmse: 0.819368	valid_1's rmse: 0.982014
# [400]	training's rmse: 0.782161	valid_1's rmse: 0.981871
# Early stopping, best iteration is:
# [376]	training's rmse: 0.79061	valid_1's rmse: 0.981506
# Partial score of fold 4 is: 0.5893331157393451
#
# Our oof cohen kappa score is: 0.5926690331975506
#
# kappa:  0.5926690331975506
# |  20       |  0.5927   |  0.6984   |  0.4427   |  4.971    |  0.03291  |  16.9     |  1.038    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938514	valid_1's rmse: 1.00353
# [200]	training's rmse: 0.882687	valid_1's rmse: 0.994086
# [300]	training's rmse: 0.844044	valid_1's rmse: 0.993688
# Early stopping, best iteration is:
# [214]	training's rmse: 0.876233	valid_1's rmse: 0.993461
# Partial score of fold 0 is: 0.5775357875201572
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942415	valid_1's rmse: 0.990634
# [200]	training's rmse: 0.88624	valid_1's rmse: 0.981286
# [300]	training's rmse: 0.84664	valid_1's rmse: 0.981384
# Early stopping, best iteration is:
# [247]	training's rmse: 0.866426	valid_1's rmse: 0.98049
# Partial score of fold 1 is: 0.598650051422157
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.941787	valid_1's rmse: 1.00053
# [200]	training's rmse: 0.88634	valid_1's rmse: 0.986992
# [300]	training's rmse: 0.847618	valid_1's rmse: 0.984131
# [400]	training's rmse: 0.815342	valid_1's rmse: 0.984875
# Early stopping, best iteration is:
# [327]	training's rmse: 0.838433	valid_1's rmse: 0.98326
# Partial score of fold 2 is: 0.5965028381439875
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943934	valid_1's rmse: 0.994949
# [200]	training's rmse: 0.887641	valid_1's rmse: 0.983896
# [300]	training's rmse: 0.849394	valid_1's rmse: 0.982179
# [400]	training's rmse: 0.817738	valid_1's rmse: 0.982134
# Early stopping, best iteration is:
# [306]	training's rmse: 0.847408	valid_1's rmse: 0.981777
# Partial score of fold 3 is: 0.5972185759033773
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942233	valid_1's rmse: 0.99527
# [200]	training's rmse: 0.887374	valid_1's rmse: 0.985499
# [300]	training's rmse: 0.84897	valid_1's rmse: 0.983495
# [400]	training's rmse: 0.816702	valid_1's rmse: 0.983356
# Early stopping, best iteration is:
# [378]	training's rmse: 0.823719	valid_1's rmse: 0.98277
# Partial score of fold 4 is: 0.5913018826719523
#
# Our oof cohen kappa score is: 0.5920963862009037
#
# kappa:  0.5920963862009037
# |  21       |  0.5921   |  0.8788   |  4.82     |  4.888    |  0.02876  |  16.89    |  9.953    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.903939	valid_1's rmse: 0.996636
# [200]	training's rmse: 0.837873	valid_1's rmse: 0.991592
# [300]	training's rmse: 0.789761	valid_1's rmse: 0.991379
# Early stopping, best iteration is:
# [272]	training's rmse: 0.801912	valid_1's rmse: 0.990474
# Partial score of fold 0 is: 0.584872099553903
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.905851	valid_1's rmse: 0.982239
# [200]	training's rmse: 0.841078	valid_1's rmse: 0.981146
# Early stopping, best iteration is:
# [173]	training's rmse: 0.856025	valid_1's rmse: 0.979679
# Partial score of fold 1 is: 0.5975764447830723
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.906309	valid_1's rmse: 0.99062
# [200]	training's rmse: 0.841717	valid_1's rmse: 0.984784
# [300]	training's rmse: 0.792972	valid_1's rmse: 0.985714
# Early stopping, best iteration is:
# [217]	training's rmse: 0.832603	valid_1's rmse: 0.984534
# Partial score of fold 2 is: 0.5909558705087163
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.906144	valid_1's rmse: 0.986221
# [200]	training's rmse: 0.84132	valid_1's rmse: 0.982617
# [300]	training's rmse: 0.792599	valid_1's rmse: 0.983337
# Early stopping, best iteration is:
# [236]	training's rmse: 0.8226	valid_1's rmse: 0.982159
# Partial score of fold 3 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.906639	valid_1's rmse: 0.988116
# [200]	training's rmse: 0.842314	valid_1's rmse: 0.982557
# [300]	training's rmse: 0.79389	valid_1's rmse: 0.982618
# Early stopping, best iteration is:
# [234]	training's rmse: 0.824762	valid_1's rmse: 0.981936
# Partial score of fold 4 is: 0.5882592428670139
#
# Our oof cohen kappa score is: 0.5913447870178046
#
# kappa:  0.5913447870178046
# |  22       |  0.5913   |  0.7618   |  4.822    |  4.792    |  0.0457   |  15.0     |  1.803    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943939	valid_1's rmse: 1.00657
# [200]	training's rmse: 0.886017	valid_1's rmse: 0.995199
# [300]	training's rmse: 0.846738	valid_1's rmse: 0.992935
# [400]	training's rmse: 0.814401	valid_1's rmse: 0.992845
# Early stopping, best iteration is:
# [337]	training's rmse: 0.833958	valid_1's rmse: 0.99257
# Partial score of fold 0 is: 0.5743149676029031
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946871	valid_1's rmse: 0.993544
# [200]	training's rmse: 0.889179	valid_1's rmse: 0.980694
# [300]	training's rmse: 0.84986	valid_1's rmse: 0.979326
# [400]	training's rmse: 0.817791	valid_1's rmse: 0.979458
# Early stopping, best iteration is:
# [321]	training's rmse: 0.842677	valid_1's rmse: 0.979001
# Partial score of fold 1 is: 0.6004393958206315
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94629	valid_1's rmse: 1.0013
# [200]	training's rmse: 0.889021	valid_1's rmse: 0.98564
# [300]	training's rmse: 0.849855	valid_1's rmse: 0.982811
# [400]	training's rmse: 0.817599	valid_1's rmse: 0.982302
# Early stopping, best iteration is:
# [356]	training's rmse: 0.831216	valid_1's rmse: 0.981886
# Partial score of fold 2 is: 0.5931030837868858
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94857	valid_1's rmse: 0.997288
# [200]	training's rmse: 0.890859	valid_1's rmse: 0.982803
# [300]	training's rmse: 0.851561	valid_1's rmse: 0.981294
# [400]	training's rmse: 0.819658	valid_1's rmse: 0.98142
# Early stopping, best iteration is:
# [373]	training's rmse: 0.827554	valid_1's rmse: 0.980855
# Partial score of fold 3 is: 0.5975764447830723
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.946923	valid_1's rmse: 0.997067
# [200]	training's rmse: 0.89002	valid_1's rmse: 0.985141
# [300]	training's rmse: 0.851402	valid_1's rmse: 0.981641
# Early stopping, best iteration is:
# [299]	training's rmse: 0.851757	valid_1's rmse: 0.981623
# Partial score of fold 4 is: 0.5905859674237315
#
# Our oof cohen kappa score is: 0.5908795113330289
#
# kappa:  0.5908795113330289
# |  23       |  0.5909   |  0.9311   |  4.19     |  0.01993  |  0.02503  |  16.99    |  1.413    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.914537	valid_1's rmse: 1.00109
# [200]	training's rmse: 0.846892	valid_1's rmse: 0.99465
# [300]	training's rmse: 0.79886	valid_1's rmse: 0.99296
# Early stopping, best iteration is:
# [249]	training's rmse: 0.821387	valid_1's rmse: 0.992323
# Partial score of fold 0 is: 0.582903820715581
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.91744	valid_1's rmse: 0.989514
# [200]	training's rmse: 0.851558	valid_1's rmse: 0.984064
# [300]	training's rmse: 0.802293	valid_1's rmse: 0.98358
# Early stopping, best iteration is:
# [214]	training's rmse: 0.843902	valid_1's rmse: 0.983041
# Partial score of fold 1 is: 0.5931030837868858
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.914884	valid_1's rmse: 0.990246
# [200]	training's rmse: 0.848991	valid_1's rmse: 0.982755
# [300]	training's rmse: 0.800271	valid_1's rmse: 0.981479
# [400]	training's rmse: 0.758773	valid_1's rmse: 0.983174
# Early stopping, best iteration is:
# [324]	training's rmse: 0.789997	valid_1's rmse: 0.981137
# Partial score of fold 2 is: 0.5984711169823096
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9175	valid_1's rmse: 0.988624
# [200]	training's rmse: 0.85119	valid_1's rmse: 0.979395
# Early stopping, best iteration is:
# [174]	training's rmse: 0.865037	valid_1's rmse: 0.978805
# Partial score of fold 3 is: 0.6000815269409366
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.917405	valid_1's rmse: 0.992696
# [200]	training's rmse: 0.851553	valid_1's rmse: 0.983553
# Early stopping, best iteration is:
# [195]	training's rmse: 0.853928	valid_1's rmse: 0.982918
# Partial score of fold 4 is: 0.585574560686186
#
# Our oof cohen kappa score is: 0.5920963862009037
#
# kappa:  0.5920963862009037
# |  24       |  0.5921   |  0.5185   |  1.516    |  0.4176   |  0.0377   |  16.98    |  4.444    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943825	valid_1's rmse: 1.00735
# [200]	training's rmse: 0.884981	valid_1's rmse: 0.994788
# [300]	training's rmse: 0.84569	valid_1's rmse: 0.992364
# [400]	training's rmse: 0.813078	valid_1's rmse: 0.991714
# [500]	training's rmse: 0.78465	valid_1's rmse: 0.991035
# [600]	training's rmse: 0.758518	valid_1's rmse: 0.992372
# Early stopping, best iteration is:
# [522]	training's rmse: 0.778957	valid_1's rmse: 0.990783
# Partial score of fold 0 is: 0.5814723451968014
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945833	valid_1's rmse: 0.992057
# [200]	training's rmse: 0.888073	valid_1's rmse: 0.979911
# [300]	training's rmse: 0.848351	valid_1's rmse: 0.980128
# Early stopping, best iteration is:
# [241]	training's rmse: 0.870819	valid_1's rmse: 0.97928
# Partial score of fold 1 is: 0.5995447236213942
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944511	valid_1's rmse: 1.00045
# [200]	training's rmse: 0.888117	valid_1's rmse: 0.986056
# [300]	training's rmse: 0.849182	valid_1's rmse: 0.985216
# Early stopping, best iteration is:
# [246]	training's rmse: 0.869193	valid_1's rmse: 0.984842
# Partial score of fold 2 is: 0.5882718539110046
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.947144	valid_1's rmse: 0.996141
# [200]	training's rmse: 0.889452	valid_1's rmse: 0.981391
# [300]	training's rmse: 0.850451	valid_1's rmse: 0.980004
# [400]	training's rmse: 0.818006	valid_1's rmse: 0.980584
# Early stopping, best iteration is:
# [306]	training's rmse: 0.8484	valid_1's rmse: 0.979866
# Partial score of fold 3 is: 0.5988289858620044
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.94583	valid_1's rmse: 0.998112
# [200]	training's rmse: 0.88923	valid_1's rmse: 0.987612
# [300]	training's rmse: 0.850818	valid_1's rmse: 0.984738
# [400]	training's rmse: 0.817703	valid_1's rmse: 0.985003
# Early stopping, best iteration is:
# [302]	training's rmse: 0.850197	valid_1's rmse: 0.984703
# Partial score of fold 4 is: 0.5879012852429035
#
# Our oof cohen kappa score is: 0.5910584635194811
#
# kappa:  0.5910584635194811
# |  25       |  0.5911   |  0.8888   |  2.754    |  4.906    |  0.02598  |  16.99    |  2.132    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95245	valid_1's rmse: 1.01218
# [200]	training's rmse: 0.891238	valid_1's rmse: 0.994655
# [300]	training's rmse: 0.852552	valid_1's rmse: 0.991781
# [400]	training's rmse: 0.820388	valid_1's rmse: 0.990722
# Early stopping, best iteration is:
# [375]	training's rmse: 0.82792	valid_1's rmse: 0.990247
# Partial score of fold 0 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955778	valid_1's rmse: 1.00114
# [200]	training's rmse: 0.894646	valid_1's rmse: 0.981851
# [300]	training's rmse: 0.855205	valid_1's rmse: 0.978838
# [400]	training's rmse: 0.823552	valid_1's rmse: 0.979034
# Early stopping, best iteration is:
# [345]	training's rmse: 0.840058	valid_1's rmse: 0.978306
# Partial score of fold 1 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954271	valid_1's rmse: 1.00553
# [200]	training's rmse: 0.892796	valid_1's rmse: 0.984837
# [300]	training's rmse: 0.854225	valid_1's rmse: 0.982342
# [400]	training's rmse: 0.82269	valid_1's rmse: 0.982948
# Early stopping, best iteration is:
# [346]	training's rmse: 0.839566	valid_1's rmse: 0.98196
# Partial score of fold 2 is: 0.594355624865818
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955532	valid_1's rmse: 1.00413
# [200]	training's rmse: 0.894459	valid_1's rmse: 0.982824
# [300]	training's rmse: 0.85613	valid_1's rmse: 0.97941
# [400]	training's rmse: 0.824523	valid_1's rmse: 0.978358
# Early stopping, best iteration is:
# [364]	training's rmse: 0.835223	valid_1's rmse: 0.977967
# Partial score of fold 3 is: 0.5984711169823096
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955085	valid_1's rmse: 1.00597
# [200]	training's rmse: 0.894977	valid_1's rmse: 0.988624
# [300]	training's rmse: 0.856048	valid_1's rmse: 0.984055
# [400]	training's rmse: 0.824481	valid_1's rmse: 0.984469
# [500]	training's rmse: 0.797445	valid_1's rmse: 0.982618
# [600]	training's rmse: 0.772805	valid_1's rmse: 0.982876
# Early stopping, best iteration is:
# [562]	training's rmse: 0.781859	valid_1's rmse: 0.982378
# Partial score of fold 4 is: 0.5898700521755107
#
# Our oof cohen kappa score is: 0.5933490515060689
#
# kappa:  0.5933490515060689
# |  26       |  0.5933   |  0.5466   |  4.94     |  0.5844   |  0.02624  |  15.05    |  3.77     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953439	valid_1's rmse: 1.01088
# [200]	training's rmse: 0.894711	valid_1's rmse: 0.99516
# [300]	training's rmse: 0.858158	valid_1's rmse: 0.991247
# [400]	training's rmse: 0.827638	valid_1's rmse: 0.991102
# Early stopping, best iteration is:
# [387]	training's rmse: 0.83159	valid_1's rmse: 0.990627
# Partial score of fold 0 is: 0.5852299684335979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.956975	valid_1's rmse: 1.00045
# [200]	training's rmse: 0.898589	valid_1's rmse: 0.983159
# [300]	training's rmse: 0.861167	valid_1's rmse: 0.980969
# [400]	training's rmse: 0.830417	valid_1's rmse: 0.981673
# Early stopping, best iteration is:
# [320]	training's rmse: 0.85441	valid_1's rmse: 0.980629
# Partial score of fold 1 is: 0.5993657891815468
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.957735	valid_1's rmse: 1.00711
# [200]	training's rmse: 0.897509	valid_1's rmse: 0.985807
# [300]	training's rmse: 0.860297	valid_1's rmse: 0.983175
# [400]	training's rmse: 0.82968	valid_1's rmse: 0.984142
# Early stopping, best iteration is:
# [304]	training's rmse: 0.858966	valid_1's rmse: 0.982981
# Partial score of fold 2 is: 0.592387346027496
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.957975	valid_1's rmse: 1.00669
# [200]	training's rmse: 0.897884	valid_1's rmse: 0.984862
# [300]	training's rmse: 0.860741	valid_1's rmse: 0.981055
# [400]	training's rmse: 0.831114	valid_1's rmse: 0.98107
# Early stopping, best iteration is:
# [378]	training's rmse: 0.837328	valid_1's rmse: 0.980839
# Partial score of fold 3 is: 0.5975764447830723
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.956816	valid_1's rmse: 1.00561
# [200]	training's rmse: 0.899627	valid_1's rmse: 0.988465
# [300]	training's rmse: 0.862756	valid_1's rmse: 0.984436
# [400]	training's rmse: 0.833016	valid_1's rmse: 0.983812
# Early stopping, best iteration is:
# [370]	training's rmse: 0.841603	valid_1's rmse: 0.983247
# Partial score of fold 4 is: 0.5895120945514003
#
# Our oof cohen kappa score is: 0.5929195662585837
#
# kappa:  0.5929195662585837
# |  27       |  0.5929   |  0.5776   |  4.929    |  4.994    |  0.026    |  15.35    |  9.541    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.927504	valid_1's rmse: 1.00203
# [200]	training's rmse: 0.865613	valid_1's rmse: 0.993317
# [300]	training's rmse: 0.821968	valid_1's rmse: 0.991233
# [400]	training's rmse: 0.784313	valid_1's rmse: 0.991707
# Early stopping, best iteration is:
# [343]	training's rmse: 0.805063	valid_1's rmse: 0.990887
# Partial score of fold 0 is: 0.5846931651140554
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.930599	valid_1's rmse: 0.989455
# [200]	training's rmse: 0.86846	valid_1's rmse: 0.980466
# [300]	training's rmse: 0.82408	valid_1's rmse: 0.980244
# Early stopping, best iteration is:
# [259]	training's rmse: 0.840963	valid_1's rmse: 0.980148
# Partial score of fold 1 is: 0.5975764447830723
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.929272	valid_1's rmse: 0.995913
# [200]	training's rmse: 0.86788	valid_1's rmse: 0.985652
# [300]	training's rmse: 0.823653	valid_1's rmse: 0.985953
# Early stopping, best iteration is:
# [251]	training's rmse: 0.844277	valid_1's rmse: 0.985169
# Partial score of fold 2 is: 0.5911348049485639
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.931303	valid_1's rmse: 0.991304
# [200]	training's rmse: 0.868752	valid_1's rmse: 0.9826
# [300]	training's rmse: 0.824284	valid_1's rmse: 0.982723
# Early stopping, best iteration is:
# [216]	training's rmse: 0.861099	valid_1's rmse: 0.982319
# Partial score of fold 3 is: 0.594713493745513
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.929909	valid_1's rmse: 0.994208
# [200]	training's rmse: 0.86925	valid_1's rmse: 0.982685
# [300]	training's rmse: 0.825912	valid_1's rmse: 0.98066
# [400]	training's rmse: 0.788177	valid_1's rmse: 0.980346
# [500]	training's rmse: 0.75573	valid_1's rmse: 0.980886
# Early stopping, best iteration is:
# [411]	training's rmse: 0.78447	valid_1's rmse: 0.979888
# Partial score of fold 4 is: 0.5873643488067379
#
# Our oof cohen kappa score is: 0.5906289782719958
#
# kappa:  0.5906289782719958
# |  28       |  0.5906   |  0.7393   |  0.3453   |  4.579    |  0.03084  |  15.01    |  1.31     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.909182	valid_1's rmse: 0.997081
# [200]	training's rmse: 0.842803	valid_1's rmse: 0.990575
# Early stopping, best iteration is:
# [198]	training's rmse: 0.843812	valid_1's rmse: 0.990466
# Partial score of fold 0 is: 0.5850510339937505
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.911913	valid_1's rmse: 0.986347
# [200]	training's rmse: 0.845817	valid_1's rmse: 0.982234
# [300]	training's rmse: 0.797121	valid_1's rmse: 0.982437
# Early stopping, best iteration is:
# [228]	training's rmse: 0.831071	valid_1's rmse: 0.981421
# Partial score of fold 1 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.910092	valid_1's rmse: 0.990346
# [200]	training's rmse: 0.844932	valid_1's rmse: 0.984659
# Early stopping, best iteration is:
# [182]	training's rmse: 0.854623	valid_1's rmse: 0.984547
# Partial score of fold 2 is: 0.590419067189174
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.911431	valid_1's rmse: 0.987665
# [200]	training's rmse: 0.845997	valid_1's rmse: 0.980861
# [300]	training's rmse: 0.799044	valid_1's rmse: 0.981713
# Early stopping, best iteration is:
# [216]	training's rmse: 0.838121	valid_1's rmse: 0.980303
# Partial score of fold 3 is: 0.5995447236213942
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.912858	valid_1's rmse: 0.989781
# [200]	training's rmse: 0.84808	valid_1's rmse: 0.982663
# [300]	training's rmse: 0.801414	valid_1's rmse: 0.981423
# [400]	training's rmse: 0.76204	valid_1's rmse: 0.982691
# Early stopping, best iteration is:
# [304]	training's rmse: 0.799929	valid_1's rmse: 0.981186
# Partial score of fold 4 is: 0.5884382216790691
#
# Our oof cohen kappa score is: 0.591881643577161
#
# kappa:  0.591881643577161
# |  29       |  0.5919   |  0.5024   |  4.741    |  0.1534   |  0.04314  |  16.94    |  3.617    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942374	valid_1's rmse: 1.00693
# [200]	training's rmse: 0.879649	valid_1's rmse: 0.991333
# [300]	training's rmse: 0.837624	valid_1's rmse: 0.989832
# [400]	training's rmse: 0.802793	valid_1's rmse: 0.990063
# Early stopping, best iteration is:
# [348]	training's rmse: 0.820094	valid_1's rmse: 0.989264
# Partial score of fold 0 is: 0.5861246406328351
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943479	valid_1's rmse: 0.996948
# [200]	training's rmse: 0.881555	valid_1's rmse: 0.981905
# [300]	training's rmse: 0.839391	valid_1's rmse: 0.979155
# [400]	training's rmse: 0.804957	valid_1's rmse: 0.981191
# Early stopping, best iteration is:
# [305]	training's rmse: 0.837413	valid_1's rmse: 0.979087
# Partial score of fold 1 is: 0.5995447236213942
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942254	valid_1's rmse: 1.00109
# [200]	training's rmse: 0.879939	valid_1's rmse: 0.985805
# [300]	training's rmse: 0.838165	valid_1's rmse: 0.982905
# [400]	training's rmse: 0.804217	valid_1's rmse: 0.983552
# Early stopping, best iteration is:
# [302]	training's rmse: 0.837433	valid_1's rmse: 0.982834
# Partial score of fold 2 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943527	valid_1's rmse: 1.00006
# [200]	training's rmse: 0.880922	valid_1's rmse: 0.982292
# [300]	training's rmse: 0.839706	valid_1's rmse: 0.981053
# [400]	training's rmse: 0.805249	valid_1's rmse: 0.980565
# Early stopping, best iteration is:
# [380]	training's rmse: 0.811615	valid_1's rmse: 0.980249
# Partial score of fold 3 is: 0.5963239037041401
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944216	valid_1's rmse: 1.00172
# [200]	training's rmse: 0.882808	valid_1's rmse: 0.986508
# [300]	training's rmse: 0.841078	valid_1's rmse: 0.982779
# [400]	training's rmse: 0.807102	valid_1's rmse: 0.982884
# Early stopping, best iteration is:
# [339]	training's rmse: 0.826679	valid_1's rmse: 0.982493
# Partial score of fold 4 is: 0.5891541369272899
#
# Our oof cohen kappa score is: 0.5930985184450359
#
# kappa:  0.5930985184450359
# |  30       |  0.5931   |  0.5113   |  3.857    |  0.1219   |  0.02918  |  15.07    |  1.461    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954897	valid_1's rmse: 1.01258
# [200]	training's rmse: 0.895604	valid_1's rmse: 0.995535
# [300]	training's rmse: 0.858305	valid_1's rmse: 0.992718
# [400]	training's rmse: 0.827666	valid_1's rmse: 0.99233
# [500]	training's rmse: 0.801346	valid_1's rmse: 0.992105
# Early stopping, best iteration is:
# [441]	training's rmse: 0.81669	valid_1's rmse: 0.991854
# Partial score of fold 0 is: 0.5820091485163437
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.958697	valid_1's rmse: 1.00147
# [200]	training's rmse: 0.899309	valid_1's rmse: 0.982295
# [300]	training's rmse: 0.86179	valid_1's rmse: 0.980584
# [400]	training's rmse: 0.831044	valid_1's rmse: 0.979684
# Early stopping, best iteration is:
# [386]	training's rmse: 0.834901	valid_1's rmse: 0.979607
# Partial score of fold 1 is: 0.594713493745513
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95635	valid_1's rmse: 1.00576
# [200]	training's rmse: 0.897069	valid_1's rmse: 0.985122
# [300]	training's rmse: 0.859844	valid_1's rmse: 0.982014
# [400]	training's rmse: 0.830061	valid_1's rmse: 0.982118
# Early stopping, best iteration is:
# [356]	training's rmse: 0.842564	valid_1's rmse: 0.981794
# Partial score of fold 2 is: 0.5925662804673435
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.957787	valid_1's rmse: 1.00415
# [200]	training's rmse: 0.898967	valid_1's rmse: 0.98426
# [300]	training's rmse: 0.861937	valid_1's rmse: 0.980448
# [400]	training's rmse: 0.831062	valid_1's rmse: 0.979557
# [500]	training's rmse: 0.803346	valid_1's rmse: 0.980037
# Early stopping, best iteration is:
# [422]	training's rmse: 0.824625	valid_1's rmse: 0.979261
# Partial score of fold 3 is: 0.6029444779784959
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95817	valid_1's rmse: 1.00521
# [200]	training's rmse: 0.899958	valid_1's rmse: 0.988858
# [300]	training's rmse: 0.862823	valid_1's rmse: 0.984364
# [400]	training's rmse: 0.833129	valid_1's rmse: 0.983889
# Early stopping, best iteration is:
# [355]	training's rmse: 0.845934	valid_1's rmse: 0.983264
# Partial score of fold 4 is: 0.5909439250478419
#
# Our oof cohen kappa score is: 0.5937427463162637
#
# kappa:  0.5937427463162637
# |  31       |  0.5937   |  0.5881   |  4.842    |  4.738    |  0.02546  |  16.0     |  3.776    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.941081	valid_1's rmse: 1.00613
# [200]	training's rmse: 0.880383	valid_1's rmse: 0.993211
# [300]	training's rmse: 0.840426	valid_1's rmse: 0.992003
# [400]	training's rmse: 0.806791	valid_1's rmse: 0.991352
# Early stopping, best iteration is:
# [387]	training's rmse: 0.810615	valid_1's rmse: 0.990927
# Partial score of fold 0 is: 0.5859457061929877
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944399	valid_1's rmse: 0.996201
# [200]	training's rmse: 0.884514	valid_1's rmse: 0.982416
# [300]	training's rmse: 0.843218	valid_1's rmse: 0.980335
# [400]	training's rmse: 0.80951	valid_1's rmse: 0.981116
# Early stopping, best iteration is:
# [339]	training's rmse: 0.829	valid_1's rmse: 0.979662
# Partial score of fold 1 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942331	valid_1's rmse: 0.999741
# [200]	training's rmse: 0.882637	valid_1's rmse: 0.983165
# [300]	training's rmse: 0.842661	valid_1's rmse: 0.981825
# [400]	training's rmse: 0.809666	valid_1's rmse: 0.982318
# Early stopping, best iteration is:
# [356]	training's rmse: 0.823357	valid_1's rmse: 0.981585
# Partial score of fold 2 is: 0.5966817725838349
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943523	valid_1's rmse: 0.997422
# [200]	training's rmse: 0.88292	valid_1's rmse: 0.980751
# [300]	training's rmse: 0.843913	valid_1's rmse: 0.978523
# [400]	training's rmse: 0.810822	valid_1's rmse: 0.978716
# Early stopping, best iteration is:
# [313]	training's rmse: 0.839321	valid_1's rmse: 0.977831
# Partial score of fold 3 is: 0.602586609098801
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.944038	valid_1's rmse: 1.00009
# [200]	training's rmse: 0.884406	valid_1's rmse: 0.985162
# [300]	training's rmse: 0.844808	valid_1's rmse: 0.981739
# [400]	training's rmse: 0.811871	valid_1's rmse: 0.982208
# Early stopping, best iteration is:
# [322]	training's rmse: 0.836946	valid_1's rmse: 0.981667
# Partial score of fold 4 is: 0.5893331157393451
#
# Our oof cohen kappa score is: 0.5938143271908446
#
# kappa:  0.5938143271908446
# |  32       |  0.5938   |  0.5024   |  4.319    |  4.953    |  0.03052  |  16.84    |  3.749    |
# =================================================================================================
#
#  {'feature_fraction': 0.6370823118297216, 'lambda_l1': 3.3002276804648463, 'lambda_l2': 0.4016460404732791, 'learning_rate': 0.0433602097766614, 'max_depth': 16.350214126392107, 'subsample_freq': 2.6860995616650714}

# %%
params = {
    'feature_fraction': 0.7,
    'lambda_l1': 3.3, 
    'lambda_l2': 0.4, 
    'learning_rate': 0.04, 
    'max_depth': 16, 
    'subsample_freq': 2
}

# %%
# cat_model = Catb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals, ps=LGB_BO.max['params'])
# lgb_model = Lgb_Model(reduce_train, ajusted_te/t, features, categoricals=categoricals, ps=params)
# xgb_model = Xgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.904129	valid_1's rmse: 0.995813
# [200]	training's rmse: 0.836163	valid_1's rmse: 0.991494
# [300]	training's rmse: 0.785101	valid_1's rmse: 0.992631
# Early stopping, best iteration is:
# [222]	training's rmse: 0.823576	valid_1's rmse: 0.990472
# Partial score of fold 0 is: 0.584514230674208
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907808	valid_1's rmse: 0.985441
# [200]	training's rmse: 0.839761	valid_1's rmse: 0.982358
# Early stopping, best iteration is:
# [169]	training's rmse: 0.85807	valid_1's rmse: 0.98195
# Partial score of fold 1 is: 0.5977553792229198
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.903546	valid_1's rmse: 0.987693
# [200]	training's rmse: 0.836329	valid_1's rmse: 0.980331
# [300]	training's rmse: 0.786077	valid_1's rmse: 0.981238
# Early stopping, best iteration is:
# [219]	training's rmse: 0.825772	valid_1's rmse: 0.980045
# Partial score of fold 2 is: 0.598650051422157
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.905975	valid_1's rmse: 0.985117
# [200]	training's rmse: 0.839064	valid_1's rmse: 0.980721
# Early stopping, best iteration is:
# [189]	training's rmse: 0.845148	valid_1's rmse: 0.98037
# Partial score of fold 3 is: 0.5988289858620044
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907468	valid_1's rmse: 0.988266
# [200]	training's rmse: 0.840737	valid_1's rmse: 0.982298
# [300]	training's rmse: 0.789768	valid_1's rmse: 0.98149
# Early stopping, best iteration is:
# [288]	training's rmse: 0.795287	valid_1's rmse: 0.980912
# Partial score of fold 4 is: 0.5906304561527063
#
# Our oof cohen kappa score is: 0.5941006506891681

# %%
lgb_model.plot_importance(lgb_model.models, max_num_features=80, figsize=(12, 20))

# %%
# fig, ax = plt.subplots(1,1, figsize=(12, 24))
# xgb.plot_importance(xgb_model.models[0], ax=ax, max_num_features=100, importance_type='weight')

# %%
# cnn_model = Cnn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# nn_model = Nn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)

# %% [markdown]
# ## Submission

# %%
weights = {'lbg': 0.80, 'cat': 0, 'xgb': 0.20, 'nn': 0.00}

# final_pred = (lgb_model.y_pred * weights['lbg']) + (xgb_model.y_pred * weights['xgb'])
final_pred = lgb_model.y_pred
#final_pred = cnn_model.y_pred
print(final_pred.shape)
# Out:
# (1000,)

# %%
# pd.DataFrame(
#     [(round(a, 2), round(b, 2), round(c, 2), round(d, 2)) 
#          for a, b, c, d in zip(lgb_model.y_pred, cat_model.y_pred, xgb_model.y_pred, nn_model.y_pred)],
#     columns=['lgb', 'cat', 'xgb', 'nn']
# ).head(50)

# %%
# improved
import scipy as sp
from functools import partial

from sklearn.metrics import cohen_kappa_score

class OptimizedRounder(object):
    """
    An optimizer for rounding thresholds
    to maximize Quadratic Weighted Kappa (QWK) score
    # https://www.kaggle.com/naveenasaithambi/optimizedrounder-improved
    """
    def __init__(self, num_class=4):
        self.coef_ = 0
        self.initial_coef = [0.5+i for i in range(num_class-1)]
        self.labels = [i for i in range(num_class)]
    
    def _kappa_loss(self, coef, X, y):
        """
        Get loss according to
        using current coefficients
        
        :param coef: A list of coefficients that will be used for rounding
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels=self.labels)
        return -cohen_kappa_score(y, preds, weights = 'quadratic')
    
    def fit(self, X, y):
        """
        Optimize rounding thresholds
        
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        loss_partial = partial(self._kappa_loss, X = X, y = y)
        initial_coef = self.initial_coef
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method = 'nelder-mead')
    
    def predict(self, X, coef):
        """
        Make predictions with specified thresholds
        
        :param X: The raw predictions
        :param coef: A list of coefficients that will be used for rounding
        """
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels=self.labels)
        return preds
    
    def coefficients(self):
        """
        Return the optimized coefficients
        """
        return self.coef_['x']

# %%
trian_pred_reg = lgb_model.oof_pred

optR = OptimizedRounder(num_class=4)
optR.fit(trian_pred_reg, reduce_train['accuracy_group'])
coefficients = optR.coefficients()

opt_preds = optR.predict(trian_pred_reg.reshape(-1, ), coefficients)

# %%
off_score = cohen_kappa_score(reduce_train['accuracy_group'], opt_preds, weights='quadratic')
print(f'\noff_score is {off_score}\n')

sample_submission['accuracy_group'] = optR.predict(final_pred.reshape(-1, ), coefficients).astype(int)
sample_submission.to_csv('submission.csv', index=False)
display(sample_submission['accuracy_group'].value_counts(normalize=True).sort_index())
sample_submission['accuracy_group'].hist()
# Out:
# off_score is 0.6027298608703973
# 0    0.200
# 1    0.161
# 2    0.294
# 3    0.345
# Name: accuracy_group, dtype: float64

# %%
result_scores = []
_smpl_train = []
_smpl_pred = []

for _ in tqdm(range(50)):
    for i in range(4):
        actual = reduce_train['accuracy_group']
        _smpl_train.extend(actual[actual==i].sample(100))
        _smpl_pred.extend(pd.Series(opt_preds)[actual==i].sample(100))
    result_scores.append(cohen_kappa_score(_smpl_train, _smpl_pred, weights='quadratic'))

pd.Series(result_scores).describe().round(3)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# count    50.000
# mean      0.535
# std       0.004
# min       0.526
# 25%       0.533
# 50%       0.535
# 75%       0.537
# max       0.546
# dtype: float64
