# %%
import os
import gc
import re
import json
import copy
import time
import eli5
import datetime
from numba import jit

from IPython.display import HTML
import altair as alt
from category_encoders.ordinal import OrdinalEncoder
from typing import List, Any

import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats

import random
random.seed(28)
np.random.seed(28)

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import lightgbm as lgb

import xgboost as xgb
from xgboost import XGBClassifier, XGBRegressor
from xgboost import plot_importance

import catboost as cat
from catboost import CatBoostRegressor, CatBoostClassifier

from bayes_opt import BayesianOptimization
import shap

from itertools import product
from functools import partial

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn import linear_model
from sklearn.svm import NuSVR, SVR
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import cohen_kappa_score, mean_squared_error, mean_absolute_error


# Any results you write to the current directory are saved as output.
from time import time
from tqdm import tqdm_notebook as tqdm
from collections import Counter
from collections import defaultdict
from joblib import Parallel, delayed

pd.set_option('display.max_columns', 1000)
pd.set_option('max_rows', 500)
pd.options.display.precision = 15
np.random.seed(566)

import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/rui/.local/share/virtualenvs/data_science_bowl-_c7OiX6v/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/rui/.local/share/virtualenvs/data_science_bowl-_c7OiX6v/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Objective
#
# - 特徴量の追加
# - 主に、worldに関する特徴量を追加する。
# - cv scoreに関する詳細はnoteに書き残す。

# %% [markdown]
# # Notes
#
# - CV score with added features
#     - baseline：0.5933490515060689
#     - world count：0.5928479853840027
#     - last_session_time_sec, last_sessin_world：0.5942796028756203
#     - world_count and duration：0.5901637025872202
#     - accumulated_each_world_accuracy, nunique post world：0.593026937570455

# %% [markdown]
# ## Load Data

# %%
def read_data():
    if os.path.exists('/kaggle/input/data-science-bowl-2019/'):
        data_dir_path = '/kaggle/input/data-science-bowl-2019/'
    else:
        data_dir_path = '../data/raw/'
        
    
    print('Reading train.csv file....')
    train = pd.read_csv(data_dir_path+'train.csv')
    print('Training.csv file have {} rows and {} columns'.format(train.shape[0], train.shape[1]))

    print('Reading test.csv file....')
    test = pd.read_csv(data_dir_path+'test.csv')
    print('Test.csv file have {} rows and {} columns'.format(test.shape[0], test.shape[1]))

    print('Reading train_labels.csv file....')
    train_labels = pd.read_csv(data_dir_path+'train_labels.csv')
    print('Train_labels.csv file have {} rows and {} columns'.format(train_labels.shape[0], train_labels.shape[1]))

    print('Reading specs.csv file....')
    specs = pd.read_csv(data_dir_path+'specs.csv')
    print('Specs.csv file have {} rows and {} columns'.format(specs.shape[0], specs.shape[1]))

    print('Reading sample_submission.csv file....')
    sample_submission = pd.read_csv(data_dir_path+'sample_submission.csv')
    print('Sample_submission.csv file have {} rows and {} columns'.format(sample_submission.shape[0], sample_submission.shape[1]))
    return train, test, train_labels, specs, sample_submission

# %%
raw_train, raw_test, train_labels, specs, sample_submission = read_data()
# Out:
# Reading train.csv file....
# Training.csv file have 11341042 rows and 11 columns
# Reading test.csv file....
# Test.csv file have 1156414 rows and 11 columns
# Reading train_labels.csv file....
# Train_labels.csv file have 17690 rows and 7 columns
# Reading specs.csv file....
# Specs.csv file have 386 rows and 3 columns
# Reading sample_submission.csv file....
# Sample_submission.csv file have 1000 rows and 2 columns

# %%
print(raw_train.shape)
raw_train.head()
# Out:
# (11341042, 11)
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %% [markdown]
# ## Transform Data

# %%
def encode_title(raw_train, raw_test, train_labels):
    train = raw_train.copy()
    test = raw_test.copy()
    # encode title
    train['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), train['title'], train['event_code']))
    test['title_event_code'] = list(map(lambda x, y: str(x) + '_' + str(y), test['title'], test['event_code']))
    all_title_event_code = list(set(train["title_event_code"].unique()).union(test["title_event_code"].unique()))
    # make a list with all the unique 'titles' from the train and test set
    list_of_user_activities = list(set(train['title'].unique()).union(set(test['title'].unique())))
    # make a list with all the unique 'event_code' from the train and test set
    list_of_event_code = list(set(train['event_code'].unique()).union(set(test['event_code'].unique())))
    list_of_event_id = list(set(train['event_id'].unique()).union(set(test['event_id'].unique())))
    # make a list with all the unique worlds from the train and test set
    list_of_worlds = list(set(train['world'].unique()).union(set(test['world'].unique())))
    # create a dictionary numerating the titles
    activities_map = dict(zip(list_of_user_activities, np.arange(len(list_of_user_activities))))
    activities_labels = dict(zip(np.arange(len(list_of_user_activities)), list_of_user_activities))
#     activities_world = dict(zip(list_of_worlds, np.arange(len(list_of_worlds))))
    assess_titles = list(set(train[train['type'] == 'Assessment']['title'].value_counts().index).union(set(test[test['type'] == 'Assessment']['title'].value_counts().index)))
    # replace the text titles with the number titles from the dict
    train['title'] = train['title'].map(activities_map)
    test['title'] = test['title'].map(activities_map)
#     train['world'] = train['world'].map(activities_world)
#     test['world'] = test['world'].map(activities_world)
    train_labels['title'] = train_labels['title'].map(activities_map)
    win_code = dict(zip(activities_map.values(), (4100*np.ones(len(activities_map))).astype('int')))
    # then, it set one element, the 'Bird Measurer (Assessment)' as 4110, 10 more than the rest
    win_code[activities_map['Bird Measurer (Assessment)']] = 4110
    # convert text into datetime
    train['timestamp'] = pd.to_datetime(train['timestamp'])
    test['timestamp'] = pd.to_datetime(test['timestamp'])
    
    train['hour'] = train['timestamp'].dt.hour
    test['hour'] = test['timestamp'].dt.hour
    train['weekday'] = train['timestamp'].dt.weekday
    test['weekday'] = test['timestamp'].dt.weekday
    
    return train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, activities_labels, assess_titles, list_of_event_id, all_title_event_code, list_of_worlds

# %%
clip_time = {
    'Welcome to Lost Lagoon!':19,'Tree Top City - Level 1':17,'Ordering Spheres':61, 'Costume Box':61,
    '12 Monkeys':109,'Tree Top City - Level 2':25, 'Pirate\'s Tale':80, 'Treasure Map':156,'Tree Top City - Level 3':26,
    'Rulers':126, 'Magma Peak - Level 1':20, 'Slop Problem':60, 'Magma Peak - Level 2':22, 'Crystal Caves - Level 1':18,
    'Balancing Act':72, 'Lifting Heavy Things':118,'Crystal Caves - Level 2':24, 'Honey Cake':142, 'Crystal Caves - Level 3':19,
    'Heavy, Heavier, Heaviest':61
}

# %%
# this is the function that convert the raw data into processed features
def get_data(user_sample, test_set=False):
    '''
    The user_sample is a DataFrame from train or test where the only one 
    installation_id is filtered
    And the test_set parameter is related with the labels processing, that is only requered
    if test_set=False
    '''
    # 学習データとなるリスト（出力値）
    all_assessments = [] 
    
    # installation_idごとの特徴量
    # Constants and parameters declaration
    last_activity = 0
    # typeごとの回数
    user_activities_count = {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
    
    # new features: time spent in each activity
    # 最後のセッションの時間
    last_session_time_sec = 0
    last_sessin_world = None
    # Assessmentから得られる特徴量
    accuracy_groups = {0:0, 1:0, 2:0, 3:0} # accuracy_groupの回数
    accumulated_accuracy_group = 0 # 累積のaccuracy_group。最後にassessmenに挑戦した回数（counter）で割っている。
    accumulated_accuracy = 0 # 累積のaccuracy。単純に正答率を足し合わせている。
    accumulated_correct_attempts = 0 # 累積のcorrect_attempts
    accumulated_uncorrect_attempts = 0 # 累積のuncorrect_attempts
    accumulated_actions = 0 # 全てのセッションにおけるイベント回数
    counter = 0 # Assessmentに挑戦した回数
    time_first_activity = float(user_sample['timestamp'].values[0])
    accumulated_each_world_accuracy: Dict[str, int] = {f'accumulated_accuracy_of_{world}': 0 for world in list_of_worlds}
    # セッション時間の特徴量
    # each session type
    Assessment_durations = []
    clip_durations = [] # clipだけのセッション時間
    Activity_durations = [] # Activityだけのセッション時間
    Game_durations = [] # Gameだけのセッション時間
    world_durations: Dict[str, list] = {world: [] for world in list_of_worlds}
    
    last_accuracy_title = {'acc_' + title: -1 for title in assess_titles} # titleごとの最後の正答率
    event_code_count: Dict[str, int] = {ev: 0 for ev in list_of_event_code}
    game_event_code_count: Dict[str, int] = { str(ev) + '_g': 0 for ev in list_of_event_code}
    Activity_event_code_count: Dict[str, int] = {str(ev) + '_A': 0 for ev in list_of_event_code}    
    event_id_count: Dict[str, int] = {eve: 0 for eve in list_of_event_id}
    Activity_sum_event_count = 0
    game_sum_event_count = 0
#     game_event_id_count: Dict[str, int] = {eve+'_g': 0 for eve in list_of_event_id}
#     Activity_event_id_count: Dict[str, int] = {eve+'_A': 0 for eve in list_of_event_id}
#     Accessment_event_id_count: Dict[str, int] = {eve+'_ac': 0 for eve in list_of_event_id}
    world_count: Dict[str, int] = {world: 0 for world in list_of_worlds}
    title_count: Dict[str, int] = {eve: 0 for eve in activities_labels.values()} 
    title_event_code_count: Dict[str, int] = {t_eve: 0 for t_eve in all_title_event_code}
        
    # last features
    sessions_count = 0
    
    # itarates through each session of one instalation_id
    for i, session in user_sample.groupby('game_session', sort=False):
        # i = game_session_id
        # session is a DataFrame that contain only one game_session
        
        # get some sessions information
        session_type = session['type'].iloc[0]
        session_world = session['world'].iloc[0]
        session_title = session['title'].iloc[0]
#         session_game_time = session['game_time'].iloc[-1]
        session_game_time_sec = (session.iloc[-1, 2] - session.iloc[0, 2]).seconds
        session_title_text = activities_labels[session_title]
        
        if session_type == 'Clip':
            clip_durations.append((clip_time[activities_labels[session_title]]))
        
        if session_type == 'Activity':
            Activity_sum_event_count = Activity_sum_event_count + session['event_count'].iloc[-1]
            Activity_durations.append(session_game_time_sec)
            def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = str(k) + '_A'
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            Activity_event_code_count = update_counters(Activity_event_code_count, "event_code")
#             def update_counters_id(counter: dict, col: str):
#                 num_of_session_count = Counter(session[col])
#                 for k in num_of_session_count.keys():
#                     x = k + '_g'
#                     if col == 'title':
#                         x = activities_labels[k]
#                     counter[x] += num_of_session_count[k]
#                 return counter
#             Activity_event_id_count = update_counters(Activity_event_id_count, "event_id")
        
        if session_type == 'Game':
            game_sum_event_count = game_sum_event_count + session['event_count'].iloc[-1]
            Game_durations.append(session_game_time_sec)
            def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = str(k) + '_g'
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            game_event_code_count = update_counters(game_event_code_count, "event_code")
#             def update_counters_id(counter: dict, col: str):
#                 num_of_session_count = Counter(session[col])
#                 for k in num_of_session_count.keys():
#                     x = k + '_g'
#                     if col == 'title':
#                         x = activities_labels[k]
#                     counter[x] += num_of_session_count[k]
#                 return counter
#             game_event_id_count = update_counters(game_event_id_count, "event_id")

        # for each assessment, and only this kind off session, the features below are processed
        # and a register are generated
        if (session_type == 'Assessment') & (test_set or len(session)>1):
            # search for event_code 4100, that represents the assessments trial
            all_attempts = session.query(f'event_code == {win_code[session_title]}')
            # then, check the numbers of wins and the number of losses
            true_attempts = all_attempts['event_data'].str.contains('true').sum()
            false_attempts = all_attempts['event_data'].str.contains('false').sum()
            # copy a dict to use as feature template, it's initialized with some itens: 
            # {'Clip':0, 'Activity': 0, 'Assessment': 0, 'Game':0}
            features = user_activities_count.copy()
            features.update(last_accuracy_title.copy())
            features.update(event_code_count.copy())
            features.update(event_id_count.copy())
            
            features.update(game_event_code_count.copy())
#             features.update(game_event_id_count.copy())
            features.update(Activity_event_code_count.copy())
#             features.update(Activity_event_id_count.copy())
#             features.update(Accessment_event_id_count.copy())
            
            features.update(world_count.copy())
            features.update(title_count.copy())
            features.update(title_event_code_count.copy())
            features['installation_session_count'] = sessions_count
            features['hour'] = session['hour'].iloc[-1]
            features['weekday'] = session['weekday'].iloc[-1]
            variety_features = [('var_event_code', event_code_count),
                              ('var_event_id', event_id_count),
                               ('var_title', title_count),
                               ('var_title_event_code', title_event_code_count)]
            
            for name, dict_counts in variety_features:
                arr = np.array(list(dict_counts.values()))
                features[name] = np.count_nonzero(arr)
                 
            # get installation_id for aggregated features
            features['installation_id'] = session['installation_id'].iloc[-1]
            # add title as feature, remembering that title represents the name of the game
            features['session_title'] = session['title'].iloc[0]
            features['num_of_post_words'] = sum([v>0 for v in world_count.values()])
            # the 4 lines below add the feature of the history of the trials of this player
            # this is based on the all time attempts so far, at the moment of this assessment
            features['accumulated_correct_attempts'] = accumulated_correct_attempts
            features['accumulated_uncorrect_attempts'] = accumulated_uncorrect_attempts
            features['game_sum_event_count'] = game_sum_event_count
            features['Activity_sum_event_count'] = game_sum_event_count
            features.update(accumulated_each_world_accuracy.copy())
            accumulated_correct_attempts += true_attempts 
            accumulated_uncorrect_attempts += false_attempts
            # the time spent in the app so far
            # TODO: これに合計を入れるとどうなるのだろうか。
            features['Assessment_duration_mean'] = np.mean(Assessment_durations) if len(Assessment_durations)!=0 else 0.0
            features['Assessment_duration_std'] = np.std(Assessment_durations) if len(Assessment_durations)!=0 else 0.0
            features['Clip_duration_mean'] = np.mean(clip_durations) if len(clip_durations)!=0 else 0.0
            features['Clip_duration_std'] = np.std(clip_durations) if len(clip_durations)!=0 else 0.0
            features['Activity_duration_mean'] = np.mean(Activity_durations) if len(Activity_durations)!=0 else 0.0
            features['Activity_duration_std'] = np.std(Activity_durations) if len(Activity_durations)!=0 else 0.0
            features['Game_duration_mean'] = np.mean(Game_durations) if len(Game_durations)!=0 else 0.0
            features['Game_duration_std'] = np.std(Game_durations) if len(Game_durations)!=0 else 0.0
            
            # parse each world durations
            for key, val in world_durations.items():
                features[f'{key}_duration_sum'] = np.sum(val) if len(val)!=0 else 0.0
                features[f'{key}_duration_mean'] = np.mean(val) if len(val)!=0 else 0.0
                features[f'{key}_duration_std'] = np.std(val) if len(val)!=0 else 0.0
                
            Assessment_durations.append(session_game_time_sec)
            # the accurace is the all time wins divided by the all time attempts
            features['accumulated_accuracy'] = accumulated_accuracy/counter if counter > 0 else 0
            accuracy = true_attempts/(true_attempts+false_attempts) if (true_attempts+false_attempts) != 0 else 0
            accumulated_accuracy += accuracy
            accumulated_each_world_accuracy[f'accumulated_accuracy_of_{session_world}'] += accuracy
            last_accuracy_title['acc_' + session_title_text] = accuracy
            # a feature of the current accuracy categorized
            # it is a counter of how many times this player was in each accuracy group
            if accuracy == 0:
                features['accuracy_group'] = 0
            elif accuracy == 1:
                features['accuracy_group'] = 3
            elif accuracy == 0.5:
                features['accuracy_group'] = 2
            else:
                features['accuracy_group'] = 1
            features.update(accuracy_groups)
            accuracy_groups[features['accuracy_group']] += 1
            # mean of the all accuracy groups of this player
            features['accumulated_accuracy_group'] = accumulated_accuracy_group/counter if counter > 0 else 0
            accumulated_accuracy_group += features['accuracy_group']
            # how many actions the player has done so far, it is initialized as 0 and updated some lines below
            features['accumulated_actions'] = accumulated_actions
            # last session data
            features['last_session_time_sec'] = last_session_time_sec
            features['last_sessin_world'] = last_sessin_world
            
            # there are some conditions to allow this features to be inserted in the datasets
            # if it's a test set, all sessions belong to the final dataset
            # it it's a train, needs to be passed throught this clausule: session.query(f'event_code == {win_code[session_title]}')
            # that means, must exist an event_code 4100 or 4110
            if test_set:
                all_assessments.append(features)
            elif true_attempts+false_attempts > 0:
                all_assessments.append(features)  
            counter += 1
        
        sessions_count += 1
        # World-related features
        world_count[session_world] += 1
        world_durations[session_world].append(session_game_time_sec)
        # this piece counts how many actions was made in each event_code so far
        def update_counters(counter: dict, col: str):
                num_of_session_count = Counter(session[col])
                for k in num_of_session_count.keys():
                    x = k
                    if col == 'title':
                        x = activities_labels[k]
                    counter[x] += num_of_session_count[k]
                return counter
            
        event_code_count = update_counters(event_code_count, "event_code")
        event_id_count = update_counters(event_id_count, "event_id")
        title_count = update_counters(title_count, 'title')
        title_event_code_count = update_counters(title_event_code_count, 'title_event_code')

        # counts how many actions the player has done so far, used in the feature of the same name
        accumulated_actions += len(session)
        if last_activity != session_type:
            user_activities_count[session_type] += 1
            last_activitiy = session_type 
        
        last_session_time_sec = session_game_time_sec
        last_sessin_world = session_world
                        
    # if it't the test_set, only the last assessment must be predicted, the previous are scraped
    if test_set:
        return all_assessments[-1]
    # in the train_set, all assessments goes to the dataset
    return all_assessments

# %%
def get_train_and_test(train, test):
    compiled_train = []
    compiled_test = []
    for i, (ins_id, user_sample) in tqdm(enumerate(train.groupby('installation_id', sort = False)), total = 17000):
        compiled_train += get_data(user_sample)
    for ins_id, user_sample in tqdm(test.groupby('installation_id', sort = False), total = 1000):
        test_data = get_data(user_sample, test_set = True)
        compiled_test.append(test_data)
    reduce_train = pd.DataFrame(compiled_train)
    reduce_test = pd.DataFrame(compiled_test)
    
    map_of_worlds = {w: i for i, w in enumerate(sorted(list_of_worlds))}
    reduce_train['last_sessin_world'] = reduce_train['last_sessin_world'].map(map_of_worlds).fillna(-1).astype(int)
    reduce_test['last_sessin_world'] = reduce_test['last_sessin_world'].map(map_of_worlds).fillna(-1).astype(int)

    categoricals = ['session_title', 'last_sessin_world']
    return reduce_train, reduce_test, categoricals

# %%
# get usefull dict with maping encode
train, test, train_labels, win_code, list_of_user_activities, list_of_event_code, \
    activities_labels, assess_titles, list_of_event_id, all_title_event_code, list_of_worlds = encode_title(raw_train, raw_test, train_labels)

# tranform function to get the train and test set
reduce_train, reduce_test, categoricals = get_train_and_test(train, test)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=17000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
def stract_hists(feature, train=reduce_train, test=reduce_test, adjust=False, plot=False):
    n_bins = 10
    train_data = train[feature]
    test_data = test[feature]
    if adjust:
        test_data *= train_data.mean() / test_data.mean()
    perc_90 = np.percentile(train_data, 95)
    train_data = np.clip(train_data, 0, perc_90)
    test_data = np.clip(test_data, 0, perc_90)
    train_hist = np.histogram(train_data, bins=n_bins)[0] / len(train_data)
    test_hist = np.histogram(test_data, bins=n_bins)[0] / len(test_data)
    msre = mean_squared_error(train_hist, test_hist)
    if plot:
        print(msre)
        plt.bar(range(n_bins), train_hist, color='blue', alpha=0.5)
        plt.bar(range(n_bins), test_hist, color='red', alpha=0.5)
        plt.show()
    return msre
stract_hists('Magma Peak - Level 1_2000', adjust=False, plot=True)
# Out:
# 0.0026939774600629332
# 0.0026939774600629332

# %%
# column名をLGBMが扱える形に変更
reduce_train.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in reduce_train.columns]
reduce_test.columns = ["".join(c if c.isalnum() else "_" for c in str(x)) for x in reduce_test.columns]

# %%
# call feature engineering function
features = reduce_train.loc[(reduce_train.sum(axis=1) != 0), (reduce_train.sum(axis=0) != 0)].columns # delete useless columns
features = [x for x in features if x not in ['accuracy_group', 'installation_id']]

# %%
# counter = 0
to_remove = []
# for feat_a in features:
#     for feat_b in features:
#         if feat_a != feat_b and feat_a not in to_remove and feat_b not in to_remove:
#             c = np.corrcoef(reduce_train[feat_a], reduce_train[feat_b])[0][1]
#             if c > 0.995:
#                 counter += 1
#                 to_remove.append(feat_b)
#                 print('{}: FEAT_A: {} FEAT_B: {} - Correlation: {}'.format(counter, feat_a, feat_b, c))

# %%
to_exclude = [] 
ajusted_test = reduce_test.copy()
for feature in ajusted_test.columns:
    if feature not in ['accuracy_group', 'installation_id', 'accuracy_group']+categoricals:
        data = reduce_train[feature]
        train_mean = data.mean()
        data = ajusted_test[feature] 
        test_mean = data.mean()
        try:
            error = stract_hists(feature, adjust=True)
            ajust_factor = train_mean / test_mean
            if ajust_factor > 10 or ajust_factor < 0.1:# or error > 0.01:
                to_exclude.append(feature)
                print(feature, train_mean, test_mean, error)
            else:
                ajusted_test[feature] *= ajust_factor
        except:
            to_exclude.append(feature)
            print(feature, train_mean, test_mean)
# Out:
# acc_Cart_Balancer__Assessment_ -0.04020325710970143 -0.47065833333333335 0.006732930476733109
# 0ce40006 0.0008479366873940079 0.0
# 6aeafed4 0.14703222159412097 0.008 0.0
# 01ca3a3c 0.0004522328999434709 0.0
# ecc6157f 0.007292255511588468 0.0
# 29a42aea 0.004070096099491238 0.0
# 13f56524 0.04392312040700961 0.0
# 1b54d27f 0.0007348784624081402 0.0
# 4074bac2 0.0 0.0
# eb2c19cd 0.17382702091577162 0.008 0.0
# dcb1663e 0.0 0.0
# 003cd2ee 0.0 0.0
# 119b5b02 0.0002826455624646693 0.0
# bfc77bd6 0.012832108535895986 0.0
# a8cc6fec 0.0 0.0
# 7fd1ac25 0.01978518937252685 0.0
# 17ca3959 0.0 0.0
# 5dc079d8 0.0 0.0
# 2ec694de 0.008988128886376484 0.0
# e4d32835 0.0013001695873374789 0.0
# 611485c5 0.0013566986998304127 0.0
# ab4ec3a4 0.0009044657998869418 0.0
# 5000_g 0.0 0.0
# 5010_g 0.0 0.0
# 4021_g 0.0 0.0
# 4022_g 0.0 0.0
# 2010_g 0.0 0.0
# 2050_A 0.0 0.0
# 4100_A 0.0 0.0
# 2060_A 0.0 0.0
# 4110_A 0.0 0.0
# 2070_A 0.0 0.0
# 2075_A 0.0 0.0
# 2080_A 0.0 0.0
# 2081_A 0.0 0.0
# 2083_A 0.0 0.0
# 3120_A 0.0 0.0
# 3121_A 0.0 0.0
# 4220_A 0.0 0.0
# 4230_A 0.0 0.0
# 4235_A 0.0 0.0
# 4010_A 0.0 0.0
# 4031_A 0.0 0.0
# 4040_A 0.0 0.0
# 3020_A 0.0 0.0
# 3021_A 0.0 0.0
# 4045_A 0.0 0.0
# 4050_A 0.0 0.0
# 2010_A 0.0007348784624081402 0.0
# 2025_A 0.0 0.0
# 2035_A 0.0 0.0
# 2040_A 0.0 0.0
# 4095_A 0.0 0.0
# Dino_Dive_4080 0.0002826455624646693 0.0
# Pan_Balance_4080 0.0013001695873374789 0.0
# Cart_Balancer__Assessment__4080 0.007292255511588468 0.0
# Fireworks__Activity__4080 0.0013566986998304127 0.0
# Crystals_Rule_2010 0.0 0.0
# Bottle_Filler__Activity__2010 0.0 0.0
# Air_Show_4080 0.0 0.0
# Egg_Dropper__Activity__4080 0.01978518937252685 0.0
# Sandcastle_Builder__Activity__2010 0.0 0.0
# Happy_Camel_4080 0.0008479366873940079 0.0
# Bubble_Bath_4080 0.004070096099491238 0.0
# Mushroom_Sorter__Assessment__4080 0.04392312040700961 0.0
# Scrub_A_Dub_4080 0.0 0.0
# Chest_Sorter__Assessment__4080 0.012832108535895986 0.0
# Bug_Measurer__Activity__4080 0.008988128886376484 0.0
# Pan_Balance_2010 0.0 0.0
# Dino_Drink_4080 0.0009044657998869418 0.0
# Leaf_Leader_4080 0.0004522328999434709 0.0
# Watering_Hole__Activity__2010 0.0007348784624081402 0.0
# Bubble_Bath_4090 0.14703222159412097 0.008 0.0
# Mushroom_Sorter__Assessment__4090 0.17382702091577162 0.008 0.0
# accumulated_accuracy_of_NONE 0.0 0.0
# NONE_duration_sum 0.0 0.0
# NONE_duration_mean 0.0 0.0
# NONE_duration_std 0.0 0.0

# %%
categoricals = [x for x in categoricals if x not in (to_exclude + to_remove)]
features = [x for x in features if x not in (to_exclude + to_remove)]
reduce_train[features].shape
# Out:
# (17690, 938)

# %% [markdown]
# ## Training Model

# %%
def eval_qwk_lgb_regr(y_true, y_pred):
    """
    Fast cappa eval function for lgb.
    """
    dist = Counter(reduce_train['accuracy_group'])
    for k in dist:
        dist[k] /= len(reduce_train)
    reduce_train['accuracy_group'].hist()
    
    acum = 0
    bound = {}
    for i in range(3):
        acum += dist[i]
        bound[i] = np.percentile(y_pred, acum * 100)

    def classify(x):
        if x <= bound[0]:
            return 0
        elif x <= bound[1]:
            return 1
        elif x <= bound[2]:
            return 2
        else:
            return 3

    y_pred = np.array(list(map(classify, y_pred))).reshape(y_true.shape)

    return 'cappa', cohen_kappa_score(y_true, y_pred, weights='quadratic'), True

# %%
def cohenkappa(ypred, y):
    y = y.get_label().astype("int")
    ypred = ypred.reshape((4, -1)).argmax(axis = 0)
    loss = cohenkappascore(y, y_pred, weights = 'quadratic')
    return "cappa", loss, True

# %%
class Base_Model(object):
    
    def __init__(self, train_df, test_df, features, categoricals=[], n_splits=5, verbose=True,ps={}):
        self.train_df = train_df
        self.test_df = test_df
        self.features = features
        self.n_splits = n_splits
        self.categoricals = categoricals
        self.target = 'accuracy_group'
        self.cv = self.get_cv()
        self.verbose = verbose
#         self.params = self.get_params()
        self.params = self.set_params(ps)
        self.oof_pred, self.y_pred, self.score, self.models = self.fit()
        
    def train_model(self, train_set, val_set):
        raise NotImplementedError
        
    def get_cv(self):
        method = 'StratifiedKFold'
        if method=='StratifiedKFold':
            cv = StratifiedKFold(n_splits=self.n_splits, shuffle=True, random_state=42)
            return cv.split(self.train_df, self.train_df[self.target])
        elif method=='GroupKFold':
            cv = GroupKFold(n_splits=self.n_splits)
            return cv.split(self.train_df, self.train_df[self.target], self.train_df['installation_id'])
    
    def get_params(self):
        raise NotImplementedError
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        raise NotImplementedError
        
    def convert_x(self, x):
        return x
        
    def fit(self):
        oof_pred = np.zeros((len(reduce_train), ))
        y_pred = np.zeros((len(reduce_test), ))
        models = []
        
        for fold, (train_idx, val_idx) in enumerate(self.cv):
            x_train, x_val = self.train_df[self.features].iloc[train_idx], self.train_df[self.features].iloc[val_idx]
            y_train, y_val = self.train_df[self.target][train_idx], self.train_df[self.target][val_idx]
            train_set, val_set = self.convert_dataset(x_train, y_train, x_val, y_val)
            model = self.train_model(train_set, val_set)
            models.append(model)
            
            conv_x_val = self.convert_x(x_val)
            oof_pred[val_idx] = model.predict(conv_x_val).reshape(oof_pred[val_idx].shape)
            x_test = self.convert_x(self.test_df[self.features])
            y_pred += model.predict(x_test).reshape(y_pred.shape) / self.n_splits
            print('Partial score of fold {} is: {}'.format(fold, eval_qwk_lgb_regr(y_val, oof_pred[val_idx])[1]))
        _, loss_score, _ = eval_qwk_lgb_regr(self.train_df[self.target], oof_pred)
        if self.verbose:
            print(f'\nOur oof cohen kappa score is: {loss_score}\n')
        return oof_pred, y_pred, loss_score, models

# %%
class Lgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = lgb.Dataset(x_train, y_train, categorical_feature=self.categoricals)
        val_set = lgb.Dataset(x_val, y_val, categorical_feature=self.categoricals)
        return train_set, val_set
        
    def get_params(self):
        params = {'n_estimators':5000,
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': 'rmse',
                    'subsample': 0.75,
                    'subsample_freq': 1,
                    'learning_rate': 0.01,
                    'feature_fraction': 0.9,
                    'max_depth': 15,
                    'lambda_l1': 1,  
                    'lambda_l2': 1,
                    'early_stopping_rounds': 100
                    }
        return params
    def set_params(self,ps={}):
        params = self.get_params()
        if 'subsample_freq' in ps:
            params['subsample_freq']=int(ps['subsample_freq'])
            params['learning_rate']=ps['learning_rate']
            params['feature_fraction']=ps['feature_fraction']
            params['lambda_l1']=ps['lambda_l1']
            params['lambda_l2']=ps['lambda_l2']
            params['max_depth']=int(ps['max_depth'])
        
        return params    
    
    def get_feature_importance(self, models):
        feature_importance = pd.DataFrame(
            [model.feature_importance() for model in models],
            columns=models[0].feature_name()
        ).T

        feature_importance['Agerage_Importance'] = feature_importance.iloc[:, :len(models)].mean(axis=1)
        feature_importance['importance_std'] = feature_importance.iloc[:, :len(models)].std(axis=1)

        feature_importance.sort_values(by='Agerage_Importance', inplace=True)
        return feature_importance
    
    def plot_importance(self, models, max_num_features=50, figsize=(12, 15)):
        feature_importance = self.get_feature_importance(models)
        plt.figure(figsize=figsize)
        
        feature_importance[-max_num_features:].plot(
            kind='barh', title='Feature importance', figsize=figsize,
            y='Agerage_Importance', xerr='importance_std',
            grid=True, align="center"
        )
        plt.legend()
        plt.show()

# %%
class Xgb_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return lgb.train(self.params, train_set, valid_sets=[train_set, val_set], verbose_eval=verbosity)
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set, 
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')], 
                         verbose_eval=verbosity, early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self):
        params = {'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000}
        return params
    
    def set_params(self, ps={}):
        return self.get_params()

# %%
class fuse_Model(Base_Model):
    
    def train_model(self, train_set, val_set):
        verbosity = 100 if self.verbose else 0
        return xgb.train(self.params, train_set, 
                         num_boost_round=5000, evals=[(train_set, 'train'), (val_set, 'val')], 
                         verbose_eval=verbosity, early_stopping_rounds=100)
        
    def convert_dataset(self, x_train, y_train, x_val, y_val):
        train_set = xgb.DMatrix(x_train, y_train)
        val_set = xgb.DMatrix(x_val, y_val)
        return train_set, val_set
    
    def convert_x(self, x):
        return xgb.DMatrix(x)
        
    def get_params(self):
        params = {'colsample_bytree': 0.8,                 
            'learning_rate': 0.01,
            'max_depth': 10,
            'subsample': 1,
            'objective':'reg:squarederror',
            #'eval_metric':'rmse',
            'min_child_weight':3,
            'gamma':0.25,
            'n_estimators':5000}
        return params
    
    def set_params(self, ps={}):
        return self.get_params()

# %%
def LGB_Beyes(subsample_freq,
                    learning_rate,
                    feature_fraction,
                    max_depth,
                    lambda_l1,
                    lambda_l2):
    params={}
    params['subsample_freq']=subsample_freq
    params['learning_rate']=learning_rate
    params['feature_fraction']=feature_fraction
    params['lambda_l1']=lambda_l1
    params['lambda_l2']=lambda_l2
    params['max_depth']=max_depth
    lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals,ps=params)
    print('kappa: ',lgb_model.score)
    return lgb_model.score

bounds_LGB = {
    'subsample_freq': (1, 10),
    'learning_rate': (0.025, 0.5),
    'feature_fraction': (0.5, 1),
    'lambda_l1': (0, 5),
    'lambda_l2': (0, 5),
    'max_depth': (15, 17),
}

LGB_BO = BayesianOptimization(LGB_Beyes, bounds_LGB, random_state=1029)
import warnings
init_points = 16
n_iter = 16
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    LGB_BO.maximize(init_points=init_points, n_iter=n_iter, acq='ucb', xi=0.0, alpha=1e-6)
    
print('\n', LGB_BO.max['params'])
# Out:
# |   iter    |  target   | featur... | lambda_l1 | lambda_l2 | learni... | max_depth | subsam... |
# -------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.614127	valid_1's rmse: 1.08048
# Early stopping, best iteration is:
# [16]	training's rmse: 0.887583	valid_1's rmse: 1.01991
# Partial score of fold 0 is: 0.5571372613775474
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.622887	valid_1's rmse: 1.06599
# Early stopping, best iteration is:
# [11]	training's rmse: 0.920221	valid_1's rmse: 1.01419
# Partial score of fold 1 is: 0.5700205410465642
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.622158	valid_1's rmse: 1.0728
# Early stopping, best iteration is:
# [14]	training's rmse: 0.900768	valid_1's rmse: 1.01396
# Partial score of fold 2 is: 0.5639367700917506
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.619479	valid_1's rmse: 1.05872
# Early stopping, best iteration is:
# [13]	training's rmse: 0.904377	valid_1's rmse: 1.00952
# Partial score of fold 3 is: 0.5730961375607961
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.62129	valid_1's rmse: 1.06133
# Early stopping, best iteration is:
# [12]	training's rmse: 0.912658	valid_1's rmse: 1.01038
# Partial score of fold 4 is: 0.5674977006686108
#
# Our oof cohen kappa score is: 0.5657188339178525
#
# kappa:  0.5657188339178525
# |  1        |  0.5657   |  0.5205   |  2.049    |  2.944    |  0.4525   |  15.24    |  2.532    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.703197	valid_1's rmse: 1.01591
# Early stopping, best iteration is:
# [19]	training's rmse: 0.905397	valid_1's rmse: 1.00312
# Partial score of fold 0 is: 0.5723466887645811
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.707635	valid_1's rmse: 1.00008
# Early stopping, best iteration is:
# [19]	training's rmse: 0.907455	valid_1's rmse: 0.987291
# Partial score of fold 1 is: 0.5863035750726826
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.707769	valid_1's rmse: 1.01573
# Early stopping, best iteration is:
# [27]	training's rmse: 0.878052	valid_1's rmse: 0.997316
# Partial score of fold 2 is: 0.5755675086818353
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.706902	valid_1's rmse: 1.0119
# Early stopping, best iteration is:
# [30]	training's rmse: 0.868744	valid_1's rmse: 0.996208
# Partial score of fold 3 is: 0.5823670173960386
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.709835	valid_1's rmse: 1.01404
# Early stopping, best iteration is:
# [20]	training's rmse: 0.903303	valid_1's rmse: 0.9975
# Partial score of fold 4 is: 0.5768045988954811
#
# Our oof cohen kappa score is: 0.5789970861526041
#
# kappa:  0.5789970861526041
# |  2        |  0.579    |  0.9701   |  2.977    |  1.678    |  0.2348   |  15.99    |  1.791    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9041	valid_1's rmse: 0.995686
# [200]	training's rmse: 0.835124	valid_1's rmse: 0.991336
# [300]	training's rmse: 0.784128	valid_1's rmse: 0.992388
# Early stopping, best iteration is:
# [202]	training's rmse: 0.833929	valid_1's rmse: 0.991307
# Partial score of fold 0 is: 0.5836195584749708
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.906746	valid_1's rmse: 0.985051
# [200]	training's rmse: 0.838388	valid_1's rmse: 0.981715
# Early stopping, best iteration is:
# [156]	training's rmse: 0.865235	valid_1's rmse: 0.980973
# Partial score of fold 1 is: 0.5990079203018519
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.904024	valid_1's rmse: 0.988689
# [200]	training's rmse: 0.83743	valid_1's rmse: 0.981767
# [300]	training's rmse: 0.787063	valid_1's rmse: 0.983219
# Early stopping, best iteration is:
# [202]	training's rmse: 0.836392	valid_1's rmse: 0.98168
# Partial score of fold 2 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.905795	valid_1's rmse: 0.985864
# [200]	training's rmse: 0.837938	valid_1's rmse: 0.981052
# Early stopping, best iteration is:
# [187]	training's rmse: 0.845776	valid_1's rmse: 0.980894
# Partial score of fold 3 is: 0.6000815269409366
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907064	valid_1's rmse: 0.989673
# [200]	training's rmse: 0.840173	valid_1's rmse: 0.984601
# Early stopping, best iteration is:
# [191]	training's rmse: 0.845485	valid_1's rmse: 0.984058
# Partial score of fold 4 is: 0.5861114971223516
#
# Our oof cohen kappa score is: 0.5925616618856793
#
# kappa:  0.5925616618856793
# |  3        |  0.5926   |  0.6371   |  3.3      |  0.4016   |  0.04336  |  16.35    |  2.686    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.682967	valid_1's rmse: 1.03658
# Early stopping, best iteration is:
# [24]	training's rmse: 0.874073	valid_1's rmse: 1.00972
# Partial score of fold 0 is: 0.5664836543017195
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.687313	valid_1's rmse: 1.02496
# Early stopping, best iteration is:
# [12]	training's rmse: 0.931561	valid_1's rmse: 0.996128
# Partial score of fold 1 is: 0.5786525341809696
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.689221	valid_1's rmse: 1.03265
# Early stopping, best iteration is:
# [17]	training's rmse: 0.904285	valid_1's rmse: 1.0019
# Partial score of fold 2 is: 0.5773568530803098
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.685297	valid_1's rmse: 1.02197
# Early stopping, best iteration is:
# [15]	training's rmse: 0.914247	valid_1's rmse: 0.997505
# Partial score of fold 3 is: 0.5925662804673435
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.694523	valid_1's rmse: 1.0233
# Early stopping, best iteration is:
# [31]	training's rmse: 0.855152	valid_1's rmse: 1.00366
# Partial score of fold 4 is: 0.5746568531508187
#
# Our oof cohen kappa score is: 0.5763128033558215
#
# kappa:  0.5763128033558215
# |  4        |  0.5763   |  0.9697   |  4.356    |  1.791    |  0.2947   |  16.76    |  5.072    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766418	valid_1's rmse: 1.00385
# Early stopping, best iteration is:
# [41]	training's rmse: 0.871534	valid_1's rmse: 0.998168
# Partial score of fold 0 is: 0.5735391817393867
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.770366	valid_1's rmse: 1.00288
# Early stopping, best iteration is:
# [43]	training's rmse: 0.871135	valid_1's rmse: 0.99134
# Partial score of fold 1 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.772056	valid_1's rmse: 0.999586
# Early stopping, best iteration is:
# [36]	training's rmse: 0.886637	valid_1's rmse: 0.990497
# Partial score of fold 2 is: 0.5859457061929877
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.76744	valid_1's rmse: 0.99634
# Early stopping, best iteration is:
# [60]	training's rmse: 0.834423	valid_1's rmse: 0.991596
# Partial score of fold 3 is: 0.5902401327493265
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771834	valid_1's rmse: 0.994905
# Early stopping, best iteration is:
# [65]	training's rmse: 0.826659	valid_1's rmse: 0.988098
# Partial score of fold 4 is: 0.5846796666259099
#
# Our oof cohen kappa score is: 0.5836856334376512
#
# kappa:  0.5836856334376512
# |  5        |  0.5837   |  0.8525   |  3.981    |  4.719    |  0.1693   |  16.82    |  5.5      |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.760864	valid_1's rmse: 1.01118
# Early stopping, best iteration is:
# [43]	training's rmse: 0.864642	valid_1's rmse: 1.00063
# Partial score of fold 0 is: 0.5714520165653438
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766826	valid_1's rmse: 0.993419
# Early stopping, best iteration is:
# [42]	training's rmse: 0.871299	valid_1's rmse: 0.988831
# Partial score of fold 1 is: 0.5895243949899367
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.76352	valid_1's rmse: 1.00121
# Early stopping, best iteration is:
# [49]	training's rmse: 0.854743	valid_1's rmse: 0.99437
# Partial score of fold 2 is: 0.5839774273546656
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.768836	valid_1's rmse: 0.998092
# Early stopping, best iteration is:
# [67]	training's rmse: 0.823968	valid_1's rmse: 0.99067
# Partial score of fold 3 is: 0.5886297227906995
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769121	valid_1's rmse: 0.999607
# Early stopping, best iteration is:
# [45]	training's rmse: 0.866121	valid_1's rmse: 0.995848
# Partial score of fold 4 is: 0.5843655090452924
#
# Our oof cohen kappa score is: 0.5830675859673672
#
# kappa:  0.5830675859673672
# |  6        |  0.5831   |  0.5194   |  1.336    |  0.582    |  0.1599   |  15.98    |  7.815    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.917698	valid_1's rmse: 0.998428
# [200]	training's rmse: 0.855444	valid_1's rmse: 0.991878
# [300]	training's rmse: 0.809061	valid_1's rmse: 0.99209
# Early stopping, best iteration is:
# [236]	training's rmse: 0.837389	valid_1's rmse: 0.991341
# Partial score of fold 0 is: 0.5855878373132928
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.919531	valid_1's rmse: 0.98353
# [200]	training's rmse: 0.857668	valid_1's rmse: 0.980445
# Early stopping, best iteration is:
# [166]	training's rmse: 0.875615	valid_1's rmse: 0.979668
# Partial score of fold 1 is: 0.5991868547416994
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.918696	valid_1's rmse: 0.99142
# [200]	training's rmse: 0.857775	valid_1's rmse: 0.981786
# [300]	training's rmse: 0.8112	valid_1's rmse: 0.981392
# Early stopping, best iteration is:
# [263]	training's rmse: 0.827736	valid_1's rmse: 0.980852
# Partial score of fold 2 is: 0.5948924281853605
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.920482	valid_1's rmse: 0.988949
# [200]	training's rmse: 0.857991	valid_1's rmse: 0.982348
# [300]	training's rmse: 0.812287	valid_1's rmse: 0.98208
# Early stopping, best iteration is:
# [292]	training's rmse: 0.815417	valid_1's rmse: 0.982034
# Partial score of fold 3 is: 0.5981132481026146
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.919738	valid_1's rmse: 0.990338
# [200]	training's rmse: 0.858568	valid_1's rmse: 0.980914
# [300]	training's rmse: 0.81285	valid_1's rmse: 0.979877
# Early stopping, best iteration is:
# [288]	training's rmse: 0.817603	valid_1's rmse: 0.979426
# Partial score of fold 4 is: 0.5959553317853874
#
# Our oof cohen kappa score is: 0.593850117628135
#
# kappa:  0.593850117628135
# |  7        |  0.5939   |  0.8534   |  2.64     |  4.351    |  0.03592  |  15.62    |  2.515    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769352	valid_1's rmse: 1.01204
# Early stopping, best iteration is:
# [31]	training's rmse: 0.897541	valid_1's rmse: 0.998627
# Partial score of fold 0 is: 0.5719888198848861
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.77475	valid_1's rmse: 0.995243
# Early stopping, best iteration is:
# [37]	training's rmse: 0.888328	valid_1's rmse: 0.988763
# Partial score of fold 1 is: 0.5913137393884114
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.773198	valid_1's rmse: 0.998626
# Early stopping, best iteration is:
# [73]	training's rmse: 0.813177	valid_1's rmse: 0.994831
# Partial score of fold 2 is: 0.5873771817117673
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.776391	valid_1's rmse: 0.999095
# Early stopping, best iteration is:
# [37]	training's rmse: 0.888728	valid_1's rmse: 0.992238
# Partial score of fold 3 is: 0.5834406240351233
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.776951	valid_1's rmse: 0.999759
# Early stopping, best iteration is:
# [32]	training's rmse: 0.89829	valid_1's rmse: 0.991416
# Partial score of fold 4 is: 0.5780574505798675
#
# Our oof cohen kappa score is: 0.5812160932646112
#
# kappa:  0.5812160932646112
# |  8        |  0.5812   |  0.713    |  3.884    |  2.672    |  0.1635   |  15.94    |  7.059    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.740693	valid_1's rmse: 1.01412
# Early stopping, best iteration is:
# [36]	training's rmse: 0.871114	valid_1's rmse: 1.00061
# Partial score of fold 0 is: 0.5764621808810726
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.747653	valid_1's rmse: 1.00513
# Early stopping, best iteration is:
# [34]	training's rmse: 0.880538	valid_1's rmse: 0.994475
# Partial score of fold 1 is: 0.5884507883508521
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.742413	valid_1's rmse: 1.01369
# Early stopping, best iteration is:
# [30]	training's rmse: 0.88763	valid_1's rmse: 0.995391
# Partial score of fold 2 is: 0.5759253775615302
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.752855	valid_1's rmse: 0.997386
# Early stopping, best iteration is:
# [40]	training's rmse: 0.866382	valid_1's rmse: 0.989987
# Partial score of fold 3 is: 0.5907769360688689
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.75027	valid_1's rmse: 1.0052
# Early stopping, best iteration is:
# [33]	training's rmse: 0.881927	valid_1's rmse: 0.998304
# Partial score of fold 4 is: 0.5773415353316467
#
# Our oof cohen kappa score is: 0.5820034828850007
#
# kappa:  0.5820034828850007
# |  9        |  0.582    |  0.6277   |  3.202    |  3.754    |  0.2022   |  15.32    |  9.341    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.747626	valid_1's rmse: 1.01313
# Early stopping, best iteration is:
# [28]	training's rmse: 0.892862	valid_1's rmse: 1.00265
# Partial score of fold 0 is: 0.5701994754864116
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.752791	valid_1's rmse: 1.00612
# Early stopping, best iteration is:
# [30]	training's rmse: 0.893558	valid_1's rmse: 0.989585
# Partial score of fold 1 is: 0.5895243949899367
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.753144	valid_1's rmse: 1.01081
# Early stopping, best iteration is:
# [29]	training's rmse: 0.895195	valid_1's rmse: 0.999695
# Partial score of fold 2 is: 0.5748517709224454
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.753375	valid_1's rmse: 1.00018
# Early stopping, best iteration is:
# [27]	training's rmse: 0.903123	valid_1's rmse: 0.992757
# Partial score of fold 3 is: 0.5886297227906995
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.758865	valid_1's rmse: 0.997513
# Early stopping, best iteration is:
# [44]	training's rmse: 0.85956	valid_1's rmse: 0.990043
# Partial score of fold 4 is: 0.5823529420691923
#
# Our oof cohen kappa score is: 0.5817171593866772
#
# kappa:  0.5817171593866772
# |  10       |  0.5817   |  0.9993   |  0.5259   |  4.569    |  0.1726   |  15.95    |  9.381    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.600732	valid_1's rmse: 1.09561
# Early stopping, best iteration is:
# [9]	training's rmse: 0.919251	valid_1's rmse: 1.01569
# Partial score of fold 0 is: 0.5592844746557168
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.601661	valid_1's rmse: 1.07675
# Early stopping, best iteration is:
# [7]	training's rmse: 0.942111	valid_1's rmse: 1.00615
# Partial score of fold 1 is: 0.568410131087937
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.594995	valid_1's rmse: 1.08047
# Early stopping, best iteration is:
# [9]	training's rmse: 0.924941	valid_1's rmse: 1.01387
# Partial score of fold 2 is: 0.5578529991369372
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.597911	valid_1's rmse: 1.08228
# Early stopping, best iteration is:
# [7]	training's rmse: 0.943892	valid_1's rmse: 1.00953
# Partial score of fold 3 is: 0.5745054861116508
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.600094	valid_1's rmse: 1.07293
# Early stopping, best iteration is:
# [8]	training's rmse: 0.935314	valid_1's rmse: 1.01141
# Partial score of fold 4 is: 0.5655586182363797
#
# Our oof cohen kappa score is: 0.5656997332368175
#
# kappa:  0.5656997332368175
# |  11       |  0.5657   |  0.9364   |  0.2751   |  4.832    |  0.4788   |  15.14    |  5.325    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.761654	valid_1's rmse: 1.00273
# Early stopping, best iteration is:
# [44]	training's rmse: 0.864161	valid_1's rmse: 0.996813
# Partial score of fold 0 is: 0.5728834920841235
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.771194	valid_1's rmse: 1.0006
# Early stopping, best iteration is:
# [46]	training's rmse: 0.865794	valid_1's rmse: 0.995713
# Partial score of fold 1 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766939	valid_1's rmse: 1.00503
# Early stopping, best iteration is:
# [35]	training's rmse: 0.889812	valid_1's rmse: 0.997582
# Partial score of fold 2 is: 0.5771779186404624
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.767089	valid_1's rmse: 0.999905
# Early stopping, best iteration is:
# [29]	training's rmse: 0.906475	valid_1's rmse: 0.994571
# Partial score of fold 3 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.76843	valid_1's rmse: 0.988742
# Early stopping, best iteration is:
# [73]	training's rmse: 0.8122	valid_1's rmse: 0.986225
# Partial score of fold 4 is: 0.5925547343563387
#
# Our oof cohen kappa score is: 0.582432968132486
#
# kappa:  0.582432968132486
# |  12       |  0.5824   |  0.755    |  1.843    |  2.172    |  0.1569   |  15.63    |  6.525    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.682577	valid_1's rmse: 1.04078
# Early stopping, best iteration is:
# [12]	training's rmse: 0.931601	valid_1's rmse: 1.011
# Partial score of fold 0 is: 0.5648314422909879
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.687948	valid_1's rmse: 1.02776
# Early stopping, best iteration is:
# [17]	training's rmse: 0.910008	valid_1's rmse: 0.995529
# Partial score of fold 1 is: 0.5829910548006332
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.685904	valid_1's rmse: 1.023
# Early stopping, best iteration is:
# [20]	training's rmse: 0.896507	valid_1's rmse: 0.99914
# Partial score of fold 2 is: 0.5787883285990895
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.687732	valid_1's rmse: 1.03139
# Early stopping, best iteration is:
# [14]	training's rmse: 0.923591	valid_1's rmse: 1.00278
# Partial score of fold 3 is: 0.576626584588078
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.688279	valid_1's rmse: 1.01962
# Early stopping, best iteration is:
# [24]	training's rmse: 0.879997	valid_1's rmse: 0.998415
# Partial score of fold 4 is: 0.5748358319628739
#
# Our oof cohen kappa score is: 0.5750243476133658
#
# kappa:  0.5750243476133658
# |  13       |  0.575    |  0.6994   |  1.488    |  3.371    |  0.2804   |  16.9     |  5.218    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.739138	valid_1's rmse: 1.0091
# Early stopping, best iteration is:
# [54]	training's rmse: 0.826405	valid_1's rmse: 0.999232
# Partial score of fold 0 is: 0.5728834920841235
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.743778	valid_1's rmse: 1.00564
# Early stopping, best iteration is:
# [31]	training's rmse: 0.888825	valid_1's rmse: 0.992442
# Partial score of fold 1 is: 0.5891665261102419
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.743315	valid_1's rmse: 1.00955
# Early stopping, best iteration is:
# [33]	training's rmse: 0.880898	valid_1's rmse: 0.996118
# Partial score of fold 2 is: 0.5798619352381742
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.746478	valid_1's rmse: 1.00398
# Early stopping, best iteration is:
# [33]	training's rmse: 0.883966	valid_1's rmse: 0.996106
# Partial score of fold 3 is: 0.5850510339937505
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.750491	valid_1's rmse: 1.00868
# Early stopping, best iteration is:
# [35]	training's rmse: 0.876126	valid_1's rmse: 0.995144
# Partial score of fold 4 is: 0.5825319208812475
#
# Our oof cohen kappa score is: 0.5817171593866772
#
# kappa:  0.5817171593866772
# |  14       |  0.5817   |  0.6269   |  0.9706   |  4.516    |  0.1912   |  16.35    |  5.414    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.766384	valid_1's rmse: 1.0119
# Early stopping, best iteration is:
# [29]	training's rmse: 0.901543	valid_1's rmse: 1.00206
# Partial score of fold 0 is: 0.568410131087937
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769331	valid_1's rmse: 1.00079
# Early stopping, best iteration is:
# [31]	training's rmse: 0.901068	valid_1's rmse: 0.989952
# Partial score of fold 1 is: 0.5891665261102419
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.769291	valid_1's rmse: 0.998949
# Early stopping, best iteration is:
# [70]	training's rmse: 0.817085	valid_1's rmse: 0.994489
# Partial score of fold 2 is: 0.5803987385577165
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.770795	valid_1's rmse: 1.00381
# Early stopping, best iteration is:
# [45]	training's rmse: 0.868384	valid_1's rmse: 0.994541
# Partial score of fold 3 is: 0.5884507883508521
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.770433	valid_1's rmse: 0.993545
# Early stopping, best iteration is:
# [51]	training's rmse: 0.853919	valid_1's rmse: 0.990818
# Partial score of fold 4 is: 0.5837847725656339
#
# Our oof cohen kappa score is: 0.582110854196872
#
# kappa:  0.582110854196872
# |  15       |  0.5821   |  0.853    |  1.536    |  0.4828   |  0.1487   |  15.64    |  7.365    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.670166	valid_1's rmse: 1.04692
# Early stopping, best iteration is:
# [17]	training's rmse: 0.902895	valid_1's rmse: 1.01165
# Partial score of fold 0 is: 0.5659050489300727
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.673139	valid_1's rmse: 1.02848
# Early stopping, best iteration is:
# [15]	training's rmse: 0.917039	valid_1's rmse: 0.995839
# Partial score of fold 1 is: 0.582903820715581
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.675244	valid_1's rmse: 1.03054
# Early stopping, best iteration is:
# [18]	training's rmse: 0.902416	valid_1's rmse: 1.00023
# Partial score of fold 2 is: 0.5714520165653438
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.67999	valid_1's rmse: 1.03375
# Early stopping, best iteration is:
# [18]	training's rmse: 0.902144	valid_1's rmse: 1.00288
# Partial score of fold 3 is: 0.5746728364825979
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.675211	valid_1's rmse: 1.03115
# Early stopping, best iteration is:
# [18]	training's rmse: 0.89847	valid_1's rmse: 1.00385
# Partial score of fold 4 is: 0.5752365861173467
#
# Our oof cohen kappa score is: 0.5734137779352961
#
# kappa:  0.5734137779352961
# |  16       |  0.5734   |  0.6327   |  1.826    |  1.33     |  0.2994   |  15.89    |  7.747    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.877113	valid_1's rmse: 0.993002
# [200]	training's rmse: 0.803094	valid_1's rmse: 0.99113
# [300]	training's rmse: 0.746906	valid_1's rmse: 0.994211
# Early stopping, best iteration is:
# [217]	training's rmse: 0.792491	valid_1's rmse: 0.990706
# Partial score of fold 0 is: 0.5889875916703944
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.879591	valid_1's rmse: 0.980626
# [200]	training's rmse: 0.805733	valid_1's rmse: 0.9823
# Early stopping, best iteration is:
# [103]	training's rmse: 0.876948	valid_1's rmse: 0.980239
# Partial score of fold 1 is: 0.5991868547416994
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.880717	valid_1's rmse: 0.986162
# [200]	training's rmse: 0.80628	valid_1's rmse: 0.986045
# Early stopping, best iteration is:
# [140]	training's rmse: 0.847839	valid_1's rmse: 0.984903
# Partial score of fold 2 is: 0.5873771817117673
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.880675	valid_1's rmse: 0.983117
# [200]	training's rmse: 0.806107	valid_1's rmse: 0.98369
# Early stopping, best iteration is:
# [168]	training's rmse: 0.827275	valid_1's rmse: 0.981758
# Partial score of fold 3 is: 0.6000815269409366
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.880856	valid_1's rmse: 0.987552
# [200]	training's rmse: 0.80672	valid_1's rmse: 0.984701
# Early stopping, best iteration is:
# [182]	training's rmse: 0.818272	valid_1's rmse: 0.984111
# Partial score of fold 4 is: 0.5895120945514003
#
# Our oof cohen kappa score is: 0.5921321766381942
#
# kappa:  0.5921321766381942
# |  17       |  0.5921   |  0.808    |  4.751    |  4.826    |  0.06193  |  16.88    |  1.226    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.895375	valid_1's rmse: 0.995584
# [200]	training's rmse: 0.828227	valid_1's rmse: 0.993928
# Early stopping, best iteration is:
# [129]	training's rmse: 0.872308	valid_1's rmse: 0.9932
# Partial score of fold 0 is: 0.5768200497607674
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.897306	valid_1's rmse: 0.98351
# [200]	training's rmse: 0.829004	valid_1's rmse: 0.981946
# Early stopping, best iteration is:
# [150]	training's rmse: 0.859311	valid_1's rmse: 0.980124
# Partial score of fold 1 is: 0.5966817725838349
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.898555	valid_1's rmse: 0.989595
# [200]	training's rmse: 0.82993	valid_1's rmse: 0.986095
# Early stopping, best iteration is:
# [148]	training's rmse: 0.861892	valid_1's rmse: 0.985695
# Partial score of fold 2 is: 0.5914926738282588
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.898691	valid_1's rmse: 0.985026
# [200]	training's rmse: 0.83097	valid_1's rmse: 0.984993
# Early stopping, best iteration is:
# [166]	training's rmse: 0.851567	valid_1's rmse: 0.983524
# Partial score of fold 3 is: 0.5957871003845977
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.898387	valid_1's rmse: 0.985027
# [200]	training's rmse: 0.832315	valid_1's rmse: 0.981013
# Early stopping, best iteration is:
# [198]	training's rmse: 0.833568	valid_1's rmse: 0.980879
# Partial score of fold 4 is: 0.5907649462357867
#
# Our oof cohen kappa score is: 0.589564134813868
#
# kappa:  0.589564134813868
# |  18       |  0.5896   |  0.9871   |  4.887    |  0.08303  |  0.04836  |  16.95    |  9.367    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.893053	valid_1's rmse: 0.994743
# [200]	training's rmse: 0.821605	valid_1's rmse: 0.991056
# Early stopping, best iteration is:
# [154]	training's rmse: 0.851524	valid_1's rmse: 0.990534
# Partial score of fold 0 is: 0.5771779186404624
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.895746	valid_1's rmse: 0.98143
# [200]	training's rmse: 0.82388	valid_1's rmse: 0.981747
# Early stopping, best iteration is:
# [118]	training's rmse: 0.88043	valid_1's rmse: 0.981336
# Partial score of fold 1 is: 0.5966817725838349
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.896728	valid_1's rmse: 0.98794
# [200]	training's rmse: 0.825419	valid_1's rmse: 0.982597
# Early stopping, best iteration is:
# [189]	training's rmse: 0.832064	valid_1's rmse: 0.982314
# Partial score of fold 2 is: 0.592387346027496
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.896748	valid_1's rmse: 0.985245
# [200]	training's rmse: 0.825722	valid_1's rmse: 0.981664
# [300]	training's rmse: 0.772305	valid_1's rmse: 0.983224
# Early stopping, best iteration is:
# [212]	training's rmse: 0.818873	valid_1's rmse: 0.981091
# Partial score of fold 3 is: 0.5979343136627672
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.8966	valid_1's rmse: 0.988251
# [200]	training's rmse: 0.82633	valid_1's rmse: 0.982016
# [300]	training's rmse: 0.773392	valid_1's rmse: 0.981938
# Early stopping, best iteration is:
# [218]	training's rmse: 0.816117	valid_1's rmse: 0.981195
# Partial score of fold 4 is: 0.5879012852429035
#
# Our oof cohen kappa score is: 0.5906289782719958
#
# kappa:  0.5906289782719958
# |  19       |  0.5906   |  0.9262   |  0.01456  |  0.8396   |  0.04301  |  16.92    |  1.265    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95552	valid_1's rmse: 1.01165
# [200]	training's rmse: 0.895599	valid_1's rmse: 0.994243
# [300]	training's rmse: 0.858711	valid_1's rmse: 0.991037
# [400]	training's rmse: 0.828395	valid_1's rmse: 0.990768
# Early stopping, best iteration is:
# [367]	training's rmse: 0.837927	valid_1's rmse: 0.989992
# Partial score of fold 0 is: 0.5836195584749708
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.957928	valid_1's rmse: 0.99962
# [200]	training's rmse: 0.898879	valid_1's rmse: 0.98151
# [300]	training's rmse: 0.861005	valid_1's rmse: 0.979158
# [400]	training's rmse: 0.830935	valid_1's rmse: 0.979467
# Early stopping, best iteration is:
# [366]	training's rmse: 0.840801	valid_1's rmse: 0.978726
# Partial score of fold 1 is: 0.59703964146353
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.956034	valid_1's rmse: 1.00631
# [200]	training's rmse: 0.897231	valid_1's rmse: 0.986138
# [300]	training's rmse: 0.859937	valid_1's rmse: 0.981961
# [400]	training's rmse: 0.829974	valid_1's rmse: 0.981669
# Early stopping, best iteration is:
# [328]	training's rmse: 0.851232	valid_1's rmse: 0.98142
# Partial score of fold 2 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.957744	valid_1's rmse: 1.00313
# [200]	training's rmse: 0.899354	valid_1's rmse: 0.981652
# [300]	training's rmse: 0.861816	valid_1's rmse: 0.978872
# [400]	training's rmse: 0.831444	valid_1's rmse: 0.977712
# Early stopping, best iteration is:
# [373]	training's rmse: 0.839043	valid_1's rmse: 0.977616
# Partial score of fold 3 is: 0.6040180846175807
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.957341	valid_1's rmse: 1.00442
# [200]	training's rmse: 0.899532	valid_1's rmse: 0.987501
# [300]	training's rmse: 0.862365	valid_1's rmse: 0.982925
# [400]	training's rmse: 0.831888	valid_1's rmse: 0.982534
# [500]	training's rmse: 0.805372	valid_1's rmse: 0.981826
# [600]	training's rmse: 0.781556	valid_1's rmse: 0.981767
# Early stopping, best iteration is:
# [582]	training's rmse: 0.785801	valid_1's rmse: 0.981491
# Partial score of fold 4 is: 0.5871853699946827
#
# Our oof cohen kappa score is: 0.5930627280077454
#
# kappa:  0.5930627280077454
# |  20       |  0.5931   |  0.6298   |  4.94     |  4.81     |  0.02538  |  15.14    |  2.719    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.950863	valid_1's rmse: 1.01008
# [200]	training's rmse: 0.890511	valid_1's rmse: 0.993733
# [300]	training's rmse: 0.851754	valid_1's rmse: 0.990557
# [400]	training's rmse: 0.820345	valid_1's rmse: 0.989941
# [500]	training's rmse: 0.792784	valid_1's rmse: 0.989501
# [600]	training's rmse: 0.767772	valid_1's rmse: 0.990397
# Early stopping, best iteration is:
# [507]	training's rmse: 0.791023	valid_1's rmse: 0.989366
# Partial score of fold 0 is: 0.5861246406328351
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952953	valid_1's rmse: 0.999749
# [200]	training's rmse: 0.892724	valid_1's rmse: 0.982199
# [300]	training's rmse: 0.853919	valid_1's rmse: 0.980328
# Early stopping, best iteration is:
# [241]	training's rmse: 0.87553	valid_1's rmse: 0.980068
# Partial score of fold 1 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95419	valid_1's rmse: 1.00742
# [200]	training's rmse: 0.892483	valid_1's rmse: 0.98811
# [300]	training's rmse: 0.853737	valid_1's rmse: 0.984221
# [400]	training's rmse: 0.822199	valid_1's rmse: 0.984282
# [500]	training's rmse: 0.794151	valid_1's rmse: 0.98481
# Early stopping, best iteration is:
# [438]	training's rmse: 0.81134	valid_1's rmse: 0.98404
# Partial score of fold 2 is: 0.5893454605500893
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955668	valid_1's rmse: 1.00488
# [200]	training's rmse: 0.894485	valid_1's rmse: 0.983457
# [300]	training's rmse: 0.855613	valid_1's rmse: 0.980371
# [400]	training's rmse: 0.823019	valid_1's rmse: 0.980024
# [500]	training's rmse: 0.795452	valid_1's rmse: 0.980448
# Early stopping, best iteration is:
# [440]	training's rmse: 0.81153	valid_1's rmse: 0.979817
# Partial score of fold 3 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953895	valid_1's rmse: 1.00428
# [200]	training's rmse: 0.895245	valid_1's rmse: 0.986482
# [300]	training's rmse: 0.856723	valid_1's rmse: 0.981757
# [400]	training's rmse: 0.8252	valid_1's rmse: 0.981826
# Early stopping, best iteration is:
# [347]	training's rmse: 0.841126	valid_1's rmse: 0.980969
# Partial score of fold 4 is: 0.592912691980449
#
# Our oof cohen kappa score is: 0.5925616618856793
#
# kappa:  0.5925616618856793
# |  21       |  0.5926   |  0.5794   |  4.887    |  0.37     |  0.02603  |  16.84    |  1.09     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.910856	valid_1's rmse: 0.998463
# [200]	training's rmse: 0.846927	valid_1's rmse: 0.991509
# [300]	training's rmse: 0.799686	valid_1's rmse: 0.991856
# Early stopping, best iteration is:
# [222]	training's rmse: 0.835768	valid_1's rmse: 0.990556
# Partial score of fold 0 is: 0.5780725908396996
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.913177	valid_1's rmse: 0.981789
# [200]	training's rmse: 0.848848	valid_1's rmse: 0.979792
# [300]	training's rmse: 0.800279	valid_1's rmse: 0.979244
# Early stopping, best iteration is:
# [261]	training's rmse: 0.818373	valid_1's rmse: 0.978625
# Partial score of fold 1 is: 0.5966817725838349
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.913434	valid_1's rmse: 0.989821
# [200]	training's rmse: 0.849531	valid_1's rmse: 0.982198
# Early stopping, best iteration is:
# [197]	training's rmse: 0.851127	valid_1's rmse: 0.982017
# Partial score of fold 2 is: 0.5938188215462756
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.915155	valid_1's rmse: 0.987017
# [200]	training's rmse: 0.850929	valid_1's rmse: 0.98134
# [300]	training's rmse: 0.803134	valid_1's rmse: 0.981638
# Early stopping, best iteration is:
# [212]	training's rmse: 0.844606	valid_1's rmse: 0.981036
# Partial score of fold 3 is: 0.59703964146353
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.913829	valid_1's rmse: 0.988564
# [200]	training's rmse: 0.850318	valid_1's rmse: 0.982028
# [300]	training's rmse: 0.803052	valid_1's rmse: 0.980809
# Early stopping, best iteration is:
# [299]	training's rmse: 0.803368	valid_1's rmse: 0.980758
# Partial score of fold 4 is: 0.594702480101001
#
# Our oof cohen kappa score is: 0.5914163678923854
#
# kappa:  0.5914163678923854
# |  22       |  0.5914   |  0.9444   |  0.9617   |  4.968    |  0.03694  |  16.74    |  1.15     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.949878	valid_1's rmse: 1.00766
# [200]	training's rmse: 0.892617	valid_1's rmse: 0.996026
# [300]	training's rmse: 0.856094	valid_1's rmse: 0.993967
# [400]	training's rmse: 0.82525	valid_1's rmse: 0.992964
# Early stopping, best iteration is:
# [386]	training's rmse: 0.829184	valid_1's rmse: 0.992617
# Partial score of fold 0 is: 0.582545951835886
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953323	valid_1's rmse: 0.996301
# [200]	training's rmse: 0.895708	valid_1's rmse: 0.981507
# [300]	training's rmse: 0.858347	valid_1's rmse: 0.98191
# Early stopping, best iteration is:
# [244]	training's rmse: 0.878014	valid_1's rmse: 0.98041
# Partial score of fold 1 is: 0.6011551335800214
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.951275	valid_1's rmse: 1.00377
# [200]	training's rmse: 0.89556	valid_1's rmse: 0.987323
# [300]	training's rmse: 0.858115	valid_1's rmse: 0.984996
# [400]	training's rmse: 0.827607	valid_1's rmse: 0.984475
# [500]	training's rmse: 0.800769	valid_1's rmse: 0.985452
# Early stopping, best iteration is:
# [405]	training's rmse: 0.82631	valid_1's rmse: 0.9843
# Partial score of fold 2 is: 0.592745214907191
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953725	valid_1's rmse: 0.998611
# [200]	training's rmse: 0.896908	valid_1's rmse: 0.983087
# [300]	training's rmse: 0.860637	valid_1's rmse: 0.980709
# Early stopping, best iteration is:
# [294]	training's rmse: 0.862595	valid_1's rmse: 0.980382
# Partial score of fold 3 is: 0.5984711169823096
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952855	valid_1's rmse: 1.00074
# [200]	training's rmse: 0.897289	valid_1's rmse: 0.986806
# [300]	training's rmse: 0.860583	valid_1's rmse: 0.983515
# [400]	training's rmse: 0.829972	valid_1's rmse: 0.982518
# Early stopping, best iteration is:
# [376]	training's rmse: 0.837177	valid_1's rmse: 0.982322
# Partial score of fold 4 is: 0.5880802640549587
#
# Our oof cohen kappa score is: 0.5928837758212933
#
# kappa:  0.5928837758212933
# |  23       |  0.5929   |  0.7514   |  4.726    |  4.92     |  0.02579  |  15.21    |  9.69     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.931814	valid_1's rmse: 1.00375
# [200]	training's rmse: 0.870313	valid_1's rmse: 0.995239
# [300]	training's rmse: 0.826781	valid_1's rmse: 0.99311
# [400]	training's rmse: 0.790117	valid_1's rmse: 0.993303
# Early stopping, best iteration is:
# [374]	training's rmse: 0.799151	valid_1's rmse: 0.992802
# Partial score of fold 0 is: 0.5778936563998522
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.93428	valid_1's rmse: 0.989894
# [200]	training's rmse: 0.873146	valid_1's rmse: 0.980129
# [300]	training's rmse: 0.829403	valid_1's rmse: 0.979318
# Early stopping, best iteration is:
# [263]	training's rmse: 0.844349	valid_1's rmse: 0.979067
# Partial score of fold 1 is: 0.6011551335800214
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.93501	valid_1's rmse: 0.99909
# [200]	training's rmse: 0.873632	valid_1's rmse: 0.984917
# [300]	training's rmse: 0.830706	valid_1's rmse: 0.982776
# [400]	training's rmse: 0.793609	valid_1's rmse: 0.983401
# Early stopping, best iteration is:
# [310]	training's rmse: 0.826708	valid_1's rmse: 0.982311
# Partial score of fold 2 is: 0.5918505427079537
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.937533	valid_1's rmse: 0.997435
# [200]	training's rmse: 0.875128	valid_1's rmse: 0.984904
# [300]	training's rmse: 0.831605	valid_1's rmse: 0.983445
# [400]	training's rmse: 0.79445	valid_1's rmse: 0.983024
# Early stopping, best iteration is:
# [395]	training's rmse: 0.796181	valid_1's rmse: 0.982859
# Partial score of fold 3 is: 0.59703964146353
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.934892	valid_1's rmse: 0.995065
# [200]	training's rmse: 0.874273	valid_1's rmse: 0.985132
# [300]	training's rmse: 0.83132	valid_1's rmse: 0.982302
# [400]	training's rmse: 0.79537	valid_1's rmse: 0.981812
# [500]	training's rmse: 0.763055	valid_1's rmse: 0.981646
# Early stopping, best iteration is:
# [440]	training's rmse: 0.781507	valid_1's rmse: 0.981138
# Partial score of fold 4 is: 0.5911229038598971
#
# Our oof cohen kappa score is: 0.5919174340144515
#
# kappa:  0.5919174340144515
# |  24       |  0.5919   |  0.8756   |  0.5708   |  0.261    |  0.02726  |  15.03    |  1.385    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953207	valid_1's rmse: 1.01197
# [200]	training's rmse: 0.892043	valid_1's rmse: 0.994754
# [300]	training's rmse: 0.853458	valid_1's rmse: 0.992039
# [400]	training's rmse: 0.821723	valid_1's rmse: 0.991846
# Early stopping, best iteration is:
# [391]	training's rmse: 0.824359	valid_1's rmse: 0.991486
# Partial score of fold 0 is: 0.5818302140764962
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.956983	valid_1's rmse: 1.00358
# [200]	training's rmse: 0.895535	valid_1's rmse: 0.984867
# [300]	training's rmse: 0.856838	valid_1's rmse: 0.982329
# [400]	training's rmse: 0.824713	valid_1's rmse: 0.982683
# Early stopping, best iteration is:
# [339]	training's rmse: 0.843341	valid_1's rmse: 0.981715
# Partial score of fold 1 is: 0.600260461380784
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95397	valid_1's rmse: 1.00818
# [200]	training's rmse: 0.893266	valid_1's rmse: 0.986878
# [300]	training's rmse: 0.855262	valid_1's rmse: 0.984722
# [400]	training's rmse: 0.823534	valid_1's rmse: 0.984222
# Early stopping, best iteration is:
# [374]	training's rmse: 0.831267	valid_1's rmse: 0.983876
# Partial score of fold 2 is: 0.5925662804673435
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955979	valid_1's rmse: 1.00572
# [200]	training's rmse: 0.894956	valid_1's rmse: 0.985526
# [300]	training's rmse: 0.856897	valid_1's rmse: 0.982409
# [400]	training's rmse: 0.825256	valid_1's rmse: 0.982231
# [500]	training's rmse: 0.79728	valid_1's rmse: 0.982448
# Early stopping, best iteration is:
# [451]	training's rmse: 0.810445	valid_1's rmse: 0.981997
# Partial score of fold 3 is: 0.5979343136627672
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955454	valid_1's rmse: 1.00697
# [200]	training's rmse: 0.89499	valid_1's rmse: 0.987336
# [300]	training's rmse: 0.856538	valid_1's rmse: 0.983598
# [400]	training's rmse: 0.825495	valid_1's rmse: 0.98409
# Early stopping, best iteration is:
# [327]	training's rmse: 0.848014	valid_1's rmse: 0.983119
# Partial score of fold 4 is: 0.5893331157393451
#
# Our oof cohen kappa score is: 0.5919890148890323
#
# kappa:  0.5919890148890323
# |  25       |  0.592    |  0.5337   |  3.979    |  4.994    |  0.0267   |  16.85    |  9.588    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.931746	valid_1's rmse: 1.00385
# [200]	training's rmse: 0.872412	valid_1's rmse: 0.99338
# [300]	training's rmse: 0.830021	valid_1's rmse: 0.991666
# [400]	training's rmse: 0.794626	valid_1's rmse: 0.990946
# Early stopping, best iteration is:
# [341]	training's rmse: 0.814566	valid_1's rmse: 0.990411
# Partial score of fold 0 is: 0.5802198041178691
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.934129	valid_1's rmse: 0.98854
# [200]	training's rmse: 0.875146	valid_1's rmse: 0.980409
# [300]	training's rmse: 0.832755	valid_1's rmse: 0.980638
# Early stopping, best iteration is:
# [240]	training's rmse: 0.857151	valid_1's rmse: 0.980009
# Partial score of fold 1 is: 0.5965028381439875
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.932093	valid_1's rmse: 0.99673
# [200]	training's rmse: 0.873444	valid_1's rmse: 0.985079
# [300]	training's rmse: 0.831392	valid_1's rmse: 0.98277
# Early stopping, best iteration is:
# [298]	training's rmse: 0.83219	valid_1's rmse: 0.982639
# Partial score of fold 2 is: 0.592745214907191
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.935685	valid_1's rmse: 0.988232
# [200]	training's rmse: 0.876173	valid_1's rmse: 0.978568
# [300]	training's rmse: 0.834427	valid_1's rmse: 0.977862
# Early stopping, best iteration is:
# [292]	training's rmse: 0.837344	valid_1's rmse: 0.977622
# Partial score of fold 3 is: 0.5973975103432247
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.934125	valid_1's rmse: 0.993601
# [200]	training's rmse: 0.875176	valid_1's rmse: 0.98285
# [300]	training's rmse: 0.833005	valid_1's rmse: 0.98144
# [400]	training's rmse: 0.79727	valid_1's rmse: 0.981628
# [500]	training's rmse: 0.766568	valid_1's rmse: 0.981153
# Early stopping, best iteration is:
# [442]	training's rmse: 0.783735	valid_1's rmse: 0.981067
# Partial score of fold 4 is: 0.5895120945514003
#
# Our oof cohen kappa score is: 0.5911300443940619
#
# kappa:  0.5911300443940619
# |  26       |  0.5911   |  0.9931   |  1.547    |  4.988    |  0.0292   |  15.0     |  2.429    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933051	valid_1's rmse: 1.0006
# [200]	training's rmse: 0.873728	valid_1's rmse: 0.991745
# [300]	training's rmse: 0.832537	valid_1's rmse: 0.98933
# Early stopping, best iteration is:
# [284]	training's rmse: 0.838315	valid_1's rmse: 0.988765
# Partial score of fold 0 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.936511	valid_1's rmse: 0.990689
# [200]	training's rmse: 0.877628	valid_1's rmse: 0.979943
# [300]	training's rmse: 0.836265	valid_1's rmse: 0.981218
# Early stopping, best iteration is:
# [235]	training's rmse: 0.862098	valid_1's rmse: 0.97936
# Partial score of fold 1 is: 0.5990079203018519
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9356	valid_1's rmse: 0.997997
# [200]	training's rmse: 0.877058	valid_1's rmse: 0.985978
# [300]	training's rmse: 0.836101	valid_1's rmse: 0.985727
# Early stopping, best iteration is:
# [232]	training's rmse: 0.863149	valid_1's rmse: 0.984941
# Partial score of fold 2 is: 0.5968607070236824
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938656	valid_1's rmse: 0.993467
# [200]	training's rmse: 0.878083	valid_1's rmse: 0.982625
# [300]	training's rmse: 0.837275	valid_1's rmse: 0.980806
# Early stopping, best iteration is:
# [273]	training's rmse: 0.847311	valid_1's rmse: 0.980664
# Partial score of fold 3 is: 0.6031234124183433
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.936176	valid_1's rmse: 0.995042
# [200]	training's rmse: 0.878507	valid_1's rmse: 0.984613
# [300]	training's rmse: 0.838196	valid_1's rmse: 0.98358
# [400]	training's rmse: 0.803784	valid_1's rmse: 0.983517
# Early stopping, best iteration is:
# [366]	training's rmse: 0.815278	valid_1's rmse: 0.982942
# Partial score of fold 4 is: 0.5896910733634555
#
# Our oof cohen kappa score is: 0.5947090881231054
#
# kappa:  0.5947090881231054
# |  27       |  0.5947   |  0.7039   |  4.626    |  0.1503   |  0.03073  |  15.17    |  9.802    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.952275	valid_1's rmse: 1.0103
# [200]	training's rmse: 0.891881	valid_1's rmse: 0.994164
# [300]	training's rmse: 0.853869	valid_1's rmse: 0.991146
# [400]	training's rmse: 0.82234	valid_1's rmse: 0.990968
# [500]	training's rmse: 0.794683	valid_1's rmse: 0.990811
# Early stopping, best iteration is:
# [453]	training's rmse: 0.807133	valid_1's rmse: 0.990245
# Partial score of fold 0 is: 0.5891665261102419
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.955012	valid_1's rmse: 0.999397
# [200]	training's rmse: 0.894497	valid_1's rmse: 0.981105
# [300]	training's rmse: 0.855824	valid_1's rmse: 0.980208
# Early stopping, best iteration is:
# [250]	training's rmse: 0.874008	valid_1's rmse: 0.979523
# Partial score of fold 1 is: 0.6006183302604791
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.953131	valid_1's rmse: 1.00553
# [200]	training's rmse: 0.893671	valid_1's rmse: 0.986148
# [300]	training's rmse: 0.85521	valid_1's rmse: 0.983958
# Early stopping, best iteration is:
# [253]	training's rmse: 0.871912	valid_1's rmse: 0.983774
# Partial score of fold 2 is: 0.5909558705087163
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.954467	valid_1's rmse: 1.00128
# [200]	training's rmse: 0.895355	valid_1's rmse: 0.982325
# [300]	training's rmse: 0.856989	valid_1's rmse: 0.979
# [400]	training's rmse: 0.825471	valid_1's rmse: 0.978281
# Early stopping, best iteration is:
# [378]	training's rmse: 0.83189	valid_1's rmse: 0.978095
# Partial score of fold 3 is: 0.6016919368995637
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.95483	valid_1's rmse: 1.00504
# [200]	training's rmse: 0.896143	valid_1's rmse: 0.986775
# [300]	training's rmse: 0.85783	valid_1's rmse: 0.981817
# [400]	training's rmse: 0.826465	valid_1's rmse: 0.980406
# [500]	training's rmse: 0.798777	valid_1's rmse: 0.980126
# [600]	training's rmse: 0.774181	valid_1's rmse: 0.979019
# Early stopping, best iteration is:
# [594]	training's rmse: 0.775588	valid_1's rmse: 0.978863
# Partial score of fold 4 is: 0.5916598402960627
#
# Our oof cohen kappa score is: 0.5944227646247819
#
# kappa:  0.5944227646247819
# |  28       |  0.5944   |  0.6355   |  4.964    |  0.1764   |  0.02532  |  15.1     |  1.852    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.936589	valid_1's rmse: 1.00469
# [200]	training's rmse: 0.875081	valid_1's rmse: 0.99353
# [300]	training's rmse: 0.83323	valid_1's rmse: 0.992855
# [400]	training's rmse: 0.798289	valid_1's rmse: 0.993224
# Early stopping, best iteration is:
# [341]	training's rmse: 0.818482	valid_1's rmse: 0.992393
# Partial score of fold 0 is: 0.5820091485163437
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.939527	valid_1's rmse: 0.995204
# [200]	training's rmse: 0.879417	valid_1's rmse: 0.983312
# [300]	training's rmse: 0.836989	valid_1's rmse: 0.981417
# Early stopping, best iteration is:
# [252]	training's rmse: 0.855456	valid_1's rmse: 0.980949
# Partial score of fold 1 is: 0.5950713626252079
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938128	valid_1's rmse: 0.998295
# [200]	training's rmse: 0.876666	valid_1's rmse: 0.984885
# [300]	training's rmse: 0.834943	valid_1's rmse: 0.982179
# [400]	training's rmse: 0.801059	valid_1's rmse: 0.983356
# Early stopping, best iteration is:
# [301]	training's rmse: 0.83464	valid_1's rmse: 0.982145
# Partial score of fold 2 is: 0.5931030837868858
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.939369	valid_1's rmse: 0.996474
# [200]	training's rmse: 0.877925	valid_1's rmse: 0.979534
# [300]	training's rmse: 0.836645	valid_1's rmse: 0.978706
# [400]	training's rmse: 0.801876	valid_1's rmse: 0.978908
# Early stopping, best iteration is:
# [338]	training's rmse: 0.822809	valid_1's rmse: 0.978326
# Partial score of fold 3 is: 0.6004393958206315
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.940342	valid_1's rmse: 0.999717
# [200]	training's rmse: 0.881006	valid_1's rmse: 0.987907
# [300]	training's rmse: 0.83906	valid_1's rmse: 0.984228
# [400]	training's rmse: 0.804542	valid_1's rmse: 0.985266
# Early stopping, best iteration is:
# [300]	training's rmse: 0.83906	valid_1's rmse: 0.984228
# Partial score of fold 4 is: 0.5866484335585171
#
# Our oof cohen kappa score is: 0.5910226730821906
#
# kappa:  0.5910226730821906
# |  29       |  0.591    |  0.548    |  4.883    |  0.3007   |  0.03132  |  15.18    |  4.424    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.902448	valid_1's rmse: 1.00121
# [200]	training's rmse: 0.834803	valid_1's rmse: 0.997553
# Early stopping, best iteration is:
# [189]	training's rmse: 0.84137	valid_1's rmse: 0.997136
# Partial score of fold 0 is: 0.5759253775615302
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.906354	valid_1's rmse: 0.984896
# [200]	training's rmse: 0.83816	valid_1's rmse: 0.98391
# Early stopping, best iteration is:
# [135]	training's rmse: 0.877452	valid_1's rmse: 0.981706
# Partial score of fold 1 is: 0.5999025925010892
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.908919	valid_1's rmse: 0.990223
# [200]	training's rmse: 0.838861	valid_1's rmse: 0.983914
# Early stopping, best iteration is:
# [189]	training's rmse: 0.845305	valid_1's rmse: 0.983504
# Partial score of fold 2 is: 0.5968607070236824
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907374	valid_1's rmse: 0.989087
# [200]	training's rmse: 0.839146	valid_1's rmse: 0.986347
# Early stopping, best iteration is:
# [153]	training's rmse: 0.868454	valid_1's rmse: 0.985414
# Partial score of fold 3 is: 0.5956081659447503
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.907574	valid_1's rmse: 0.989537
# [200]	training's rmse: 0.841753	valid_1's rmse: 0.98419
# Early stopping, best iteration is:
# [193]	training's rmse: 0.845515	valid_1's rmse: 0.983817
# Partial score of fold 4 is: 0.5868274123705723
#
# Our oof cohen kappa score is: 0.5915237392042567
#
# kappa:  0.5915237392042567
# |  30       |  0.5915   |  0.9639   |  0.1182   |  0.06036  |  0.03875  |  15.01    |  9.999    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.93698	valid_1's rmse: 1.00634
# [200]	training's rmse: 0.873364	valid_1's rmse: 0.992994
# [300]	training's rmse: 0.831414	valid_1's rmse: 0.990829
# Early stopping, best iteration is:
# [294]	training's rmse: 0.833846	valid_1's rmse: 0.990454
# Partial score of fold 0 is: 0.5816512796366488
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.939194	valid_1's rmse: 0.998101
# [200]	training's rmse: 0.876221	valid_1's rmse: 0.984423
# [300]	training's rmse: 0.833048	valid_1's rmse: 0.98394
# Early stopping, best iteration is:
# [244]	training's rmse: 0.855458	valid_1's rmse: 0.981988
# Partial score of fold 1 is: 0.5936398871064282
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.937585	valid_1's rmse: 1.00008
# [200]	training's rmse: 0.874753	valid_1's rmse: 0.985696
# [300]	training's rmse: 0.832162	valid_1's rmse: 0.984225
# [400]	training's rmse: 0.796418	valid_1's rmse: 0.985425
# Early stopping, best iteration is:
# [357]	training's rmse: 0.810883	valid_1's rmse: 0.983776
# Partial score of fold 2 is: 0.5936398871064282
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.939645	valid_1's rmse: 0.999976
# [200]	training's rmse: 0.876331	valid_1's rmse: 0.98676
# [300]	training's rmse: 0.834012	valid_1's rmse: 0.984867
# [400]	training's rmse: 0.798385	valid_1's rmse: 0.986204
# Early stopping, best iteration is:
# [326]	training's rmse: 0.824983	valid_1's rmse: 0.984724
# Partial score of fold 3 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938772	valid_1's rmse: 0.999196
# [200]	training's rmse: 0.876901	valid_1's rmse: 0.984531
# [300]	training's rmse: 0.834844	valid_1's rmse: 0.982379
# [400]	training's rmse: 0.799842	valid_1's rmse: 0.981751
# Early stopping, best iteration is:
# [376]	training's rmse: 0.807937	valid_1's rmse: 0.981284
# Partial score of fold 4 is: 0.5886172004911243
#
# Our oof cohen kappa score is: 0.5903426547736723
#
# kappa:  0.5903426547736723
# |  31       |  0.5903   |  0.5225   |  0.7262   |  4.97     |  0.03051  |  15.06    |  9.894    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.940486	valid_1's rmse: 1.00461
# [200]	training's rmse: 0.883956	valid_1's rmse: 0.99341
# [300]	training's rmse: 0.845919	valid_1's rmse: 0.99005
# [400]	training's rmse: 0.813645	valid_1's rmse: 0.990524
# Early stopping, best iteration is:
# [302]	training's rmse: 0.845219	valid_1's rmse: 0.989984
# Partial score of fold 0 is: 0.5791461974787844
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943589	valid_1's rmse: 0.989466
# [200]	training's rmse: 0.887397	valid_1's rmse: 0.978749
# [300]	training's rmse: 0.848263	valid_1's rmse: 0.976642
# [400]	training's rmse: 0.816934	valid_1's rmse: 0.977506
# Early stopping, best iteration is:
# [335]	training's rmse: 0.836496	valid_1's rmse: 0.976406
# Partial score of fold 1 is: 0.5997236580612417
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.942178	valid_1's rmse: 0.998787
# [200]	training's rmse: 0.886629	valid_1's rmse: 0.984431
# [300]	training's rmse: 0.847835	valid_1's rmse: 0.982658
# [400]	training's rmse: 0.815862	valid_1's rmse: 0.982695
# Early stopping, best iteration is:
# [313]	training's rmse: 0.843453	valid_1's rmse: 0.982351
# Partial score of fold 2 is: 0.5959660348244451
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.945384	valid_1's rmse: 0.994351
# [200]	training's rmse: 0.888803	valid_1's rmse: 0.982177
# [300]	training's rmse: 0.849782	valid_1's rmse: 0.980807
# [400]	training's rmse: 0.818099	valid_1's rmse: 0.980972
# Early stopping, best iteration is:
# [312]	training's rmse: 0.84581	valid_1's rmse: 0.980754
# Partial score of fold 3 is: 0.6027655435386485
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.943134	valid_1's rmse: 0.995891
# [200]	training's rmse: 0.887576	valid_1's rmse: 0.984344
# [300]	training's rmse: 0.849271	valid_1's rmse: 0.98115
# [400]	training's rmse: 0.817272	valid_1's rmse: 0.980967
# [500]	training's rmse: 0.78917	valid_1's rmse: 0.980175
# [600]	training's rmse: 0.763845	valid_1's rmse: 0.980369
# Early stopping, best iteration is:
# [532]	training's rmse: 0.780778	valid_1's rmse: 0.980009
# Partial score of fold 4 is: 0.5950604377251114
#
# Our oof cohen kappa score is: 0.5936353750043923
#
# kappa:  0.5936353750043923
# |  32       |  0.5936   |  0.9393   |  4.712    |  4.954    |  0.02728  |  16.57    |  1.207    |
# =================================================================================================
#
#  {'feature_fraction': 0.703907836790393, 'lambda_l1': 4.626198460575214, 'lambda_l2': 0.1502791865610248, 'learning_rate': 0.03073463252063875, 'max_depth': 15.16858698819633, 'subsample_freq': 9.801609882762447}

# %%
params = {
    'feature_fraction': 0.7, 
    'lambda_l1': 4.5, 
    'lambda_l2': 2.0, 
    'learning_rate': 0.03, 
    'max_depth': 16, 
    'subsample_freq': 1.1387271477760637
}

# %%
# cat_model = Catb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
lgb_model = Lgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals, ps=LGB_BO.max['params'])
# lgb_model = Lgb_Model(reduce_train, ajusted_te/t, features, categoricals=categoricals, ps=params)
# xgb_model = Xgb_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.933051	valid_1's rmse: 1.0006
# [200]	training's rmse: 0.873728	valid_1's rmse: 0.991745
# [300]	training's rmse: 0.832537	valid_1's rmse: 0.98933
# Early stopping, best iteration is:
# [284]	training's rmse: 0.838315	valid_1's rmse: 0.988765
# Partial score of fold 0 is: 0.5866614439523775
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.936511	valid_1's rmse: 0.990689
# [200]	training's rmse: 0.877628	valid_1's rmse: 0.979943
# [300]	training's rmse: 0.836265	valid_1's rmse: 0.981218
# Early stopping, best iteration is:
# [235]	training's rmse: 0.862098	valid_1's rmse: 0.97936
# Partial score of fold 1 is: 0.5990079203018519
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.9356	valid_1's rmse: 0.997997
# [200]	training's rmse: 0.877058	valid_1's rmse: 0.985978
# [300]	training's rmse: 0.836101	valid_1's rmse: 0.985727
# Early stopping, best iteration is:
# [232]	training's rmse: 0.863149	valid_1's rmse: 0.984941
# Partial score of fold 2 is: 0.5968607070236824
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.938656	valid_1's rmse: 0.993467
# [200]	training's rmse: 0.878083	valid_1's rmse: 0.982625
# [300]	training's rmse: 0.837275	valid_1's rmse: 0.980806
# Early stopping, best iteration is:
# [273]	training's rmse: 0.847311	valid_1's rmse: 0.980664
# Partial score of fold 3 is: 0.6031234124183433
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 0.936176	valid_1's rmse: 0.995042
# [200]	training's rmse: 0.878507	valid_1's rmse: 0.984613
# [300]	training's rmse: 0.838196	valid_1's rmse: 0.98358
# [400]	training's rmse: 0.803784	valid_1's rmse: 0.983517
# Early stopping, best iteration is:
# [366]	training's rmse: 0.815278	valid_1's rmse: 0.982942
# Partial score of fold 4 is: 0.5896910733634555
#
# Our oof cohen kappa score is: 0.5947090881231054

# %%
lgb_model.plot_importance(lgb_model.models, max_num_features=80, figsize=(12, 20))

# %%
# fig, ax = plt.subplots(1,1, figsize=(12, 24))
# xgb.plot_importance(xgb_model.models[0], ax=ax, max_num_features=100, importance_type='weight')

# %%
# cnn_model = Cnn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)
# nn_model = Nn_Model(reduce_train, ajusted_test, features, categoricals=categoricals)

# %% [markdown]
# ## Submission

# %%
weights = {'lbg': 0.80, 'cat': 0, 'xgb': 0.20, 'nn': 0.00}

# final_pred = (lgb_model.y_pred * weights['lbg']) + (xgb_model.y_pred * weights['xgb'])
final_pred = lgb_model.y_pred
#final_pred = cnn_model.y_pred
print(final_pred.shape)
# Out:
# (1000,)

# %%
# pd.DataFrame(
#     [(round(a, 2), round(b, 2), round(c, 2), round(d, 2)) 
#          for a, b, c, d in zip(lgb_model.y_pred, cat_model.y_pred, xgb_model.y_pred, nn_model.y_pred)],
#     columns=['lgb', 'cat', 'xgb', 'nn']
# ).head(50)

# %%
# improved
import scipy as sp
from functools import partial

from sklearn.metrics import cohen_kappa_score

class OptimizedRounder(object):
    """
    An optimizer for rounding thresholds
    to maximize Quadratic Weighted Kappa (QWK) score
    # https://www.kaggle.com/naveenasaithambi/optimizedrounder-improved
    """
    def __init__(self, num_class=4):
        self.coef_ = 0
        self.initial_coef = [0.5+i for i in range(num_class-1)]
        self.labels = [i for i in range(num_class)]
    
    def _kappa_loss(self, coef, X, y):
        """
        Get loss according to
        using current coefficients
        
        :param coef: A list of coefficients that will be used for rounding
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels=self.labels)
        return -cohen_kappa_score(y, preds, weights = 'quadratic')
    
    def fit(self, X, y):
        """
        Optimize rounding thresholds
        
        :param X: The raw predictions
        :param y: The ground truth labels
        """
        loss_partial = partial(self._kappa_loss, X = X, y = y)
        initial_coef = self.initial_coef
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method = 'nelder-mead')
    
    def predict(self, X, coef):
        """
        Make predictions with specified thresholds
        
        :param X: The raw predictions
        :param coef: A list of coefficients that will be used for rounding
        """
        preds = pd.cut(X, [-np.inf] + list(np.sort(coef)) + [np.inf], labels=self.labels)
        return preds
    
    def coefficients(self):
        """
        Return the optimized coefficients
        """
        return self.coef_['x']

# %%
trian_pred_reg = lgb_model.oof_pred

optR = OptimizedRounder(num_class=4)
optR.fit(trian_pred_reg, reduce_train['accuracy_group'])
coefficients = optR.coefficients()

opt_preds = optR.predict(trian_pred_reg.reshape(-1, ), coefficients)

# %%
off_score = cohen_kappa_score(reduce_train['accuracy_group'], opt_preds, weights='quadratic')
print(f'\noff_score is {off_score}\n')

sample_submission['accuracy_group'] = optR.predict(final_pred.reshape(-1, ), coefficients).astype(int)
sample_submission.to_csv('submission.csv', index=False)
display(sample_submission['accuracy_group'].value_counts(normalize=True).sort_index())
sample_submission['accuracy_group'].hist()
# Out:
# off_score is 0.6008433725432203
# 0    0.167
# 1    0.184
# 2    0.248
# 3    0.401
# Name: accuracy_group, dtype: float64
